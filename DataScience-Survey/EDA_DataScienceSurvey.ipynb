# %% [markdown]
# # What is this about?
#     This is exploratoray data analysis on kaggle's annual Machine Learning and Data Science Survey! This industry-wide survey that presents truly comprehensive view of the state of data science and machine learning community was live from 09/16/2022 to 10/16/2022.
#
#     There's a lot to explore in this data-set. The data-set include raw numbers about who is working with data, what is happening with machine learning in different industries, this could be the best way for new data scientists to break into the field.

# %% [markdown]
# # Step 0: Imports and reading the data!

# %% [markdown]
# ### Importing required packages and setting up work environment...!

# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
import seaborn as sns

plt.style.use('ggplot')
# pd.set_option('display.max_columns', 300)
# pd.set_option('display.max_rows', 300)

# %% [markdown]
# ### Reading the Data file.

# %%
df = pd.read_csv('kaggle_survey_2022_responses.csv');
# Out:
# C:\Users\Kushagra Chaturvedi\AppData\Local\Temp\ipykernel_10064\3521358420.py:1: DtypeWarning: Columns (0,208,225,255,257,260,270,271,277) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('kaggle_survey_2022_responses.csv');

# %% [markdown]
# # Step 1: Data Understanding
# - DataFrame Shape
# - DataFrame Head, Tail
# - DataFrame Describe
# - dtypes

# %%
df.head(3)
# Out:
#    Duration (in seconds)                           Q2  \
# 0  Duration (in seconds)  What is your age (# years)?
# 1                    121                        30-34
# 2                    462                        30-34
#
#                                        Q3  \
# 0  What is your gender? - Selected Choice
# 1                                     Man
# 2                                     Man
#
#                                           Q4  \
# 0  In which country do you currently reside?
# 1                                      India
# 2                                    Algeria
#
#                                                   Q5  \
# 0  Are you currently a student? (high school, uni...
# 1                                                 No
# 2                                                 No
#
#                                                 Q6_1  \
# 0  On which platforms have you begun or completed...
# 1                                                NaN
# 2                                                NaN
#
#                                                 Q6_2  \
# 0  On which platforms have you begun or completed...
# 1                                                NaN
# 2                                                NaN
#
#                                                 Q6_3  \
# 0  On which platforms have you begun or completed...
# 1                                                NaN
# 2                                                NaN
#
#                                                 Q6_4  \
# 0  On which platforms have you begun or completed...
# 1                                                NaN
# 2                                                NaN
#
#                                                 Q6_5  ...  \
# 0  On which platforms have you begun or completed...  ...
# 1                                                NaN  ...
# 2                                                NaN  ...
#
#                                                Q44_3  \
# 0  Who/what are your favorite media sources that ...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q44_4  \
# 0  Who/what are your favorite media sources that ...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q44_5  \
# 0  Who/what are your favorite media sources that ...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q44_6  \
# 0  Who/what are your favorite media sources that ...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q44_7  \
# 0  Who/what are your favorite media sources that ...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q44_8  \
# 0  Who/what are your favorite media sources that ...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q44_9  \
# 0  Who/what are your favorite media sources that ...
# 1                                                NaN
# 2                                                NaN
#
#                                               Q44_10  \
# 0  Who/what are your favorite media sources that ...
# 1                                                NaN
# 2                                                NaN
#
#                                               Q44_11  \
# 0  Who/what are your favorite media sources that ...
# 1                                                NaN
# 2                                                NaN
#
#                                               Q44_12
# 0  Who/what are your favorite media sources that ...
# 1                                                NaN
# 2                                                NaN
#
# [3 rows x 296 columns]

# %% [markdown]
# The data-set is result of total of 44 questions, In which, few questions are MSQ and each option of MSQ question is stored in a different column resulting in 296 different columns.

# %%
df.shape
# Out:
# (23998, 296)

# %%
# df.dtypes

# %% [markdown]
# # Step 2: Data Preperation
# - Dropping irrelevant columns and rows
# - identifying duplicated columns and rows
# - Renaming Columns
# - Feature Cration (New columns creation)

# %% [markdown]
# Removing the 0th header row!

# %%
df.drop(0, inplace=True)

# %%
list(df.columns)
# Out:
# ['Duration (in seconds)',
#  'Q2',
#  'Q3',
#  'Q4',
#  'Q5',
#  'Q6_1',
#  'Q6_2',
#  'Q6_3',
#  'Q6_4',
#  'Q6_5',
#  'Q6_6',
#  'Q6_7',
#  'Q6_8',
#  'Q6_9',
#  'Q6_10',
#  'Q6_11',
#  'Q6_12',
#  'Q7_1',
#  'Q7_2',
#  'Q7_3',
#  'Q7_4',
#  'Q7_5',
#  'Q7_6',
#  'Q7_7',
#  'Q8',
#  'Q9',
#  'Q10_1',
#  'Q10_2',
#  'Q10_3',
#  'Q11',
#  'Q12_1',
#  'Q12_2',
#  'Q12_3',
#  'Q12_4',
#  'Q12_5',
#  'Q12_6',
#  'Q12_7',
#  'Q12_8',
#  'Q12_9',
#  'Q12_10',
#  'Q12_11',
#  'Q12_12',
#  'Q12_13',
#  'Q12_14',
#  'Q12_15',
#  'Q13_1',
#  'Q13_2',
#  'Q13_3',
#  'Q13_4',
#  'Q13_5',
#  'Q13_6',
#  'Q13_7',
#  'Q13_8',
#  'Q13_9',
#  'Q13_10',
#  'Q13_11',
#  'Q13_12',
#  'Q13_13',
#  'Q13_14',
#  'Q14_1',
#  'Q14_2',
#  'Q14_3',
#  'Q14_4',
#  'Q14_5',
#  'Q14_6',
#  'Q14_7',
#  'Q14_8',
#  'Q14_9',
#  'Q14_10',
#  'Q14_11',
#  'Q14_12',
#  'Q14_13',
#  'Q14_14',
#  'Q14_15',
#  'Q14_16',
#  'Q15_1',
#  'Q15_2',
#  'Q15_3',
#  'Q15_4',
#  'Q15_5',
#  'Q15_6',
#  'Q15_7',
#  'Q15_8',
#  'Q15_9',
#  'Q15_10',
#  'Q15_11',
#  'Q15_12',
#  'Q15_13',
#  'Q15_14',
#  'Q15_15',
#  'Q16',
#  'Q17_1',
#  'Q17_2',
#  'Q17_3',
#  'Q17_4',
#  'Q17_5',
#  'Q17_6',
#  'Q17_7',
#  'Q17_8',
#  'Q17_9',
#  'Q17_10',
#  'Q17_11',
#  'Q17_12',
#  'Q17_13',
#  'Q17_14',
#  'Q17_15',
#  'Q18_1',
#  'Q18_2',
#  'Q18_3',
#  'Q18_4',
#  'Q18_5',
#  'Q18_6',
#  'Q18_7',
#  'Q18_8',
#  'Q18_9',
#  'Q18_10',
#  'Q18_11',
#  'Q18_12',
#  'Q18_13',
#  'Q18_14',
#  'Q19_1',
#  'Q19_2',
#  'Q19_3',
#  'Q19_4',
#  'Q19_5',
#  'Q19_6',
#  'Q19_7',
#  'Q19_8',
#  'Q20_1',
#  'Q20_2',
#  'Q20_3',
#  'Q20_4',
#  'Q20_5',
#  'Q20_6',
#  'Q21_1',
#  'Q21_2',
#  'Q21_3',
#  'Q21_4',
#  'Q21_5',
#  'Q21_6',
#  'Q21_7',
#  'Q21_8',
#  'Q21_9',
#  'Q21_10',
#  'Q22',
#  'Q23',
#  'Q24',
#  'Q25',
#  'Q26',
#  'Q27',
#  'Q28_1',
#  'Q28_2',
#  'Q28_3',
#  'Q28_4',
#  'Q28_5',
#  'Q28_6',
#  'Q28_7',
#  'Q28_8',
#  'Q29',
#  'Q30',
#  'Q31_1',
#  'Q31_2',
#  'Q31_3',
#  'Q31_4',
#  'Q31_5',
#  'Q31_6',
#  'Q31_7',
#  'Q31_8',
#  'Q31_9',
#  'Q31_10',
#  'Q31_11',
#  'Q31_12',
#  'Q32',
#  'Q33_1',
#  'Q33_2',
#  'Q33_3',
#  'Q33_4',
#  'Q33_5',
#  'Q34_1',
#  'Q34_2',
#  'Q34_3',
#  'Q34_4',
#  'Q34_5',
#  'Q34_6',
#  'Q34_7',
#  'Q34_8',
#  'Q35_1',
#  'Q35_2',
#  'Q35_3',
#  'Q35_4',
#  'Q35_5',
#  'Q35_6',
#  'Q35_7',
#  'Q35_8',
#  'Q35_9',
#  'Q35_10',
#  'Q35_11',
#  'Q35_12',
#  'Q35_13',
#  'Q35_14',
#  'Q35_15',
#  'Q35_16',
#  'Q36_1',
#  'Q36_2',
#  'Q36_3',
#  'Q36_4',
#  'Q36_5',
#  'Q36_6',
#  'Q36_7',
#  'Q36_8',
#  'Q36_9',
#  'Q36_10',
#  'Q36_11',
#  'Q36_12',
#  'Q36_13',
#  'Q36_14',
#  'Q36_15',
#  'Q37_1',
#  'Q37_2',
#  'Q37_3',
#  'Q37_4',
#  'Q37_5',
#  'Q37_6',
#  'Q37_7',
#  'Q37_8',
#  'Q37_9',
#  'Q37_10',
#  'Q37_11',
#  'Q37_12',
#  'Q37_13',
#  'Q38_1',
#  'Q38_2',
#  'Q38_3',
#  'Q38_4',
#  'Q38_5',
#  'Q38_6',
#  'Q38_7',
#  'Q38_8',
#  'Q39_1',
#  'Q39_2',
#  'Q39_3',
#  'Q39_4',
#  'Q39_5',
#  'Q39_6',
#  'Q39_7',
#  'Q39_8',
#  'Q39_9',
#  'Q39_10',
#  'Q39_11',
#  'Q39_12',
#  'Q40_1',
#  'Q40_2',
#  'Q40_3',
#  'Q40_4',
#  'Q40_5',
#  'Q40_6',
#  'Q40_7',
#  'Q40_8',
#  'Q40_9',
#  'Q40_10',
#  'Q40_11',
#  'Q40_12',
#  'Q40_13',
#  'Q40_14',
#  'Q40_15',
#  'Q41_1',
#  'Q41_2',
#  'Q41_3',
#  'Q41_4',
#  'Q41_5',
#  'Q41_6',
#  'Q41_7',
#  'Q41_8',
#  'Q41_9',
#  'Q42_1',
#  'Q42_2',
#  'Q42_3',
#  'Q42_4',
#  'Q42_5',
#  'Q42_6',
#  'Q42_7',
#  'Q42_8',
#  'Q42_9',
#  'Q43',
#  'Q44_1',
#  'Q44_2',
#  'Q44_3',
#  'Q44_4',
#  'Q44_5',
#  'Q44_6',
#  'Q44_7',
#  'Q44_8',
#  'Q44_9',
#  'Q44_10',
#  'Q44_11',
#  'Q44_12']

# %% [markdown]
# ### Subsetting required columns...!
# Because the data-set is very big. Its will hard to explore the whole of it at once. Here i am subsetting it with questions related to cloud, internet resources and some of the personal questions like age, gender, country, role, yearly compensation etc and few others.

# %%
df = df[[
        #'Duration (in seconds)',
        'Q2',
        'Q3',
        'Q4',
        #'Q5',
        #'Q6_1',  'Q6_2',  'Q6_3',  'Q6_4',  'Q6_5',  'Q6_6',  'Q6_7',  'Q6_8',  'Q6_9',  'Q6_10',  'Q6_11',  'Q6_12',
        #'Q7_1',  'Q7_2',  'Q7_3',  'Q7_4',  'Q7_5',  'Q7_6',  'Q7_7',
        #'Q8',
        #'Q9',
        #'Q10_1',  'Q10_2',  'Q10_3',
        'Q11',
        'Q12_1',  'Q12_2',  'Q12_3',  'Q12_4',  'Q12_5',  'Q12_6',  'Q12_7',  'Q12_8',  'Q12_9',  'Q12_10',  'Q12_11',  'Q12_12',  'Q12_13',  'Q12_14',  'Q12_15',
        'Q13_1',  'Q13_2',  'Q13_3',  'Q13_4',  'Q13_5',  'Q13_6',  'Q13_7',  'Q13_8',  'Q13_9',  'Q13_10',  'Q13_11',  'Q13_12',  'Q13_13',  'Q13_14',
        'Q14_1',  'Q14_2',  'Q14_3',  'Q14_4',  'Q14_5',  'Q14_6',  'Q14_7',  'Q14_8',  'Q14_9',  'Q14_10',  'Q14_11',  'Q14_12',  'Q14_13',  'Q14_14',  'Q14_15',  'Q14_16',
        'Q15_1',  'Q15_2',  'Q15_3',  'Q15_4',  'Q15_5',  'Q15_6',  'Q15_7',  'Q15_8',  'Q15_9',  'Q15_10',  'Q15_11',  'Q15_12',  'Q15_13',  'Q15_14',  'Q15_15',
        #'Q16',
        'Q17_1',  'Q17_2',  'Q17_3',  'Q17_4',  'Q17_5',  'Q17_6',  'Q17_7',  'Q17_8',  'Q17_9',  'Q17_10',  'Q17_11',  'Q17_12',  'Q17_13',  'Q17_14',  'Q17_15',
        #'Q18_1',  'Q18_2',  'Q18_3',  'Q18_4',  'Q18_5',  'Q18_6',  'Q18_7',  'Q18_8',  'Q18_9',  'Q18_10',  'Q18_11',  'Q18_12',  'Q18_13',  'Q18_14',
        #'Q19_1',  'Q19_2',  'Q19_3',  'Q19_4',  'Q19_5',  'Q19_6',  'Q19_7',  'Q19_8',
        #'Q20_1',  'Q20_2',  'Q20_3',  'Q20_4',  'Q20_5',  'Q20_6',
        'Q21_1',  'Q21_2',  'Q21_3',  'Q21_4',  'Q21_5',  'Q21_6',  'Q21_7',  'Q21_8',  'Q21_9',  'Q21_10',
        'Q22',
        'Q23',
        'Q24',
        'Q25',
        'Q26',
        #'Q27',
        #'Q28_1',  'Q28_2',  'Q28_3',  'Q28_4',  'Q28_5',  'Q28_6',  'Q28_7',  'Q28_8',
        'Q29',
        'Q30',  'Q31_1',  'Q31_2',  'Q31_3',  'Q31_4',  'Q31_5',  'Q31_6',  'Q31_7',  'Q31_8',  'Q31_9',  'Q31_10',  'Q31_11',  'Q31_12',
        'Q32',
        'Q33_1',  'Q33_2',  'Q33_3',  'Q33_4',  'Q33_5',
        'Q34_1',  'Q34_2',  'Q34_3',  'Q34_4',  'Q34_5',  'Q34_6',  'Q34_7',  'Q34_8',
        'Q35_1',  'Q35_2',  'Q35_3',  'Q35_4',  'Q35_5',  'Q35_6',  'Q35_7',  'Q35_8',  'Q35_9',  'Q35_10',  'Q35_11',  'Q35_12',  'Q35_13',  'Q35_14',  'Q35_15',  'Q35_16',
        'Q36_1',  'Q36_2',  'Q36_3',  'Q36_4',  'Q36_5',  'Q36_6',  'Q36_7',  'Q36_8',  'Q36_9',  'Q36_10',  'Q36_11',  'Q36_12',  'Q36_13',  'Q36_14',  'Q36_15',
        'Q37_1',  'Q37_2',  'Q37_3',  'Q37_4',  'Q37_5',  'Q37_6',  'Q37_7',  'Q37_8',  'Q37_9',  'Q37_10',  'Q37_11',  'Q37_12',  'Q37_13',
        'Q38_1',  'Q38_2',  'Q38_3',  'Q38_4',  'Q38_5',  'Q38_6',  'Q38_7',  'Q38_8',
        'Q39_1',  'Q39_2',  'Q39_3',  'Q39_4',  'Q39_5',  'Q39_6',  'Q39_7',  'Q39_8',  'Q39_9',  'Q39_10',  'Q39_11',  'Q39_12',
        'Q40_1',  'Q40_2',  'Q40_3',  'Q40_4',  'Q40_5',  'Q40_6',  'Q40_7',  'Q40_8',  'Q40_9',  'Q40_10',  'Q40_11',  'Q40_12',  'Q40_13',  'Q40_14',  'Q40_15',
        'Q41_1',  'Q41_2',  'Q41_3',  'Q41_4',  'Q41_5',  'Q41_6',  'Q41_7',  'Q41_8',  'Q41_9',
        'Q42_1',  'Q42_2',  'Q42_3',  'Q42_4',  'Q42_5',  'Q42_6',  'Q42_7',  'Q42_8',  'Q42_9',
        'Q43',
        #'Q44_1',  'Q44_2',  'Q44_3',  'Q44_4',  'Q44_5',  'Q44_6',  'Q44_7',  'Q44_8',  'Q44_9',  'Q44_10',  'Q44_11',  'Q44_12' 
]]

# %%
df.head(3)
# Out:
#       Q2   Q3       Q4        Q11   Q12_1 Q12_2 Q12_3 Q12_4 Q12_5 Q12_6  ...  \
# 1  30-34  Man    India        NaN     NaN   NaN   NaN   NaN   NaN   NaN  ...
# 2  30-34  Man  Algeria  1-3 years     NaN   NaN   NaN   NaN   NaN   NaN  ...
# 3  18-21  Man    Egypt  1-3 years  Python   NaN   SQL     C   NaN   NaN  ...
#
#   Q42_1 Q42_2 Q42_3 Q42_4 Q42_5 Q42_6 Q42_7 Q42_8 Q42_9  Q43
# 1   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  NaN
# 2   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  NaN
# 3   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  NaN
#
# [3 rows x 220 columns]

# %% [markdown]
# ### Merging columns of Multiple Select Question & Creating new columns.

# %%
df['Programming_Language'] = df[df.columns[4:19]].apply(lambda x: ','.join(x.dropna().str.strip()),axis=1)
df['IDE'] = df[df.columns[19:33]].apply(lambda x: ','.join(x.dropna().str.strip()),axis=1)
df['Hosted_Notebook'] = df[df.columns[33:49]].apply(lambda x: ','.join(x.dropna().str.strip()),axis=1)
df['Visualization_Libraries'] = df[df.columns[49:64]].apply(lambda x: ','.join(x.dropna().str.strip()),axis=1)
df['ML_Frameworks'] = df[df.columns[64:79]].apply(lambda x: ','.join(x.dropna().str.strip()),axis=1)
df['Pre-Trained_Model_Weights'] = df[df.columns[79:89]].apply(lambda x: ','.join(x.dropna().str.strip()),axis=1)
df['Best_Exp_Cloud_platForm'] = df[df.columns[96:108]].apply(lambda x: ','.join(x.dropna().str.strip()),axis=1)
df['Cloud_Computing_Products'] = df[df.columns[109:114]].apply(lambda x: ','.join(x.dropna().str.strip()),axis=1)
df['Data_Storage_Products'] = df[df.columns[114:122]].apply(lambda x: ','.join(x.dropna().str.strip()),axis=1)
df['DBMS'] = df[df.columns[122:138]].apply(lambda x: ','.join(x.dropna().str.strip()),axis=1)
df['BI_Tools'] = df[df.columns[138:153]].apply(lambda x: ','.join(x.dropna().str.strip()),axis=1)
df['Managed_ML_Products'] = df[df.columns[153:166]].apply(lambda x: ','.join(x.dropna().str.strip()),axis=1)
df['Auto_ML_Tools'] = df[df.columns[166:174]].apply(lambda x: ','.join(x.dropna().str.strip()),axis=1)
df['Serve_ML_Models'] = df[df.columns[174:186]].apply(lambda x: ','.join(x.dropna().str.strip()),axis=1)
df['ML_Monitering_Tools'] = df[df.columns[186:201]].apply(lambda x: ','.join(x.dropna().str.strip()),axis=1)
df['Ethical_AI_Products'] = df[df.columns[201:210]].apply(lambda x: ','.join(x.dropna().str.strip()),axis=1)
df['Hardware'] = df[df.columns[210:219]].apply(lambda x: ','.join(x.dropna().str.strip()),axis=1)

# %% [markdown]
# ### Droping merged columns.

# %%
remove_col = df.columns[4:89].append(df.columns[96:108]).append(df.columns[109:219])
df.drop(remove_col, axis=1, inplace=True)

# %%
list(df.columns)
# Out:
# ['Q2',
#  'Q3',
#  'Q4',
#  'Q11',
#  'Q22',
#  'Q23',
#  'Q24',
#  'Q25',
#  'Q26',
#  'Q29',
#  'Q30',
#  'Q32',
#  'Q43',
#  'Programming_Language',
#  'IDE',
#  'Hosted_Notebook',
#  'Visualization_Libraries',
#  'ML_Frameworks',
#  'Pre-Trained_Model_Weights',
#  'Best_Exp_Cloud_platForm',
#  'Cloud_Computing_Products',
#  'Data_Storage_Products',
#  'DBMS',
#  'BI_Tools',
#  'Managed_ML_Products',
#  'Auto_ML_Tools',
#  'Serve_ML_Models',
#  'ML_Monitering_Tools',
#  'Ethical_AI_Products',
#  'Hardware']

# %% [markdown]
# ### Renaming columns

# %%
df.rename(columns = {
    'Q2': 'Age',
    'Q3' : 'Gender',
    'Q4' : 'Country',
    'Q11' : 'Coding_Experience',
    'Q22': 'ML_Model_Hubs/Repo',
    'Q23': 'Role',
    'Q24': 'Industry',
    'Q25': 'Company_Size',
    'Q26': 'Team_Size',
    'Q29': 'SalaryPerAnnum_USD',
    'Q30': 'Cloud_Expenses',
    'Q32': 'Best_Cloud_Experience',
    'Q43': 'Time_TPUs_Used',
}, inplace=True)

# %%
list(df.columns)
# Out:
# ['Age',
#  'Gender',
#  'Country',
#  'Coding_Experience',
#  'ML_Model_Hubs/Repo',
#  'Role',
#  'Industry',
#  'Company_Size',
#  'Team_Size',
#  'SalaryPerAnnum_USD',
#  'Cloud_Expenses',
#  'Best_Cloud_Experience',
#  'Time_TPUs_Used',
#  'Programming_Language',
#  'IDE',
#  'Hosted_Notebook',
#  'Visualization_Libraries',
#  'ML_Frameworks',
#  'Pre-Trained_Model_Weights',
#  'Best_Exp_Cloud_platForm',
#  'Cloud_Computing_Products',
#  'Data_Storage_Products',
#  'DBMS',
#  'BI_Tools',
#  'Managed_ML_Products',
#  'Auto_ML_Tools',
#  'Serve_ML_Models',
#  'ML_Monitering_Tools',
#  'Ethical_AI_Products',
#  'Hardware']

# %%
df.head(3)
# Out:
#      Age Gender  Country Coding_Experience ML_Model_Hubs/Repo Role Industry  \
# 1  30-34    Man    India               NaN                NaN  NaN      NaN
# 2  30-34    Man  Algeria         1-3 years                NaN  NaN      NaN
# 3  18-21    Man    Egypt         1-3 years                NaN  NaN      NaN
#
#   Company_Size Team_Size SalaryPerAnnum_USD  ... Cloud_Computing_Products  \
# 1          NaN       NaN                NaN  ...
# 2          NaN       NaN                NaN  ...
# 3          NaN       NaN                NaN  ...
#
#   Data_Storage_Products DBMS BI_Tools Managed_ML_Products Auto_ML_Tools  \
# 1
# 2
# 3
#
#   Serve_ML_Models ML_Monitering_Tools Ethical_AI_Products Hardware
# 1
# 2
# 3
#
# [3 rows x 30 columns]

# %% [markdown]
# ### Renaming values with large names replacing null/NaN with None.

# %%
df.Country = df.Country.replace(
   ['United States of America','United Kingdom of Great Britain and Northern Ireland','Viet Nam','Iran, Islamic Republic of...', 'United Arab Emirates', 'Czech Republic', 'Hong Kong (S.A.R.)', 'I do not wish to disclose my location'],
   ['USA', 'UK', 'Vietnam', 'Iran',  'UAE', 'Czechia', 'Hong Kong', 'Not wish to disclose'])


df.Role = df.Role.replace(
   ['Data Analyst (Business, Marketing, Financial, Quantitative, etc)', 'Manager (Program, Project, Operations, Executive-level, etc)'],
   ['Data Analyst', 'Manager'])

df.Cloud_Expenses = df.Cloud_Expenses.replace(['$0 ($USD)', '$100,000 or more ($USD)'],
                          ['$0', '$100,000 or more'])

df.Best_Cloud_Experience = df.Best_Cloud_Experience.replace(['They all had a similarly enjoyable developer experience'],
                          ['Similar experience'])

df.IDE = df.IDE.replace(['', 'Visual Studio Code (VSCode)'],
               ['None', 'VSCode'])

df.fillna('None', inplace=True)

df = df.replace([''], 'None')

# %% [markdown]
# # Step 3: Features Understanding
# - Unique values
# - Ploting / Graphing
#  - Distributions
#  - Histograms, barplots, KDE
#  - Co-Relation between features

# %% [markdown]
# ### Looking for unique values.

# %%
for column in df.columns:
    print(f'{column} : {df[column].unique()[:30]}\n\n\n')
# Out:
# Age : ['30-34' '18-21' '55-59' '45-49' '70+' '22-24' '35-39' '40-44' '50-54'
#  '25-29' '60-69']
#
#
#
# Gender : ['Man' 'Woman' 'Prefer not to say' 'Nonbinary' 'Prefer to self-describe']
#
#
#
# Country : ['India' 'Algeria' 'Egypt' 'France' 'Germany' 'Australia' 'Other'
#  'South Korea' 'USA' 'Pakistan' 'Mexico' 'Singapore' 'Italy' 'Taiwan'
#  'China' 'Argentina' 'Turkey' 'Brazil' 'Nigeria' 'Chile' 'Japan' 'Canada'
#  'Indonesia' 'Israel' 'Colombia' 'Russia' 'UK' 'Ethiopia' 'South Africa'
#  'Vietnam']
#
#
#
# Coding_Experience : ['None' '1-3 years' '10-20 years' '5-10 years' '20+ years' '3-5 years'
#  '< 1 years' 'I have never written code']
#
#
#
# ML_Model_Hubs/Repo : ['None' ' Huggingface Models ' ' Kaggle datasets ' '  TensorFlow Hub '
#  ' PyTorch Hub ' ' ONNX models ' ' Timm '
#  'Other storage services (i.e. google drive)' ' Jumpstart '
#  ' NVIDIA NGC models  ']
#
#
#
# Role : ['None' 'Data Scientist' 'Software Engineer' 'Research Scientist' 'Other'
#  'Developer Advocate' 'Data Analyst' 'Data Engineer'
#  'Currently not employed' 'Machine Learning/ MLops Engineer'
#  'Engineer (non-software)' 'Teacher / professor' 'Statistician' 'Manager'
#  'Data Administrator' 'Data Architect']
#
#
#
# Industry : ['None' 'Online Service/Internet-based Services'
#  'Insurance/Risk Assessment' 'Government/Public Service'
#  'Manufacturing/Fabrication' 'Computers/Technology' 'Accounting/Finance'
#  'Academics/Education' 'Non-profit/Service' 'Other'
#  'Medical/Pharmaceutical' 'Marketing/CRM' 'Energy/Mining'
#  'Broadcasting/Communications' 'Retail/Sales' 'Shipping/Transportation']
#
#
#
# Company_Size : ['None' '0-49 employees' '250-999 employees' '1000-9,999 employees'
#  '10,000 or more employees' '50-249 employees']
#
#
#
# Team_Size : ['None' '1-2' '20+' '3-4' '5-9' '0' '10-14' '15-19']
#
#
#
# SalaryPerAnnum_USD : ['None' '25,000-29,999' '100,000-124,999' '200,000-249,999'
#  '150,000-199,999' '90,000-99,999' '30,000-39,999' '3,000-3,999'
#  '50,000-59,999' '125,000-149,999' '15,000-19,999' '5,000-7,499'
#  '10,000-14,999' '20,000-24,999' '$0-999' '7,500-9,999' '4,000-4,999'
#  '80,000-89,999' '2,000-2,999' '250,000-299,999' '1,000-1,999'
#  '$500,000-999,999' '70,000-79,999' '60,000-69,999' '40,000-49,999'
#  '>$1,000,000' '300,000-499,999']
#
#
#
# Cloud_Expenses : ['None' '$1000-$9,999' '$0' '$100-$999' '$100,000 or more' '$1-$99'
#  '$10,000-$99,999']
#
#
#
# Best_Cloud_Experience : ['None' 'Similar experience' ' Microsoft Azure ' ' Alibaba Cloud '
#  ' Amazon Web Services (AWS) ' 'None were satisfactory'
#  ' Google Cloud Platform (GCP) ' ' VMware Cloud ' ' IBM Cloud / Red Hat '
#  ' Oracle Cloud ' 'Other' ' SAP Cloud ' ' Tencent Cloud ' ' Huawei Cloud ']
#
#
#
# Time_TPUs_Used : ['None' '2-5 times' 'Never' 'More than 25 times' 'Once' '6-25 times']
#
#
#
# Programming_Language : ['None' 'Java' 'Python,SQL,C,MATLAB' 'Python,SQL,Bash' 'Python,C++,Java'
#  'Python,SQL' 'Python,SQL,C++,Javascript'
#  'Python,SQL,C,Java,Javascript,PHP' 'Python' 'Python,R,SQL,C,C++,Bash'
#  'Python,R,SQL' 'Python,C#,MATLAB,Other' 'Python,SQL,C,C#,Javascript,Bash'
#  'Python,SQL,C,C++,Java,Javascript,Bash' 'Python,MATLAB'
#  'Python,Java,MATLAB' 'Python,SQL,Javascript,Bash'
#  'Python,R,SQL,C,C++,Other' 'R' 'Python,C#,Javascript'
#  'Python,C,C++,MATLAB' 'Other' 'Python,C,C#,Java,MATLAB'
#  'Python,R,SQL,C++' 'Python,Java' 'SQL' 'Python,R,SQL,C,MATLAB'
#  'Python,Other' 'Python,SQL,Java,Javascript,PHP,Go'
#  'Python,C++,Javascript,Bash']
#
#
#
# IDE : ['None' 'Notepad++,Other' 'JupyterLab,Jupyter Notebook'
#  'Visual Studio Code (VSCode),Sublime Text,Vim / Emacs,Jupyter Notebook'
#  'Visual Studio Code (VSCode),PyCharm,Spyder,Notepad++' 'Jupyter Notebook'
#  'Visual Studio Code (VSCode),Jupyter Notebook,IntelliJ,Other'
#  'Visual Studio,Jupyter Notebook' 'PyCharm,Jupyter Notebook'
#  'JupyterLab,RStudio,Visual Studio,Visual Studio Code (VSCode),PyCharm,Jupyter Notebook'
#  'JupyterLab,RStudio,Visual Studio Code (VSCode),Jupyter Notebook'
#  'Visual Studio,Visual Studio Code (VSCode),Spyder,Sublime Text,MATLAB,Jupyter Notebook'
#  'JupyterLab,Visual Studio,Visual Studio Code (VSCode),Spyder'
#  'JupyterLab,Visual Studio Code (VSCode),Jupyter Notebook' 'JupyterLab'
#  'Visual Studio Code (VSCode),PyCharm,Notepad++'
#  'Visual Studio,MATLAB,Jupyter Notebook'
#  'Notepad++,Jupyter Notebook,IntelliJ,Other'
#  'Visual Studio Code (VSCode),Sublime Text,Jupyter Notebook,IntelliJ'
#  'JupyterLab,Visual Studio,Visual Studio Code (VSCode),Jupyter Notebook'
#  'Visual Studio Code (VSCode),Spyder,Jupyter Notebook' 'RStudio'
#  'JupyterLab,RStudio,Spyder,Notepad++,Sublime Text,Jupyter Notebook'
#  'Visual Studio,Visual Studio Code (VSCode),PyCharm,Notepad++,MATLAB,Jupyter Notebook'
#  'Notepad++' 'IntelliJ' 'Visual Studio,PyCharm,MATLAB,IntelliJ'
#  'JupyterLab,RStudio,Visual Studio Code (VSCode),PyCharm,Notepad++,MATLAB,Jupyter Notebook'
#  'Visual Studio Code (VSCode),Jupyter Notebook' 'Notepad++,Vim / Emacs']
#
#
#
# Hosted_Notebook : ['None' 'Kaggle Notebooks,IBM Watson Studio'
#  'Kaggle Notebooks,Colab Notebooks,Deepnote Notebooks'
#  'Kaggle Notebooks,Colab Notebooks' 'Colab Notebooks' 'Kaggle Notebooks'
#  'Kaggle Notebooks,Colab Notebooks,Azure Notebooks,Google Cloud Vertex AI Workbench'
#  'Kaggle Notebooks,Colab Notebooks,Databricks Collaborative Notebooks'
#  'Colab Notebooks,Databricks Collaborative Notebooks'
#  'Kaggle Notebooks,Amazon Sagemaker Studio Lab'
#  'Colab Notebooks,Google Cloud Vertex AI Workbench'
#  'Amazon Sagemaker Studio,Amazon Sagemaker Studio Lab,Google Cloud Vertex AI Workbench'
#  'Kaggle Notebooks,Colab Notebooks,Google Cloud Vertex AI Workbench'
#  'Azure Notebooks,Databricks Collaborative Notebooks'
#  'Amazon Sagemaker Studio,Amazon Sagemaker Studio Lab,Amazon EMR Notebooks'
#  'Kaggle Notebooks,Colab Notebooks,Azure Notebooks,Noteable Notebooks,Gradient Notebooks'
#  'Colab Notebooks,Azure Notebooks' 'Colab Notebooks,Other'
#  'Kaggle Notebooks,Colab Notebooks,IBM Watson Studio'
#  'Colab Notebooks,IBM Watson Studio,Google Cloud Vertex AI Workbench'
#  'Other' 'Google Cloud Vertex AI Workbench'
#  'Amazon Sagemaker Studio,Databricks Collaborative Notebooks'
#  'Colab Notebooks,Gradient Notebooks'
#  'Colab Notebooks,Amazon Sagemaker Studio,Amazon Sagemaker Studio Lab'
#  'Kaggle Notebooks,Noteable Notebooks,Deepnote Notebooks'
#  'Kaggle Notebooks,Colab Notebooks,Amazon Sagemaker Studio,Amazon Sagemaker Studio Lab'
#  'Kaggle Notebooks,Colab Notebooks,Azure Notebooks,Other'
#  'Colab Notebooks,Amazon Sagemaker Studio Lab'
#  'Colab Notebooks,Azure Notebooks,Amazon Sagemaker Studio Lab']
#
#
#
# Visualization_Libraries : ['None' 'Matplotlib'
#  'Matplotlib,Seaborn,Plotly / Plotly Express,Geoplotlib'
#  'Matplotlib,Seaborn'
#  'Matplotlib,Seaborn,Plotly / Plotly Express,Ggplot / ggplot2'
#  'Matplotlib,Ggplot / ggplot2,D3 js,Geoplotlib' 'Plotly / Plotly Express'
#  'Matplotlib,Ggplot / ggplot2'
#  'Seaborn,Plotly / Plotly Express,Ggplot / ggplot2'
#  'Matplotlib,Seaborn,Plotly / Plotly Express,Altair,Bokeh'
#  'Matplotlib,Seaborn,Other' 'Seaborn'
#  'Matplotlib,Plotly / Plotly Express,Shiny'
#  'Matplotlib,Seaborn,Leaflet / Folium'
#  'Matplotlib,Plotly / Plotly Express,D3 js' 'Ggplot / ggplot2'
#  'Matplotlib,Seaborn,Plotly / Plotly Express'
#  'Matplotlib,Seaborn,Ggplot / ggplot2'
#  'Matplotlib,Seaborn,Plotly / Plotly Express,Ggplot / ggplot2,Shiny,D3 js,Bokeh,Geoplotlib'
#  'Matplotlib,Seaborn,Bokeh' 'Matplotlib,Plotly / Plotly Express'
#  'Matplotlib,D3 js'
#  'Matplotlib,Seaborn,Plotly / Plotly Express,Ggplot / ggplot2,Shiny,Bokeh,Geoplotlib'
#  'Plotly / Plotly Express,Ggplot / ggplot2' 'Seaborn,Leaflet / Folium'
#  'Matplotlib,Plotly / Plotly Express,Geoplotlib'
#  'Matplotlib,Plotly / Plotly Express,Pygal,Dygraphs'
#  'Plotly / Plotly Express,Ggplot / ggplot2,Shiny'
#  'Matplotlib,Plotly / Plotly Express,Ggplot / ggplot2,Shiny,Bokeh'
#  'Matplotlib,Ggplot / ggplot2,Geoplotlib,Other']
#
#
#
# ML_Frameworks : ['None' 'Scikit-learn,TensorFlow,PyTorch'
#  'Scikit-learn,PyTorch,Xgboost,PyTorch Lightning'
#  'Scikit-learn,PyTorch,Huggingface'
#  'Scikit-learn,TensorFlow,Keras,PyTorch' 'Scikit-learn' 'Keras'
#  'Scikit-learn,TensorFlow,Keras,PyTorch,Xgboost,LightGBM,CatBoost,Tidymodels,PyTorch Lightning'
#  'TensorFlow,Keras'
#  'Scikit-learn,TensorFlow,Keras,PyTorch,Xgboost,Huggingface'
#  'Scikit-learn,TensorFlow,Keras,PyTorch,LightGBM,CatBoost'
#  'Scikit-learn,Keras,Xgboost,LightGBM,CatBoost' 'Xgboost'
#  'Scikit-learn,TensorFlow,Keras' 'Scikit-learn,Xgboost'
#  'Scikit-learn,TensorFlow,Keras,Xgboost,LightGBM,CatBoost'
#  'Scikit-learn,TensorFlow,Keras,Xgboost,LightGBM'
#  'Scikit-learn,TensorFlow,Xgboost'
#  'Scikit-learn,TensorFlow,Keras,PyTorch,Xgboost,CatBoost' 'PyTorch'
#  'Scikit-learn,PyTorch' 'Scikit-learn,TensorFlow,Keras,Other'
#  'Scikit-learn,TensorFlow,Keras,PyTorch,Caret,PyTorch Lightning'
#  'Scikit-learn,PyTorch,Xgboost,LightGBM,CatBoost,Huggingface'
#  'Keras,PyTorch' 'Scikit-learn,TensorFlow,PyTorch,Xgboost,LightGBM'
#  'TensorFlow,PyTorch' 'Scikit-learn,TensorFlow,Keras,PyTorch,Xgboost'
#  'Scikit-learn,TensorFlow' 'TensorFlow,PyTorch Lightning']
#
#
#
# Pre-Trained_Model_Weights : ['None'
#  'No, I do not download pre-trained model weights on a regular basis'
#  'Kaggle datasets'
#  'Huggingface Models,ONNX models,Other storage services (i.e. google drive)'
#  'TensorFlow Hub,PyTorch Hub,Kaggle datasets'
#  'TensorFlow Hub,Huggingface Models' 'Huggingface Models' 'TensorFlow Hub'
#  'TensorFlow Hub,Kaggle datasets'
#  'TensorFlow Hub,Huggingface Models,Kaggle datasets'
#  'TensorFlow Hub,PyTorch Hub,Huggingface Models,Kaggle datasets'
#  'Other storage services (i.e. google drive)'
#  'TensorFlow Hub,PyTorch Hub,Huggingface Models'
#  'TensorFlow Hub,PyTorch Hub' 'PyTorch Hub'
#  'PyTorch Hub,Huggingface Models,Timm'
#  'PyTorch Hub,Huggingface Models,Kaggle datasets'
#  'TensorFlow Hub,PyTorch Hub,NVIDIA NGC models,Kaggle datasets,Other storage services (i.e. google drive)'
#  'Huggingface Models,ONNX models,NVIDIA NGC models,Kaggle datasets'
#  'ONNX models,Kaggle datasets' 'Huggingface Models,Timm'
#  'PyTorch Hub,Huggingface Models' 'PyTorch Hub,Kaggle datasets'
#  'TensorFlow Hub,NVIDIA NGC models,Kaggle datasets'
#  'TensorFlow Hub,PyTorch Hub,Huggingface Models,NVIDIA NGC models,Kaggle datasets'
#  'TensorFlow Hub,Jumpstart,Kaggle datasets'
#  'TensorFlow Hub,PyTorch Hub,ONNX models'
#  'Huggingface Models,Kaggle datasets' 'Jumpstart' 'ONNX models']
#
#
#
# Best_Exp_Cloud_platForm : ['None' 'Other' 'Amazon Web Services (AWS),Google Cloud Platform (GCP)'
#  'Amazon Web Services (AWS),Microsoft Azure' 'Alibaba Cloud,Tencent Cloud'
#  'Google Cloud Platform (GCP)' 'Amazon Web Services (AWS)'
#  'Microsoft Azure' 'Amazon Web Services (AWS),Other' 'Oracle Cloud'
#  'Amazon Web Services (AWS),Microsoft Azure,Google Cloud Platform (GCP)'
#  'Huawei Cloud' 'IBM Cloud / Red Hat' 'Microsoft Azure,Alibaba Cloud'
#  'IBM Cloud / Red Hat,Oracle Cloud,VMware Cloud'
#  'Google Cloud Platform (GCP),VMware Cloud'
#  'Amazon Web Services (AWS),Microsoft Azure,Google Cloud Platform (GCP),IBM Cloud / Red Hat'
#  'Microsoft Azure,Google Cloud Platform (GCP)'
#  'Amazon Web Services (AWS),Microsoft Azure,Oracle Cloud'
#  'Amazon Web Services (AWS),Google Cloud Platform (GCP),VMware Cloud'
#  'VMware Cloud' 'Amazon Web Services (AWS),VMware Cloud'
#  'Amazon Web Services (AWS),Microsoft Azure,Other'
#  'Google Cloud Platform (GCP),IBM Cloud / Red Hat,Oracle Cloud,SAP Cloud,Alibaba Cloud'
#  'Amazon Web Services (AWS),IBM Cloud / Red Hat'
#  'Amazon Web Services (AWS),Microsoft Azure,Google Cloud Platform (GCP),IBM Cloud / Red Hat,Oracle Cloud,Other'
#  'Amazon Web Services (AWS),SAP Cloud'
#  'Amazon Web Services (AWS),Microsoft Azure,IBM Cloud / Red Hat,VMware Cloud'
#  'Amazon Web Services (AWS),Microsoft Azure,Google Cloud Platform (GCP),IBM Cloud / Red Hat,Oracle Cloud'
#  'Amazon Web Services (AWS),Microsoft Azure,Google Cloud Platform (GCP),IBM Cloud / Red Hat,Oracle Cloud,SAP Cloud,VMware Cloud,Alibaba Cloud,Tencent Cloud,Huawei Cloud']
#
#
#
# Cloud_Computing_Products : ['None' 'Amazon Elastic Compute Cloud (EC2)'
#  'Amazon Elastic Compute Cloud (EC2),Microsoft Azure Virtual Machines'
#  'Microsoft Azure Virtual Machines' 'No / None'
#  'Amazon Elastic Compute Cloud (EC2),Google Cloud Compute Engine'
#  'Google Cloud Compute Engine'
#  'Amazon Elastic Compute Cloud (EC2),Microsoft Azure Virtual Machines,Google Cloud Compute Engine'
#  'Microsoft Azure Virtual Machines,Google Cloud Compute Engine'
#  'Amazon Elastic Compute Cloud (EC2),Microsoft Azure Virtual Machines,Google Cloud Compute Engine,Other'
#  'Google Cloud Compute Engine,Other' 'Other'
#  'Amazon Elastic Compute Cloud (EC2),Other'
#  'Microsoft Azure Virtual Machines,Other'
#  'Microsoft Azure Virtual Machines,Google Cloud Compute Engine,Other'
#  'Amazon Elastic Compute Cloud (EC2),Google Cloud Compute Engine,Other']
#
#
#
# Data_Storage_Products : ['None' 'Amazon Simple Storage Service (S3)'
#  'Microsoft Azure Blob Storage,Amazon Simple Storage Service (S3)'
#  'Amazon Simple Storage Service (S3),Google Cloud Storage (GCS)'
#  'Microsoft Azure Blob Storage,Microsoft Azure Files,Amazon Simple Storage Service (S3)'
#  'No / None' 'Microsoft Azure Files,Amazon Simple Storage Service (S3)'
#  'Google Cloud Storage (GCS)'
#  'Amazon Simple Storage Service (S3),Amazon Elastic File System (EFS)'
#  'Google Cloud Storage (GCS),Google Cloud Filestore'
#  'Microsoft Azure Files,Amazon Simple Storage Service (S3),Google Cloud Storage (GCS)'
#  'Microsoft Azure Files'
#  'Microsoft Azure Files,Google Cloud Storage (GCS)'
#  'Microsoft Azure Files,Amazon Simple Storage Service (S3),Amazon Elastic File System (EFS)'
#  'Amazon Simple Storage Service (S3),Google Cloud Filestore'
#  'Microsoft Azure Files,Amazon Simple Storage Service (S3),Amazon Elastic File System (EFS),Google Cloud Filestore'
#  'Google Cloud Filestore'
#  'Amazon Simple Storage Service (S3),Amazon Elastic File System (EFS),Google Cloud Storage (GCS),Google Cloud Filestore'
#  'Microsoft Azure Blob Storage,Google Cloud Storage (GCS)'
#  'Amazon Simple Storage Service (S3),Google Cloud Storage (GCS),Google Cloud Filestore'
#  'Microsoft Azure Blob Storage,Microsoft Azure Files'
#  'Microsoft Azure Blob Storage,Microsoft Azure Files,Amazon Simple Storage Service (S3),Amazon Elastic File System (EFS),Google Cloud Storage (GCS),Google Cloud Filestore'
#  'Microsoft Azure Blob Storage,Amazon Simple Storage Service (S3),Amazon Elastic File System (EFS)'
#  'Microsoft Azure Blob Storage'
#  'Microsoft Azure Files,Amazon Elastic File System (EFS),Google Cloud Storage (GCS)'
#  'Amazon Simple Storage Service (S3),Amazon Elastic File System (EFS),Google Cloud Filestore'
#  'Amazon Elastic File System (EFS)'
#  'Microsoft Azure Blob Storage,Microsoft Azure Files,Google Cloud Filestore'
#  'Microsoft Azure Blob Storage,Google Cloud Storage (GCS),Google Cloud Filestore'
#  'Microsoft Azure Blob Storage,Microsoft Azure Files,Amazon Simple Storage Service (S3),Amazon Elastic File System (EFS)']
#
#
#
# DBMS : ['None' 'MongoDB' 'Snowflake,Amazon Redshift,Amazon RDS'
#  'MySQL,PostgreSQL,Microsoft SQL Server,Microsoft Azure SQL Database,Amazon Redshift'
#  'PostgreSQL,Amazon Redshift'
#  'Microsoft SQL Server,Microsoft Azure SQL Database'
#  'Microsoft SQL Server,Amazon Redshift,Amazon RDS'
#  'MySQL,PostgreSQL,SQLite,Oracle Database' 'MySQL,MongoDB,Snowflake'
#  'MySQL,PostgreSQL' 'PostgreSQL' 'SQLite,Microsoft SQL Server,Amazon RDS'
#  'MySQL,Google Cloud BigQuery'
#  'SQLite,Snowflake,Amazon RDS,Amazon DynamoDB'
#  'SQLite,Oracle Database,IBM Db2,Amazon RDS' 'MySQL,Oracle Database'
#  'SQLite,MongoDB' 'MySQL,Snowflake' 'MySQL,SQLite,Microsoft SQL Server'
#  'SQLite,Microsoft SQL Server,Microsoft Azure SQL Database'
#  'Oracle Database'
#  'MySQL,PostgreSQL,Oracle Database,Microsoft Azure SQL Database'
#  'MongoDB,Snowflake,Microsoft SQL Server'
#  'MySQL,Oracle Database,MongoDB,IBM Db2,Microsoft SQL Server,Amazon DynamoDB'
#  'PostgreSQL,Oracle Database,MongoDB,Microsoft Azure SQL Database,Amazon Redshift'
#  'MySQL' 'MySQL,PostgreSQL,Oracle Database' 'Microsoft SQL Server'
#  'MySQL,MongoDB' 'MySQL,Oracle Database,MongoDB']
#
#
#
# BI_Tools : ['None' 'Microsoft Power BI,Tableau'
#  'Microsoft Power BI,Alteryx,Microsoft Azure Synapse' 'Other' 'Tableau'
#  'Microsoft Power BI,Tableau,Microsoft Azure Synapse'
#  'Amazon QuickSight,Qlik Sense' 'Microsoft Power BI'
#  'Google Data Studio,Microsoft Azure Synapse' 'Google Data Studio,Tableau'
#  'Amazon QuickSight' 'TIBCO Spotfire'
#  'Amazon QuickSight,Microsoft Power BI'
#  'Amazon QuickSight,SAP Analytics Cloud'
#  'Microsoft Power BI,Google Data Studio,Tableau,Qlik Sense'
#  'Google Data Studio,Looker' 'Google Data Studio,SAP Analytics Cloud'
#  'Microsoft Power BI,Google Data Studio,Tableau'
#  'Microsoft Power BI,Tableau,Alteryx'
#  'Microsoft Power BI,Google Data Studio,Tableau,SAP Analytics Cloud'
#  'Domo' 'Microsoft Power BI,Tableau,SAP Analytics Cloud'
#  'Google Data Studio' 'Microsoft Power BI,Tableau,Qlik Sense'
#  'Amazon QuickSight,Microsoft Power BI,Tableau'
#  'Google Data Studio,Qlik Sense' 'Tableau,Sisense' 'Qlik Sense'
#  'Microsoft Power BI,TIBCO Spotfire'
#  'Amazon QuickSight,Microsoft Power BI,Google Data Studio,Looker,Tableau,Domo']
#
#
#
# Managed_ML_Products : ['None' 'No / None' 'Databricks' 'Databricks,Alteryx' 'H2O AI Cloud'
#  'Azure Machine Learning Studio,Databricks' 'Amazon SageMaker' 'Other'
#  'Amazon SageMaker,Google Cloud Vertex AI' 'Databricks,Dataiku'
#  'Domino Data Lab' 'Databricks,H2O AI Cloud'
#  'Azure Machine Learning Studio' 'Rapidminer'
#  'Google Cloud Vertex AI,Dataiku'
#  'Amazon SageMaker,Azure Machine Learning Studio,Google Cloud Vertex AI,Databricks'
#  'Google Cloud Vertex AI,DataRobot' 'Databricks,Dataiku,Alteryx'
#  'Azure Machine Learning Studio,Google Cloud Vertex AI'
#  'Amazon SageMaker,Azure Machine Learning Studio' 'Google Cloud Vertex AI'
#  'Amazon SageMaker,Dataiku'
#  'Amazon SageMaker,Azure Machine Learning Studio,Google Cloud Vertex AI'
#  'Amazon SageMaker,Databricks'
#  'Amazon SageMaker,Azure Machine Learning Studio,Google Cloud Vertex AI,DataRobot,Databricks,Dataiku,Alteryx,Rapidminer,C3.ai,Domino Data Lab,H2O AI Cloud'
#  'Google Cloud Vertex AI,DataRobot,Other'
#  'Amazon SageMaker,Azure Machine Learning Studio,DataRobot'
#  'Amazon SageMaker,Google Cloud Vertex AI,Databricks' 'Alteryx'
#  'DataRobot']
#
#
#
# Auto_ML_Tools : ['None' 'No / None' 'Databricks AutoML' 'Amazon Sagemaker Autopilot'
#  'Google Cloud AutoML'
#  'Databricks AutoML,Azure Automated Machine Learning' 'Other'
#  'Google Cloud AutoML,Databricks AutoML,Amazon Sagemaker Autopilot'
#  'H2O Driverless AI,Databricks AutoML'
#  'Google Cloud AutoML,Databricks AutoML'
#  'Azure Automated Machine Learning'
#  'Google Cloud AutoML,H2O Driverless AI,Azure Automated Machine Learning'
#  'Google Cloud AutoML,Azure Automated Machine Learning'
#  'H2O Driverless AI'
#  'Google Cloud AutoML,H2O Driverless AI,Databricks AutoML,DataRobot AutoML,Amazon Sagemaker Autopilot,Azure Automated Machine Learning'
#  'Google Cloud AutoML,Amazon Sagemaker Autopilot,Azure Automated Machine Learning'
#  'Google Cloud AutoML,Databricks AutoML,DataRobot AutoML,Amazon Sagemaker Autopilot'
#  'Google Cloud AutoML,Amazon Sagemaker Autopilot'
#  'Google Cloud AutoML,DataRobot AutoML,Other'
#  'DataRobot AutoML,Amazon Sagemaker Autopilot' 'Google Cloud AutoML,Other'
#  'DataRobot AutoML'
#  'Google Cloud AutoML,Databricks AutoML,Azure Automated Machine Learning'
#  'Google Cloud AutoML,DataRobot AutoML'
#  'H2O Driverless AI,Azure Automated Machine Learning'
#  'Databricks AutoML,Amazon Sagemaker Autopilot,Azure Automated Machine Learning'
#  'Databricks AutoML,DataRobot AutoML'
#  'Google Cloud AutoML,H2O Driverless AI'
#  'Google Cloud AutoML,Databricks AutoML,Amazon Sagemaker Autopilot,Azure Automated Machine Learning'
#  'Amazon Sagemaker Autopilot,Azure Automated Machine Learning']
#
#
#
# Serve_ML_Models : ['None' 'ONNX Runtime' 'MLflow' 'Other'
#  'TensorFlow Extended (TFX),TorchServe,ONNX Runtime'
#  'TensorFlow Extended (TFX),TorchServe' 'TensorFlow Extended (TFX),MLflow'
#  'TensorFlow Extended (TFX)' 'ONNX Runtime,MLflow'
#  'ONNX Runtime,OpenVINO Model Server'
#  'ONNX Runtime,Triton Inference Server'
#  'ONNX Runtime,Triton Inference Server,Other'
#  'OpenVINO Model Server,MLflow'
#  'TensorFlow Extended (TFX),TorchServe,ONNX Runtime,MLflow'
#  'TensorFlow Extended (TFX),TorchServe,MLflow'
#  'TensorFlow Extended (TFX),TorchServe,ONNX Runtime,OpenVINO Model Server,Multi Model Server (MMS),MLflow'
#  'Triton Inference Server,Seldon Core,MLflow'
#  'TensorFlow Extended (TFX),TorchServe,ONNX Runtime,Triton Inference Server,OpenVINO Model Server,KServe,BentoML,Multi Model Server (MMS),Seldon Core,MLflow'
#  'TensorFlow Extended (TFX),ONNX Runtime,MLflow'
#  'TensorFlow Extended (TFX),TorchServe,Other'
#  'TensorFlow Extended (TFX),TorchServe,Multi Model Server (MMS),Seldon Core'
#  'TensorFlow Extended (TFX),ONNX Runtime,KServe,Multi Model Server (MMS),MLflow'
#  'TorchServe' 'ONNX Runtime,BentoML,MLflow'
#  'ONNX Runtime,OpenVINO Model Server,Other' 'MLflow,Other'
#  'ONNX Runtime,Triton Inference Server,OpenVINO Model Server'
#  'TorchServe,MLflow' 'TorchServe,Multi Model Server (MMS)'
#  'TorchServe,ONNX Runtime']
#
#
#
# ML_Monitering_Tools : ['None' 'Weights & Biases,TensorBoard' 'No / None' 'TensorBoard,MLflow'
#  'MLflow' 'Weights & Biases' 'Other' 'TensorBoard' 'Neptune.ai'
#  'Weights & Biases,MLflow' 'ClearML,MLflow' 'MLflow,DVC' 'Comet.ml,Arize'
#  'DVC' 'Fiddler' 'Weights & Biases,TensorBoard,MLflow,DVC' 'ClearML'
#  'Neptune.ai,MLflow' 'Neptune.ai,Weights & Biases,TensorBoard'
#  'Comet.ml,TensorBoard,ClearML,Aporia'
#  'Neptune.ai,Weights & Biases,Comet.ml,TensorBoard,Guild.ai,ClearML,MLflow,Aporia,Evidently AI,Arize,WhyLabs,Fiddler,DVC'
#  'Neptune.ai,TensorBoard' 'Weights & Biases,TensorBoard,MLflow'
#  'Weights & Biases,MLflow,Fiddler'
#  'Neptune.ai,Weights & Biases,Comet.ml,TensorBoard,ClearML,MLflow,WhyLabs,Fiddler'
#  'Weights & Biases,ClearML,MLflow' 'Weights & Biases,DVC'
#  'Weights & Biases,Comet.ml,TensorBoard,Evidently AI'
#  'TensorBoard,MLflow,Evidently AI,DVC' 'Neptune.ai,TensorBoard,Fiddler']
#
#
#
# Ethical_AI_Products : ['None' 'Audit-AI' 'Other'
#  'Google Responsible AI Toolkit (LIT, What-if, Fairness Indicator, etc)'
#  'Amazon AI Ethics Tools (Clarify, A2I, etc)'
#  'Google Responsible AI Toolkit (LIT, What-if, Fairness Indicator, etc),Microsoft Responsible AI Resources (Fairlearn, Counterfit, InterpretML, etc)'
#  'Microsoft Responsible AI Resources (Fairlearn, Counterfit, InterpretML, etc)'
#  'Google Responsible AI Toolkit (LIT, What-if, Fairness Indicator, etc),IBM AI Ethics tools (AI Fairness 360, Adversarial Robustness Toolbox, etc'
#  'Amazon AI Ethics Tools (Clarify, A2I, etc),Aequitas'
#  'Google Responsible AI Toolkit (LIT, What-if, Fairness Indicator, etc),Microsoft Responsible AI Resources (Fairlearn, Counterfit, InterpretML, etc),IBM AI Ethics tools (AI Fairness 360, Adversarial Robustness Toolbox, etc,Amazon AI Ethics Tools (Clarify, A2I, etc)'
#  'IBM AI Ethics tools (AI Fairness 360, Adversarial Robustness Toolbox, etc'
#  'Aequitas'
#  'Microsoft Responsible AI Resources (Fairlearn, Counterfit, InterpretML, etc),Amazon AI Ethics Tools (Clarify, A2I, etc)'
#  'Google Responsible AI Toolkit (LIT, What-if, Fairness Indicator, etc),IBM AI Ethics tools (AI Fairness 360, Adversarial Robustness Toolbox, etc,Amazon AI Ethics Tools (Clarify, A2I, etc)'
#  'Google Responsible AI Toolkit (LIT, What-if, Fairness Indicator, etc),Microsoft Responsible AI Resources (Fairlearn, Counterfit, InterpretML, etc),Amazon AI Ethics Tools (Clarify, A2I, etc)'
#  'The LinkedIn Fairness Toolkit (LiFT),Aequitas'
#  'Google Responsible AI Toolkit (LIT, What-if, Fairness Indicator, etc),Microsoft Responsible AI Resources (Fairlearn, Counterfit, InterpretML, etc),IBM AI Ethics tools (AI Fairness 360, Adversarial Robustness Toolbox, etc,Amazon AI Ethics Tools (Clarify, A2I, etc),The LinkedIn Fairness Toolkit (LiFT),Audit-AI,Aequitas'
#  'Google Responsible AI Toolkit (LIT, What-if, Fairness Indicator, etc),Microsoft Responsible AI Resources (Fairlearn, Counterfit, InterpretML, etc),Amazon AI Ethics Tools (Clarify, A2I, etc),Audit-AI'
#  'Microsoft Responsible AI Resources (Fairlearn, Counterfit, InterpretML, etc),The LinkedIn Fairness Toolkit (LiFT),Audit-AI'
#  'Google Responsible AI Toolkit (LIT, What-if, Fairness Indicator, etc),Audit-AI'
#  'IBM AI Ethics tools (AI Fairness 360, Adversarial Robustness Toolbox, etc,The LinkedIn Fairness Toolkit (LiFT)'
#  'Microsoft Responsible AI Resources (Fairlearn, Counterfit, InterpretML, etc),Audit-AI'
#  'Google Responsible AI Toolkit (LIT, What-if, Fairness Indicator, etc),Amazon AI Ethics Tools (Clarify, A2I, etc)'
#  'Google Responsible AI Toolkit (LIT, What-if, Fairness Indicator, etc),The LinkedIn Fairness Toolkit (LiFT)'
#  'Google Responsible AI Toolkit (LIT, What-if, Fairness Indicator, etc),Microsoft Responsible AI Resources (Fairlearn, Counterfit, InterpretML, etc),IBM AI Ethics tools (AI Fairness 360, Adversarial Robustness Toolbox, etc,Amazon AI Ethics Tools (Clarify, A2I, etc),The LinkedIn Fairness Toolkit (LiFT)'
#  'Google Responsible AI Toolkit (LIT, What-if, Fairness Indicator, etc),Microsoft Responsible AI Resources (Fairlearn, Counterfit, InterpretML, etc),The LinkedIn Fairness Toolkit (LiFT)'
#  'IBM AI Ethics tools (AI Fairness 360, Adversarial Robustness Toolbox, etc,Amazon AI Ethics Tools (Clarify, A2I, etc)'
#  'IBM AI Ethics tools (AI Fairness 360, Adversarial Robustness Toolbox, etc,Amazon AI Ethics Tools (Clarify, A2I, etc),The LinkedIn Fairness Toolkit (LiFT),Aequitas'
#  'Google Responsible AI Toolkit (LIT, What-if, Fairness Indicator, etc),Microsoft Responsible AI Resources (Fairlearn, Counterfit, InterpretML, etc),IBM AI Ethics tools (AI Fairness 360, Adversarial Robustness Toolbox, etc,The LinkedIn Fairness Toolkit (LiFT)'
#  'The LinkedIn Fairness Toolkit (LiFT)']
#
#
#
# Hardware : ['None' 'GPUs' 'GPUs,TPUs' 'Other' 'Trainium Chips' 'RDUs'
#  'GPUs,TPUs,RDUs' 'TPUs' 'GPUs,TPUs,Trainium Chips,Inferentia Chips'
#  'GPUs,IPUs' 'GPUs,TPUs,Inferentia Chips' 'TPUs,Inferentia Chips'
#  'GPUs,TPUs,IPUs,RDUs,WSEs,Trainium Chips,Inferentia Chips' 'GPUs,Other'
#  'GPUs,RDUs' 'TPUs,WSEs' 'IPUs' 'GPUs,TPUs,Other' 'GPUs,Inferentia Chips'
#  'GPUs,RDUs,Trainium Chips' 'GPUs,IPUs,Trainium Chips,Inferentia Chips'
#  'GPUs,IPUs,RDUs' 'GPUs,Trainium Chips' 'IPUs,Inferentia Chips'
#  'TPUs,IPUs,Inferentia Chips' 'GPUs,RDUs,WSEs' 'TPUs,Trainium Chips'
#  'WSEs' 'Inferentia Chips' 'GPUs,TPUs,IPUs,Trainium Chips']

# %% [markdown]
# ### Men, Women participation ratio

# %%
plt.subplots(figsize=(10, 3))
sns.barplot(
    x = df.Gender.unique(),
    y = df.Gender.value_counts()) \
    .set(xlabel = 'Gender', ylabel = 'Count', title = 'Women, Men participation ratio')
plt.show()

# %% [markdown]
# ### Compared to men, women participation is very less!
#     What could be the reson behind this?

# %% [markdown]
# ### How young the participants are?

# %%
df.Age.value_counts() \
    .sort_index() \
    .plot(
        kind = 'bar',
        color = [(1, .4, 0), (0, .5, 0)],
        figsize = (10, 3),
        title = 'How young the participants are?',
        xlabel = 'Age (in years)',
        ylabel = 'Count')
plt.show()

# %%
df.Country.value_counts()[:10] \
    .plot(
        kind = 'bar',
        color = [(1, .4, 0), (0, .5, 0)],
        figsize = (10, 3),
        title = 'Top 10 countries with most participation.',
        xlabel = 'Country',
        ylabel = 'No. of Participants')
plt.show()

# %% [markdown]
# Its looks like most of the kaggle users are indians.

# %%
df.Hosted_Notebook = df.Hosted_Notebook.apply(lambda x: tuple(x.split(',')))

# %%
df.Hosted_Notebook['Kaggle Notebooks' == df.Hosted_Notebook]
# Out:
# Series([], Name: Hosted_Notebook, dtype: object)
