# %% [markdown]
# # Step 0: Imports and reading the data!

# %% [markdown]
# ### Importing required packages and setting up work environment...!

# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
import seaborn as sns
# plt.style.use('ggplot')
pd.set_option('display.max_columns', 300)
pd.set_option('display.max_rows', 300)

# %% [markdown]
# ### Reading the Data file.

# %%
df = pd.read_csv('kaggle_survey_2022_responses.csv');
# Out:
# C:\Users\Kushagra Chaturvedi\AppData\Local\Temp\ipykernel_15932\3521358420.py:1: DtypeWarning: Columns (0,208,225,255,257,260,270,271,277) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('kaggle_survey_2022_responses.csv');

# %% [markdown]
# # Step 1: Data Understanding
# - DataFrame Shape
# - DataFrame Head, Tail
# - DataFrame Describe
# - dtypes

# %%
df.head(3)
# Out:
#    Duration (in seconds)                           Q2  \
# 0  Duration (in seconds)  What is your age (# years)?
# 1                    121                        30-34
# 2                    462                        30-34
#
#                                        Q3  \
# 0  What is your gender? - Selected Choice
# 1                                     Man
# 2                                     Man
#
#                                           Q4  \
# 0  In which country do you currently reside?
# 1                                      India
# 2                                    Algeria
#
#                                                   Q5  \
# 0  Are you currently a student? (high school, uni...
# 1                                                 No
# 2                                                 No
#
#                                                 Q6_1  \
# 0  On which platforms have you begun or completed...
# 1                                                NaN
# 2                                                NaN
#
#                                                 Q6_2  \
# 0  On which platforms have you begun or completed...
# 1                                                NaN
# 2                                                NaN
#
#                                                 Q6_3  \
# 0  On which platforms have you begun or completed...
# 1                                                NaN
# 2                                                NaN
#
#                                                 Q6_4  \
# 0  On which platforms have you begun or completed...
# 1                                                NaN
# 2                                                NaN
#
#                                                 Q6_5  \
# 0  On which platforms have you begun or completed...
# 1                                                NaN
# 2                                                NaN
#
#                                                 Q6_6  \
# 0  On which platforms have you begun or completed...
# 1                                                NaN
# 2                                                NaN
#
#                                                 Q6_7  \
# 0  On which platforms have you begun or completed...
# 1                                                NaN
# 2                                                NaN
#
#                                                 Q6_8  \
# 0  On which platforms have you begun or completed...
# 1                                                NaN
# 2                                                NaN
#
#                                                 Q6_9  \
# 0  On which platforms have you begun or completed...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q6_10  \
# 0  On which platforms have you begun or completed...
# 1                                                NaN
# 2  University Courses (resulting in a university ...
#
#                                                Q6_11  \
# 0  On which platforms have you begun or completed...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q6_12  \
# 0  On which platforms have you begun or completed...
# 1                                              Other
# 2                                                NaN
#
#                                                 Q7_1  \
# 0  What products or platforms did you find to be ...
# 1                                                NaN
# 2                                 University courses
#
#                                                 Q7_2  \
# 0  What products or platforms did you find to be ...
# 1                                                NaN
# 2                                                NaN
#
#                                                 Q7_3  \
# 0  What products or platforms did you find to be ...
# 1                                                NaN
# 2                                                NaN
#
#                                                 Q7_4  \
# 0  What products or platforms did you find to be ...
# 1                                                NaN
# 2                                                NaN
#
#                                                 Q7_5  \
# 0  What products or platforms did you find to be ...
# 1                                                NaN
# 2              Kaggle (notebooks, competitions, etc)
#
#                                                 Q7_6  \
# 0  What products or platforms did you find to be ...
# 1                                                NaN
# 2                                                NaN
#
#                                                 Q7_7  \
# 0  What products or platforms did you find to be ...
# 1                                                NaN
# 2                                                NaN
#
#                                                   Q8  \
# 0  What is the highest level of formal education ...
# 1                                                NaN
# 2                                    Master’s degree
#
#                                                   Q9  \
# 0  Have you ever published any academic research ...
# 1                                                NaN
# 2                                                Yes
#
#                                                Q10_1  \
# 0  Did your research make use of machine learning...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q10_2  \
# 0  Did your research make use of machine learning...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q10_3  \
# 0  Did your research make use of machine learning...
# 1                                                NaN
# 2                                                 No
#
#                                                  Q11  \
# 0  For how many years have you been writing code ...
# 1                                                NaN
# 2                                          1-3 years
#
#                                                Q12_1  \
# 0  What programming languages do you use on a reg...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q12_2  \
# 0  What programming languages do you use on a reg...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q12_3  \
# 0  What programming languages do you use on a reg...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q12_4  \
# 0  What programming languages do you use on a reg...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q12_5  \
# 0  What programming languages do you use on a reg...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q12_6  \
# 0  What programming languages do you use on a reg...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q12_7  \
# 0  What programming languages do you use on a reg...
# 1                                                NaN
# 2                                               Java
#
#                                                Q12_8  \
# 0  What programming languages do you use on a reg...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q12_9  \
# 0  What programming languages do you use on a reg...
# 1                                                NaN
# 2                                                NaN
#
#                                               Q12_10  \
# 0  What programming languages do you use on a reg...
# 1                                                NaN
# 2                                                NaN
#
#                                               Q12_11  \
# 0  What programming languages do you use on a reg...
# 1                                                NaN
# 2                                                NaN
#
#                                               Q12_12  \
# 0  What programming languages do you use on a reg...
# 1                                                NaN
# 2                                                NaN
#
#                                               Q12_13  \
# 0  What programming languages do you use on a reg...
# 1                                                NaN
# 2                                                NaN
#
#                                               Q12_14  \
# 0  What programming languages do you use on a reg...
# 1                                                NaN
# 2                                                NaN
#
#                                               Q12_15  \
# 0  What programming languages do you use on a reg...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q13_1  \
# 0  Which of the following integrated development ...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q13_2  \
# 0  Which of the following integrated development ...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q13_3  \
# 0  Which of the following integrated development ...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q13_4  \
# 0  Which of the following integrated development ...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q13_5  \
# 0  Which of the following integrated development ...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q13_6  \
# 0  Which of the following integrated development ...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q13_7  \
# 0  Which of the following integrated development ...
# 1                                                NaN
# 2                                        Notepad++
#
#                                                Q13_8  \
# 0  Which of the following integrated development ...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q13_9  \
# 0  Which of the following integrated development ...
# 1                                                NaN
# 2                                                NaN
#
#                                               Q13_10  \
# 0  Which of the following integrated development ...
# 1                                                NaN
# 2                                                NaN
#
#                                               Q13_11  \
# 0  Which of the following integrated development ...
# 1                                                NaN
# 2                                                NaN
#
#                                               Q13_12  \
# 0  Which of the following integrated development ...
# 1                                                NaN
# 2                                                NaN
#
#                                               Q13_13  \
# 0  Which of the following integrated development ...
# 1                                                NaN
# 2                                                NaN
#
#                                               Q13_14  \
# 0  Which of the following integrated development ...
# 1                                                NaN
# 2                                              Other
#
#                                                Q14_1  \
# 0  Do you use any of the following hosted noteboo...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q14_2  \
# 0  Do you use any of the following hosted noteboo...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q14_3  \
# 0  Do you use any of the following hosted noteboo...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q14_4  \
# 0  Do you use any of the following hosted noteboo...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q14_5  \
# 0  Do you use any of the following hosted noteboo...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q14_6  \
# 0  Do you use any of the following hosted noteboo...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q14_7  \
# 0  Do you use any of the following hosted noteboo...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q14_8  \
# 0  Do you use any of the following hosted noteboo...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q14_9  \
# 0  Do you use any of the following hosted noteboo...
# 1                                                NaN
# 2                                                NaN
#
#                                               Q14_10  \
# 0  Do you use any of the following hosted noteboo...
# 1                                                NaN
# 2                                                NaN
#
#                                               Q14_11  \
# 0  Do you use any of the following hosted noteboo...
# 1                                                NaN
# 2                                                NaN
#
#                                               Q14_12  \
# 0  Do you use any of the following hosted noteboo...
# 1                                                NaN
# 2                                                NaN
#
#                                               Q14_13  \
# 0  Do you use any of the following hosted noteboo...
# 1                                                NaN
# 2                                                NaN
#
#                                               Q14_14  \
# 0  Do you use any of the following hosted noteboo...
# 1                                                NaN
# 2                                                NaN
#
#                                               Q14_15  \
# 0  Do you use any of the following hosted noteboo...
# 1                                                NaN
# 2                                               None
#
#                                               Q14_16  \
# 0  Do you use any of the following hosted noteboo...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q15_1  \
# 0  Do you use any of the following data visualiza...
# 1                                                NaN
# 2                                        Matplotlib
#
#                                                Q15_2  \
# 0  Do you use any of the following data visualiza...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q15_3  \
# 0  Do you use any of the following data visualiza...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q15_4  \
# 0  Do you use any of the following data visualiza...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q15_5  \
# 0  Do you use any of the following data visualiza...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q15_6  \
# 0  Do you use any of the following data visualiza...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q15_7  \
# 0  Do you use any of the following data visualiza...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q15_8  \
# 0  Do you use any of the following data visualiza...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q15_9  \
# 0  Do you use any of the following data visualiza...
# 1                                                NaN
# 2                                                NaN
#
#                                               Q15_10  \
# 0  Do you use any of the following data visualiza...
# 1                                                NaN
# 2                                                NaN
#
#                                               Q15_11  \
# 0  Do you use any of the following data visualiza...
# 1                                                NaN
# 2                                                NaN
#
#                                               Q15_12  \
# 0  Do you use any of the following data visualiza...
# 1                                                NaN
# 2                                                NaN
#
#                                               Q15_13  \
# 0  Do you use any of the following data visualiza...
# 1                                                NaN
# 2                                                NaN
#
#                                               Q15_14  \
# 0  Do you use any of the following data visualiza...
# 1                                                NaN
# 2                                                NaN
#
#                                               Q15_15  \
# 0  Do you use any of the following data visualiza...
# 1                                                NaN
# 2                                                NaN
#
#                                                  Q16  \
# 0  For how many years have you used machine learn...
# 1                                                NaN
# 2                                       Under 1 year
#
#                                                Q17_1  \
# 0  Which of the following machine learning framew...
# 1                                                NaN
# 2                                      Scikit-learn
#
#                                                Q17_2  \
# 0  Which of the following machine learning framew...
# 1                                                NaN
# 2                                        TensorFlow
#
#                                                Q17_3  \
# 0  Which of the following machine learning framew...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q17_4  \
# 0  Which of the following machine learning framew...
# 1                                                NaN
# 2                                           PyTorch
#
#                                                Q17_5  \
# 0  Which of the following machine learning framew...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q17_6  \
# 0  Which of the following machine learning framew...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q17_7  \
# 0  Which of the following machine learning framew...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q17_8  \
# 0  Which of the following machine learning framew...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q17_9  \
# 0  Which of the following machine learning framew...
# 1                                                NaN
# 2                                                NaN
#
#                                               Q17_10  \
# 0  Which of the following machine learning framew...
# 1                                                NaN
# 2                                                NaN
#
#                                               Q17_11  \
# 0  Which of the following machine learning framew...
# 1                                                NaN
# 2                                                NaN
#
#                                               Q17_12  \
# 0  Which of the following machine learning framew...
# 1                                                NaN
# 2                                                NaN
#
#                                               Q17_13  \
# 0  Which of the following machine learning framew...
# 1                                                NaN
# 2                                                NaN
#
#                                               Q17_14  \
# 0  Which of the following machine learning framew...
# 1                                                NaN
# 2                                                NaN
#
#                                               Q17_15  \
# 0  Which of the following machine learning framew...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q18_1  \
# 0  Which of the following ML algorithms do you us...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q18_2  \
# 0  Which of the following ML algorithms do you us...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q18_3  \
# 0  Which of the following ML algorithms do you us...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q18_4  \
# 0  Which of the following ML algorithms do you us...
# 1                                                NaN
# 2                                Bayesian Approaches
#
#                                                Q18_5  \
# 0  Which of the following ML algorithms do you us...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q18_6  \
# 0  Which of the following ML algorithms do you us...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q18_7  \
# 0  Which of the following ML algorithms do you us...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q18_8  \
# 0  Which of the following ML algorithms do you us...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q18_9  \
# 0  Which of the following ML algorithms do you us...
# 1                                                NaN
# 2                                                NaN
#
#                                               Q18_10  \
# 0  Which of the following ML algorithms do you us...
# 1                                                NaN
# 2                                                NaN
#
#                                               Q18_11  \
# 0  Which of the following ML algorithms do you us...
# 1                                                NaN
# 2                                                NaN
#
#                                               Q18_12  \
# 0  Which of the following ML algorithms do you us...
# 1                                                NaN
# 2                                                NaN
#
#                                               Q18_13  \
# 0  Which of the following ML algorithms do you us...
# 1                                                NaN
# 2                                                NaN
#
#                                               Q18_14  \
# 0  Which of the following ML algorithms do you us...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q19_1  \
# 0  Which categories of computer vision methods do...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q19_2  \
# 0  Which categories of computer vision methods do...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q19_3  \
# 0  Which categories of computer vision methods do...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q19_4  \
# 0  Which categories of computer vision methods do...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q19_5  \
# 0  Which categories of computer vision methods do...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q19_6  \
# 0  Which categories of computer vision methods do...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q19_7  \
# 0  Which categories of computer vision methods do...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q19_8  \
# 0  Which categories of computer vision methods do...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q20_1  \
# 0  Which of the following natural language proces...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q20_2  \
# 0  Which of the following natural language proces...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q20_3  \
# 0  Which of the following natural language proces...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q20_4  \
# 0  Which of the following natural language proces...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q20_5  \
# 0  Which of the following natural language proces...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q20_6  \
# 0  Which of the following natural language proces...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q21_1  \
# 0  Do you download pre-trained model weights from...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q21_2  \
# 0  Do you download pre-trained model weights from...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q21_3  \
# 0  Do you download pre-trained model weights from...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q21_4  \
# 0  Do you download pre-trained model weights from...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q21_5  \
# 0  Do you download pre-trained model weights from...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q21_6  \
# 0  Do you download pre-trained model weights from...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q21_7  \
# 0  Do you download pre-trained model weights from...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q21_8  \
# 0  Do you download pre-trained model weights from...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q21_9  \
# 0  Do you download pre-trained model weights from...
# 1                                                NaN
# 2  No, I do not download pre-trained model weight...
#
#                                               Q21_10  \
# 0  Do you download pre-trained model weights from...
# 1                                                NaN
# 2                                                NaN
#
#                                                  Q22  \
# 0  Which of the following ML model hubs/repositor...
# 1                                                NaN
# 2                                                NaN
#
#                                                  Q23  \
# 0  Select the title most similar to your current ...
# 1                                                NaN
# 2                                                NaN
#
#                                                  Q24  \
# 0  In what industry is your current employer/cont...
# 1                                                NaN
# 2                                                NaN
#
#                                                  Q25  \
# 0  What is the size of the company where you are ...
# 1                                                NaN
# 2                                                NaN
#
#                                                  Q26  \
# 0  Approximately how many individuals are respons...
# 1                                                NaN
# 2                                                NaN
#
#                                                  Q27  \
# 0  Does your current employer incorporate machine...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q28_1  \
# 0  Select any activities that make up an importan...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q28_2  \
# 0  Select any activities that make up an importan...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q28_3  \
# 0  Select any activities that make up an importan...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q28_4  \
# 0  Select any activities that make up an importan...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q28_5  \
# 0  Select any activities that make up an importan...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q28_6  \
# 0  Select any activities that make up an importan...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q28_7  \
# 0  Select any activities that make up an importan...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q28_8  \
# 0  Select any activities that make up an importan...
# 1                                                NaN
# 2                                                NaN
#
#                                                  Q29  \
# 0  What is your current yearly compensation (appr...
# 1                                                NaN
# 2                                                NaN
#
#                                                  Q30  \
# 0  Approximately how much money have you spent on...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q31_1  \
# 0  Which of the following cloud computing platfor...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q31_2  \
# 0  Which of the following cloud computing platfor...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q31_3  \
# 0  Which of the following cloud computing platfor...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q31_4  \
# 0  Which of the following cloud computing platfor...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q31_5  \
# 0  Which of the following cloud computing platfor...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q31_6  \
# 0  Which of the following cloud computing platfor...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q31_7  \
# 0  Which of the following cloud computing platfor...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q31_8  \
# 0  Which of the following cloud computing platfor...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q31_9  \
# 0  Which of the following cloud computing platfor...
# 1                                                NaN
# 2                                                NaN
#
#                                               Q31_10  \
# 0  Which of the following cloud computing platfor...
# 1                                                NaN
# 2                                                NaN
#
#                                               Q31_11  \
# 0  Which of the following cloud computing platfor...
# 1                                                NaN
# 2                                                NaN
#
#                                               Q31_12  \
# 0  Which of the following cloud computing platfor...
# 1                                                NaN
# 2                                                NaN
#
#                                                  Q32  \
# 0  Of the cloud platforms that you are familiar w...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q33_1  \
# 0  Do you use any of the following cloud computin...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q33_2  \
# 0  Do you use any of the following cloud computin...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q33_3  \
# 0  Do you use any of the following cloud computin...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q33_4  \
# 0  Do you use any of the following cloud computin...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q33_5  \
# 0  Do you use any of the following cloud computin...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q34_1  \
# 0  Do you use any of the following data storage p...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q34_2  \
# 0  Do you use any of the following data storage p...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q34_3  \
# 0  Do you use any of the following data storage p...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q34_4  \
# 0  Do you use any of the following data storage p...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q34_5  \
# 0  Do you use any of the following data storage p...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q34_6  \
# 0  Do you use any of the following data storage p...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q34_7  \
# 0  Do you use any of the following data storage p...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q34_8  \
# 0  Do you use any of the following data storage p...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q35_1  \
# 0  Do you use any of the following data products ...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q35_2  \
# 0  Do you use any of the following data products ...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q35_3  \
# 0  Do you use any of the following data products ...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q35_4  \
# 0  Do you use any of the following data products ...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q35_5  \
# 0  Do you use any of the following data products ...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q35_6  \
# 0  Do you use any of the following data products ...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q35_7  \
# 0  Do you use any of the following data products ...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q35_8  \
# 0  Do you use any of the following data products ...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q35_9  \
# 0  Do you use any of the following data products ...
# 1                                                NaN
# 2                                                NaN
#
#                                               Q35_10  \
# 0  Do you use any of the following data products ...
# 1                                                NaN
# 2                                                NaN
#
#                                               Q35_11  \
# 0  Do you use any of the following data products ...
# 1                                                NaN
# 2                                                NaN
#
#                                               Q35_12  \
# 0  Do you use any of the following data products ...
# 1                                                NaN
# 2                                                NaN
#
#                                               Q35_13  \
# 0  Do you use any of the following data products ...
# 1                                                NaN
# 2                                                NaN
#
#                                               Q35_14  \
# 0  Do you use any of the following data products ...
# 1                                                NaN
# 2                                                NaN
#
#                                               Q35_15  \
# 0  Do you use any of the following data products ...
# 1                                                NaN
# 2                                                NaN
#
#                                               Q35_16  \
# 0  Do you use any of the following data products ...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q36_1  \
# 0  Do you use any of the following business intel...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q36_2  \
# 0  Do you use any of the following business intel...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q36_3  \
# 0  Do you use any of the following business intel...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q36_4  \
# 0  Do you use any of the following business intel...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q36_5  \
# 0  Do you use any of the following business intel...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q36_6  \
# 0  Do you use any of the following business intel...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q36_7  \
# 0  Do you use any of the following business intel...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q36_8  \
# 0  Do you use any of the following business intel...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q36_9  \
# 0  Do you use any of the following business intel...
# 1                                                NaN
# 2                                                NaN
#
#                                               Q36_10  \
# 0  Do you use any of the following business intel...
# 1                                                NaN
# 2                                                NaN
#
#                                               Q36_11  \
# 0  Do you use any of the following business intel...
# 1                                                NaN
# 2                                                NaN
#
#                                               Q36_12  \
# 0  Do you use any of the following business intel...
# 1                                                NaN
# 2                                                NaN
#
#                                               Q36_13  \
# 0  Do you use any of the following business intel...
# ...
#
#                                                Q37_9  \
# 0  Do you use any of the following managed machin...
# 1                                                NaN
# 2                                                NaN
#
#                                               Q37_10  \
# 0  Do you use any of the following managed machin...
# 1                                                NaN
# 2                                                NaN
#
#                                               Q37_11  \
# 0  Do you use any of the following managed machin...
# 1                                                NaN
# 2                                                NaN
#
#                                               Q37_12  \
# 0  Do you use any of the following managed machin...
# 1                                                NaN
# 2                                                NaN
#
#                                               Q37_13  \
# 0  Do you use any of the following managed machin...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q38_1  \
# 0  Do you use any of the following automated mach...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q38_2  \
# 0  Do you use any of the following automated mach...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q38_3  \
# 0  Do you use any of the following automated mach...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q38_4  \
# 0  Do you use any of the following automated mach...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q38_5  \
# 0  Do you use any of the following automated mach...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q38_6  \
# 0  Do you use any of the following automated mach...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q38_7  \
# 0  Do you use any of the following automated mach...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q38_8  \
# 0  Do you use any of the following automated mach...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q39_1  \
# 0  Do you use any of the following products to se...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q39_2  \
# 0  Do you use any of the following products to se...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q39_3  \
# 0  Do you use any of the following products to se...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q39_4  \
# 0  Do you use any of the following products to se...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q39_5  \
# 0  Do you use any of the following products to se...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q39_6  \
# 0  Do you use any of the following products to se...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q39_7  \
# 0  Do you use any of the following products to se...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q39_8  \
# 0  Do you use any of the following products to se...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q39_9  \
# 0  Do you use any of the following products to se...
# 1                                                NaN
# 2                                                NaN
#
#                                               Q39_10  \
# 0  Do you use any of the following products to se...
# 1                                                NaN
# 2                                                NaN
#
#                                               Q39_11  \
# 0  Do you use any of the following products to se...
# 1                                                NaN
# 2                                                NaN
#
#                                               Q39_12  \
# 0  Do you use any of the following products to se...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q40_1  \
# 0  Do you use any tools to help monitor your mach...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q40_2  \
# 0  Do you use any tools to help monitor your mach...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q40_3  \
# 0  Do you use any tools to help monitor your mach...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q40_4  \
# 0  Do you use any tools to help monitor your mach...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q40_5  \
# 0  Do you use any tools to help monitor your mach...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q40_6  \
# 0  Do you use any tools to help monitor your mach...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q40_7  \
# 0  Do you use any tools to help monitor your mach...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q40_8  \
# 0  Do you use any tools to help monitor your mach...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q40_9  \
# 0  Do you use any tools to help monitor your mach...
# 1                                                NaN
# 2                                                NaN
#
#                                               Q40_10  \
# 0  Do you use any tools to help monitor your mach...
# 1                                                NaN
# 2                                                NaN
#
#                                               Q40_11  \
# 0  Do you use any tools to help monitor your mach...
# 1                                                NaN
# 2                                                NaN
#
#                                               Q40_12  \
# 0  Do you use any tools to help monitor your mach...
# 1                                                NaN
# 2                                                NaN
#
#                                               Q40_13  \
# 0  Do you use any tools to help monitor your mach...
# 1                                                NaN
# 2                                                NaN
#
#                                               Q40_14  \
# 0  Do you use any tools to help monitor your mach...
# 1                                                NaN
# 2                                                NaN
#
#                                               Q40_15  \
# 0  Do you use any tools to help monitor your mach...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q41_1  \
# 0  Do you use any of the following responsible or...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q41_2  \
# 0  Do you use any of the following responsible or...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q41_3  \
# 0  Do you use any of the following responsible or...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q41_4  \
# 0  Do you use any of the following responsible or...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q41_5  \
# 0  Do you use any of the following responsible or...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q41_6  \
# 0  Do you use any of the following responsible or...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q41_7  \
# 0  Do you use any of the following responsible or...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q41_8  \
# 0  Do you use any of the following responsible or...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q41_9  \
# 0  Do you use any of the following responsible or...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q42_1  \
# 0  Do you use any of the following types of speci...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q42_2  \
# 0  Do you use any of the following types of speci...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q42_3  \
# 0  Do you use any of the following types of speci...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q42_4  \
# 0  Do you use any of the following types of speci...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q42_5  \
# 0  Do you use any of the following types of speci...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q42_6  \
# 0  Do you use any of the following types of speci...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q42_7  \
# 0  Do you use any of the following types of speci...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q42_8  \
# 0  Do you use any of the following types of speci...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q42_9  \
# 0  Do you use any of the following types of speci...
# 1                                                NaN
# 2                                                NaN
#
#                                                  Q43  \
# 0  Approximately how many times have you used a T...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q44_1  \
# 0  Who/what are your favorite media sources that ...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q44_2  \
# 0  Who/what are your favorite media sources that ...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q44_3  \
# 0  Who/what are your favorite media sources that ...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q44_4  \
# 0  Who/what are your favorite media sources that ...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q44_5  \
# 0  Who/what are your favorite media sources that ...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q44_6  \
# 0  Who/what are your favorite media sources that ...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q44_7  \
# 0  Who/what are your favorite media sources that ...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q44_8  \
# 0  Who/what are your favorite media sources that ...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q44_9  \
# 0  Who/what are your favorite media sources that ...
# 1                                                NaN
# 2                                                NaN
#
#                                               Q44_10  \
# 0  Who/what are your favorite media sources that ...
# 1                                                NaN
# 2                                                NaN
#
#                                               Q44_11  \
# 0  Who/what are your favorite media sources that ...
# 1                                                NaN
# 2                                                NaN
#
#                                               Q44_12
# 0  Who/what are your favorite media sources that ...
# 1                                                NaN
# 2                                                NaN

# %%
df.shape
# Out:
# (23998, 296)

# %%
df.dtypes
# Out:
# Duration (in seconds)    object
# Q2                       object
# Q3                       object
# Q4                       object
# Q5                       object
# Q6_1                     object
# Q6_2                     object
# Q6_3                     object
# Q6_4                     object
# Q6_5                     object
# Q6_6                     object
# Q6_7                     object
# Q6_8                     object
# Q6_9                     object
# Q6_10                    object
# Q6_11                    object
# Q6_12                    object
# Q7_1                     object
# Q7_2                     object
# Q7_3                     object
# Q7_4                     object
# Q7_5                     object
# Q7_6                     object
# Q7_7                     object
# Q8                       object
# Q9                       object
# Q10_1                    object
# Q10_2                    object
# Q10_3                    object
# Q11                      object
# Q12_1                    object
# Q12_2                    object
# Q12_3                    object
# Q12_4                    object
# Q12_5                    object
# Q12_6                    object
# Q12_7                    object
# Q12_8                    object
# Q12_9                    object
# Q12_10                   object
# Q12_11                   object
# Q12_12                   object
# Q12_13                   object
# Q12_14                   object
# Q12_15                   object
# Q13_1                    object
# Q13_2                    object
# Q13_3                    object
# Q13_4                    object
# Q13_5                    object
# Q13_6                    object
# Q13_7                    object
# Q13_8                    object
# Q13_9                    object
# Q13_10                   object
# Q13_11                   object
# Q13_12                   object
# Q13_13                   object
# Q13_14                   object
# Q14_1                    object
# Q14_2                    object
# Q14_3                    object
# Q14_4                    object
# Q14_5                    object
# Q14_6                    object
# Q14_7                    object
# Q14_8                    object
# Q14_9                    object
# Q14_10                   object
# Q14_11                   object
# Q14_12                   object
# Q14_13                   object
# Q14_14                   object
# Q14_15                   object
# Q14_16                   object
# Q15_1                    object
# Q15_2                    object
# Q15_3                    object
# Q15_4                    object
# Q15_5                    object
# Q15_6                    object
# Q15_7                    object
# Q15_8                    object
# Q15_9                    object
# Q15_10                   object
# Q15_11                   object
# Q15_12                   object
# Q15_13                   object
# Q15_14                   object
# Q15_15                   object
# Q16                      object
# Q17_1                    object
# Q17_2                    object
# Q17_3                    object
# Q17_4                    object
# Q17_5                    object
# Q17_6                    object
# Q17_7                    object
# Q17_8                    object
# Q17_9                    object
# Q17_10                   object
# Q17_11                   object
# Q17_12                   object
# Q17_13                   object
# Q17_14                   object
# Q17_15                   object
# Q18_1                    object
# Q18_2                    object
# Q18_3                    object
# Q18_4                    object
# Q18_5                    object
# Q18_6                    object
# Q18_7                    object
# Q18_8                    object
# Q18_9                    object
# Q18_10                   object
# Q18_11                   object
# Q18_12                   object
# Q18_13                   object
# Q18_14                   object
# Q19_1                    object
# Q19_2                    object
# Q19_3                    object
# Q19_4                    object
# Q19_5                    object
# Q19_6                    object
# Q19_7                    object
# Q19_8                    object
# Q20_1                    object
# Q20_2                    object
# Q20_3                    object
# Q20_4                    object
# Q20_5                    object
# Q20_6                    object
# Q21_1                    object
# Q21_2                    object
# Q21_3                    object
# Q21_4                    object
# Q21_5                    object
# Q21_6                    object
# Q21_7                    object
# Q21_8                    object
# Q21_9                    object
# Q21_10                   object
# Q22                      object
# Q23                      object
# Q24                      object
# Q25                      object
# Q26                      object
# Q27                      object
# Q28_1                    object
# Q28_2                    object
# Q28_3                    object
# Q28_4                    object
# Q28_5                    object
# Q28_6                    object
# Q28_7                    object
# Q28_8                    object
# Q29                      object
# Q30                      object
# Q31_1                    object
# Q31_2                    object
# Q31_3                    object
# Q31_4                    object
# Q31_5                    object
# Q31_6                    object
# Q31_7                    object
# Q31_8                    object
# Q31_9                    object
# Q31_10                   object
# Q31_11                   object
# Q31_12                   object
# Q32                      object
# Q33_1                    object
# Q33_2                    object
# Q33_3                    object
# Q33_4                    object
# Q33_5                    object
# Q34_1                    object
# Q34_2                    object
# Q34_3                    object
# Q34_4                    object
# Q34_5                    object
# Q34_6                    object
# Q34_7                    object
# Q34_8                    object
# Q35_1                    object
# Q35_2                    object
# Q35_3                    object
# Q35_4                    object
# Q35_5                    object
# Q35_6                    object
# Q35_7                    object
# Q35_8                    object
# Q35_9                    object
# Q35_10                   object
# Q35_11                   object
# Q35_12                   object
# Q35_13                   object
# Q35_14                   object
# Q35_15                   object
# Q35_16                   object
# Q36_1                    object
# Q36_2                    object
# Q36_3                    object
# Q36_4                    object
# Q36_5                    object
# Q36_6                    object
# Q36_7                    object
# Q36_8                    object
# Q36_9                    object
# Q36_10                   object
# Q36_11                   object
# Q36_12                   object
# Q36_13                   object
# Q36_14                   object
# Q36_15                   object
# Q37_1                    object
# Q37_2                    object
# Q37_3                    object
# Q37_4                    object
# Q37_5                    object
# Q37_6                    object
# Q37_7                    object
# Q37_8                    object
# Q37_9                    object
# Q37_10                   object
# Q37_11                   object
# Q37_12                   object
# Q37_13                   object
# Q38_1                    object
# Q38_2                    object
# Q38_3                    object
# Q38_4                    object
# Q38_5                    object
# Q38_6                    object
# Q38_7                    object
# Q38_8                    object
# Q39_1                    object
# Q39_2                    object
# Q39_3                    object
# Q39_4                    object
# Q39_5                    object
# Q39_6                    object
# Q39_7                    object
# Q39_8                    object
# Q39_9                    object
# Q39_10                   object
# Q39_11                   object
# Q39_12                   object
# Q40_1                    object
# Q40_2                    object
# Q40_3                    object
# Q40_4                    object
# Q40_5                    object
# Q40_6                    object
# Q40_7                    object
# Q40_8                    object
# Q40_9                    object
# Q40_10                   object
# Q40_11                   object
# Q40_12                   object
# Q40_13                   object
# Q40_14                   object
# Q40_15                   object
# Q41_1                    object
# Q41_2                    object
# Q41_3                    object
# Q41_4                    object
# Q41_5                    object
# Q41_6                    object
# Q41_7                    object
# Q41_8                    object
# Q41_9                    object
# Q42_1                    object
# Q42_2                    object
# Q42_3                    object
# Q42_4                    object
# Q42_5                    object
# Q42_6                    object
# Q42_7                    object
# Q42_8                    object
# Q42_9                    object
# Q43                      object
# Q44_1                    object
# Q44_2                    object
# Q44_3                    object
# Q44_4                    object
# Q44_5                    object
# Q44_6                    object
# Q44_7                    object
# Q44_8                    object
# Q44_9                    object
# Q44_10                   object
# Q44_11                   object
# Q44_12                   object
# dtype: object

# %% [markdown]
# # Step 2: Data Preperation
# - Dropping irrelevant columns and rows
# - identifying duplicated columns and rows
# - Renaming Columns
# - Feature Cration (New columns creation)

# %%
list(df.columns)
# Out:
# ['Duration (in seconds)',
#  'Q2',
#  'Q3',
#  'Q4',
#  'Q5',
#  'Q6_1',
#  'Q6_2',
#  'Q6_3',
#  'Q6_4',
#  'Q6_5',
#  'Q6_6',
#  'Q6_7',
#  'Q6_8',
#  'Q6_9',
#  'Q6_10',
#  'Q6_11',
#  'Q6_12',
#  'Q7_1',
#  'Q7_2',
#  'Q7_3',
#  'Q7_4',
#  'Q7_5',
#  'Q7_6',
#  'Q7_7',
#  'Q8',
#  'Q9',
#  'Q10_1',
#  'Q10_2',
#  'Q10_3',
#  'Q11',
#  'Q12_1',
#  'Q12_2',
#  'Q12_3',
#  'Q12_4',
#  'Q12_5',
#  'Q12_6',
#  'Q12_7',
#  'Q12_8',
#  'Q12_9',
#  'Q12_10',
#  'Q12_11',
#  'Q12_12',
#  'Q12_13',
#  'Q12_14',
#  'Q12_15',
#  'Q13_1',
#  'Q13_2',
#  'Q13_3',
#  'Q13_4',
#  'Q13_5',
#  'Q13_6',
#  'Q13_7',
#  'Q13_8',
#  'Q13_9',
#  'Q13_10',
#  'Q13_11',
#  'Q13_12',
#  'Q13_13',
#  'Q13_14',
#  'Q14_1',
#  'Q14_2',
#  'Q14_3',
#  'Q14_4',
#  'Q14_5',
#  'Q14_6',
#  'Q14_7',
#  'Q14_8',
#  'Q14_9',
#  'Q14_10',
#  'Q14_11',
#  'Q14_12',
#  'Q14_13',
#  'Q14_14',
#  'Q14_15',
#  'Q14_16',
#  'Q15_1',
#  'Q15_2',
#  'Q15_3',
#  'Q15_4',
#  'Q15_5',
#  'Q15_6',
#  'Q15_7',
#  'Q15_8',
#  'Q15_9',
#  'Q15_10',
#  'Q15_11',
#  'Q15_12',
#  'Q15_13',
#  'Q15_14',
#  'Q15_15',
#  'Q16',
#  'Q17_1',
#  'Q17_2',
#  'Q17_3',
#  'Q17_4',
#  'Q17_5',
#  'Q17_6',
#  'Q17_7',
#  'Q17_8',
#  'Q17_9',
#  'Q17_10',
#  'Q17_11',
#  'Q17_12',
#  'Q17_13',
#  'Q17_14',
#  'Q17_15',
#  'Q18_1',
#  'Q18_2',
#  'Q18_3',
#  'Q18_4',
#  'Q18_5',
#  'Q18_6',
#  'Q18_7',
#  'Q18_8',
#  'Q18_9',
#  'Q18_10',
#  'Q18_11',
#  'Q18_12',
#  'Q18_13',
#  'Q18_14',
#  'Q19_1',
#  'Q19_2',
#  'Q19_3',
#  'Q19_4',
#  'Q19_5',
#  'Q19_6',
#  'Q19_7',
#  'Q19_8',
#  'Q20_1',
#  'Q20_2',
#  'Q20_3',
#  'Q20_4',
#  'Q20_5',
#  'Q20_6',
#  'Q21_1',
#  'Q21_2',
#  'Q21_3',
#  'Q21_4',
#  'Q21_5',
#  'Q21_6',
#  'Q21_7',
#  'Q21_8',
#  'Q21_9',
#  'Q21_10',
#  'Q22',
#  'Q23',
#  'Q24',
#  'Q25',
#  'Q26',
#  'Q27',
#  'Q28_1',
#  'Q28_2',
#  'Q28_3',
#  'Q28_4',
#  'Q28_5',
#  'Q28_6',
#  'Q28_7',
#  'Q28_8',
#  'Q29',
#  'Q30',
#  'Q31_1',
#  'Q31_2',
#  'Q31_3',
#  'Q31_4',
#  'Q31_5',
#  'Q31_6',
#  'Q31_7',
#  'Q31_8',
#  'Q31_9',
#  'Q31_10',
#  'Q31_11',
#  'Q31_12',
#  'Q32',
#  'Q33_1',
#  'Q33_2',
#  'Q33_3',
#  'Q33_4',
#  'Q33_5',
#  'Q34_1',
#  'Q34_2',
#  'Q34_3',
#  'Q34_4',
#  'Q34_5',
#  'Q34_6',
#  'Q34_7',
#  'Q34_8',
#  'Q35_1',
#  'Q35_2',
#  'Q35_3',
#  'Q35_4',
#  'Q35_5',
#  'Q35_6',
#  'Q35_7',
#  'Q35_8',
#  'Q35_9',
#  'Q35_10',
#  'Q35_11',
#  'Q35_12',
#  'Q35_13',
#  'Q35_14',
#  'Q35_15',
#  'Q35_16',
#  'Q36_1',
#  'Q36_2',
#  'Q36_3',
#  'Q36_4',
#  'Q36_5',
#  'Q36_6',
#  'Q36_7',
#  'Q36_8',
#  'Q36_9',
#  'Q36_10',
#  'Q36_11',
#  'Q36_12',
#  'Q36_13',
#  'Q36_14',
#  'Q36_15',
#  'Q37_1',
#  'Q37_2',
#  'Q37_3',
#  'Q37_4',
#  'Q37_5',
#  'Q37_6',
#  'Q37_7',
#  'Q37_8',
#  'Q37_9',
#  'Q37_10',
#  'Q37_11',
#  'Q37_12',
#  'Q37_13',
#  'Q38_1',
#  'Q38_2',
#  'Q38_3',
#  'Q38_4',
#  'Q38_5',
#  'Q38_6',
#  'Q38_7',
#  'Q38_8',
#  'Q39_1',
#  'Q39_2',
#  'Q39_3',
#  'Q39_4',
#  'Q39_5',
#  'Q39_6',
#  'Q39_7',
#  'Q39_8',
#  'Q39_9',
#  'Q39_10',
#  'Q39_11',
#  'Q39_12',
#  'Q40_1',
#  'Q40_2',
#  'Q40_3',
#  'Q40_4',
#  'Q40_5',
#  'Q40_6',
#  'Q40_7',
#  'Q40_8',
#  'Q40_9',
#  'Q40_10',
#  'Q40_11',
#  'Q40_12',
#  'Q40_13',
#  'Q40_14',
#  'Q40_15',
#  'Q41_1',
#  'Q41_2',
#  'Q41_3',
#  'Q41_4',
#  'Q41_5',
#  'Q41_6',
#  'Q41_7',
#  'Q41_8',
#  'Q41_9',
#  'Q42_1',
#  'Q42_2',
#  'Q42_3',
#  'Q42_4',
#  'Q42_5',
#  'Q42_6',
#  'Q42_7',
#  'Q42_8',
#  'Q42_9',
#  'Q43',
#  'Q44_1',
#  'Q44_2',
#  'Q44_3',
#  'Q44_4',
#  'Q44_5',
#  'Q44_6',
#  'Q44_7',
#  'Q44_8',
#  'Q44_9',
#  'Q44_10',
#  'Q44_11',
#  'Q44_12']

# %% [markdown]
# ### Subsetting required columns...!

# %%
df = df[[
        #'Duration (in seconds)',
        'Q2',
        'Q3',
        'Q4',
        #'Q5',
        #'Q6_1',  'Q6_2',  'Q6_3',  'Q6_4',  'Q6_5',  'Q6_6',  'Q6_7',  'Q6_8',  'Q6_9',  'Q6_10',  'Q6_11',  'Q6_12',
        #'Q7_1',  'Q7_2',  'Q7_3',  'Q7_4',  'Q7_5',  'Q7_6',  'Q7_7',
        #'Q8',
        #'Q9',
        #'Q10_1',  'Q10_2',  'Q10_3',
        'Q11',
        'Q12_1',  'Q12_2',  'Q12_3',  'Q12_4',  'Q12_5',  'Q12_6',  'Q12_7',  'Q12_8',  'Q12_9',  'Q12_10',  'Q12_11',  'Q12_12',  'Q12_13',  'Q12_14',  'Q12_15',
        'Q13_1',  'Q13_2',  'Q13_3',  'Q13_4',  'Q13_5',  'Q13_6',  'Q13_7',  'Q13_8',  'Q13_9',  'Q13_10',  'Q13_11',  'Q13_12',  'Q13_13',  'Q13_14',
        'Q14_1',  'Q14_2',  'Q14_3',  'Q14_4',  'Q14_5',  'Q14_6',  'Q14_7',  'Q14_8',  'Q14_9',  'Q14_10',  'Q14_11',  'Q14_12',  'Q14_13',  'Q14_14',  'Q14_15',  'Q14_16',
        'Q15_1',  'Q15_2',  'Q15_3',  'Q15_4',  'Q15_5',  'Q15_6',  'Q15_7',  'Q15_8',  'Q15_9',  'Q15_10',  'Q15_11',  'Q15_12',  'Q15_13',  'Q15_14',  'Q15_15',
        #'Q16',
        'Q17_1',  'Q17_2',  'Q17_3',  'Q17_4',  'Q17_5',  'Q17_6',  'Q17_7',  'Q17_8',  'Q17_9',  'Q17_10',  'Q17_11',  'Q17_12',  'Q17_13',  'Q17_14',  'Q17_15',
        #'Q18_1',  'Q18_2',  'Q18_3',  'Q18_4',  'Q18_5',  'Q18_6',  'Q18_7',  'Q18_8',  'Q18_9',  'Q18_10',  'Q18_11',  'Q18_12',  'Q18_13',  'Q18_14',
        #'Q19_1',  'Q19_2',  'Q19_3',  'Q19_4',  'Q19_5',  'Q19_6',  'Q19_7',  'Q19_8',
        #'Q20_1',  'Q20_2',  'Q20_3',  'Q20_4',  'Q20_5',  'Q20_6',
        'Q21_1',  'Q21_2',  'Q21_3',  'Q21_4',  'Q21_5',  'Q21_6',  'Q21_7',  'Q21_8',  'Q21_9',  'Q21_10',
        'Q22',
        'Q23',
        'Q24',
        'Q25',
        'Q26',
        #'Q27',
        #'Q28_1',  'Q28_2',  'Q28_3',  'Q28_4',  'Q28_5',  'Q28_6',  'Q28_7',  'Q28_8',
        'Q29',
        'Q30',  'Q31_1',  'Q31_2',  'Q31_3',  'Q31_4',  'Q31_5',  'Q31_6',  'Q31_7',  'Q31_8',  'Q31_9',  'Q31_10',  'Q31_11',  'Q31_12',
        'Q32',
        'Q33_1',  'Q33_2',  'Q33_3',  'Q33_4',  'Q33_5',
        'Q34_1',  'Q34_2',  'Q34_3',  'Q34_4',  'Q34_5',  'Q34_6',  'Q34_7',  'Q34_8',
        'Q35_1',  'Q35_2',  'Q35_3',  'Q35_4',  'Q35_5',  'Q35_6',  'Q35_7',  'Q35_8',  'Q35_9',  'Q35_10',  'Q35_11',  'Q35_12',  'Q35_13',  'Q35_14',  'Q35_15',  'Q35_16',
        'Q36_1',  'Q36_2',  'Q36_3',  'Q36_4',  'Q36_5',  'Q36_6',  'Q36_7',  'Q36_8',  'Q36_9',  'Q36_10',  'Q36_11',  'Q36_12',  'Q36_13',  'Q36_14',  'Q36_15',
        'Q37_1',  'Q37_2',  'Q37_3',  'Q37_4',  'Q37_5',  'Q37_6',  'Q37_7',  'Q37_8',  'Q37_9',  'Q37_10',  'Q37_11',  'Q37_12',  'Q37_13',
        'Q38_1',  'Q38_2',  'Q38_3',  'Q38_4',  'Q38_5',  'Q38_6',  'Q38_7',  'Q38_8',
        'Q39_1',  'Q39_2',  'Q39_3',  'Q39_4',  'Q39_5',  'Q39_6',  'Q39_7',  'Q39_8',  'Q39_9',  'Q39_10',  'Q39_11',  'Q39_12',
        'Q40_1',  'Q40_2',  'Q40_3',  'Q40_4',  'Q40_5',  'Q40_6',  'Q40_7',  'Q40_8',  'Q40_9',  'Q40_10',  'Q40_11',  'Q40_12',  'Q40_13',  'Q40_14',  'Q40_15',
        'Q41_1',  'Q41_2',  'Q41_3',  'Q41_4',  'Q41_5',  'Q41_6',  'Q41_7',  'Q41_8',  'Q41_9',
        'Q42_1',  'Q42_2',  'Q42_3',  'Q42_4',  'Q42_5',  'Q42_6',  'Q42_7',  'Q42_8',  'Q42_9',
        'Q43',
        #'Q44_1',  'Q44_2',  'Q44_3',  'Q44_4',  'Q44_5',  'Q44_6',  'Q44_7',  'Q44_8',  'Q44_9',  'Q44_10',  'Q44_11',  'Q44_12' 
]]

# %%
df.head(3)
# Out:
#                             Q2                                      Q3  \
# 0  What is your age (# years)?  What is your gender? - Selected Choice
# 1                        30-34                                     Man
# 2                        30-34                                     Man
#
#                                           Q4  \
# 0  In which country do you currently reside?
# 1                                      India
# 2                                    Algeria
#
#                                                  Q11  \
# 0  For how many years have you been writing code ...
# 1                                                NaN
# 2                                          1-3 years
#
#                                                Q12_1  \
# 0  What programming languages do you use on a reg...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q12_2  \
# 0  What programming languages do you use on a reg...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q12_3  \
# 0  What programming languages do you use on a reg...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q12_4  \
# 0  What programming languages do you use on a reg...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q12_5  \
# 0  What programming languages do you use on a reg...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q12_6  \
# 0  What programming languages do you use on a reg...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q12_7  \
# 0  What programming languages do you use on a reg...
# 1                                                NaN
# 2                                               Java
#
#                                                Q12_8  \
# 0  What programming languages do you use on a reg...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q12_9  \
# 0  What programming languages do you use on a reg...
# 1                                                NaN
# 2                                                NaN
#
#                                               Q12_10  \
# 0  What programming languages do you use on a reg...
# 1                                                NaN
# 2                                                NaN
#
#                                               Q12_11  \
# 0  What programming languages do you use on a reg...
# 1                                                NaN
# 2                                                NaN
#
#                                               Q12_12  \
# 0  What programming languages do you use on a reg...
# 1                                                NaN
# 2                                                NaN
#
#                                               Q12_13  \
# 0  What programming languages do you use on a reg...
# 1                                                NaN
# 2                                                NaN
#
#                                               Q12_14  \
# 0  What programming languages do you use on a reg...
# 1                                                NaN
# 2                                                NaN
#
#                                               Q12_15  \
# 0  What programming languages do you use on a reg...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q13_1  \
# 0  Which of the following integrated development ...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q13_2  \
# 0  Which of the following integrated development ...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q13_3  \
# 0  Which of the following integrated development ...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q13_4  \
# 0  Which of the following integrated development ...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q13_5  \
# 0  Which of the following integrated development ...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q13_6  \
# 0  Which of the following integrated development ...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q13_7  \
# 0  Which of the following integrated development ...
# 1                                                NaN
# 2                                        Notepad++
#
#                                                Q13_8  \
# 0  Which of the following integrated development ...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q13_9  \
# 0  Which of the following integrated development ...
# 1                                                NaN
# 2                                                NaN
#
#                                               Q13_10  \
# 0  Which of the following integrated development ...
# 1                                                NaN
# 2                                                NaN
#
#                                               Q13_11  \
# 0  Which of the following integrated development ...
# 1                                                NaN
# 2                                                NaN
#
#                                               Q13_12  \
# 0  Which of the following integrated development ...
# 1                                                NaN
# 2                                                NaN
#
#                                               Q13_13  \
# 0  Which of the following integrated development ...
# 1                                                NaN
# 2                                                NaN
#
#                                               Q13_14  \
# 0  Which of the following integrated development ...
# 1                                                NaN
# 2                                              Other
#
#                                                Q14_1  \
# 0  Do you use any of the following hosted noteboo...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q14_2  \
# 0  Do you use any of the following hosted noteboo...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q14_3  \
# 0  Do you use any of the following hosted noteboo...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q14_4  \
# 0  Do you use any of the following hosted noteboo...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q14_5  \
# 0  Do you use any of the following hosted noteboo...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q14_6  \
# 0  Do you use any of the following hosted noteboo...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q14_7  \
# 0  Do you use any of the following hosted noteboo...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q14_8  \
# 0  Do you use any of the following hosted noteboo...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q14_9  \
# 0  Do you use any of the following hosted noteboo...
# 1                                                NaN
# 2                                                NaN
#
#                                               Q14_10  \
# 0  Do you use any of the following hosted noteboo...
# 1                                                NaN
# 2                                                NaN
#
#                                               Q14_11  \
# 0  Do you use any of the following hosted noteboo...
# 1                                                NaN
# 2                                                NaN
#
#                                               Q14_12  \
# 0  Do you use any of the following hosted noteboo...
# 1                                                NaN
# 2                                                NaN
#
#                                               Q14_13  \
# 0  Do you use any of the following hosted noteboo...
# 1                                                NaN
# 2                                                NaN
#
#                                               Q14_14  \
# 0  Do you use any of the following hosted noteboo...
# 1                                                NaN
# 2                                                NaN
#
#                                               Q14_15  \
# 0  Do you use any of the following hosted noteboo...
# 1                                                NaN
# 2                                               None
#
#                                               Q14_16  \
# 0  Do you use any of the following hosted noteboo...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q15_1  \
# 0  Do you use any of the following data visualiza...
# 1                                                NaN
# 2                                        Matplotlib
#
#                                                Q15_2  \
# 0  Do you use any of the following data visualiza...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q15_3  \
# 0  Do you use any of the following data visualiza...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q15_4  \
# 0  Do you use any of the following data visualiza...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q15_5  \
# 0  Do you use any of the following data visualiza...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q15_6  \
# 0  Do you use any of the following data visualiza...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q15_7  \
# 0  Do you use any of the following data visualiza...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q15_8  \
# 0  Do you use any of the following data visualiza...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q15_9  \
# 0  Do you use any of the following data visualiza...
# 1                                                NaN
# 2                                                NaN
#
#                                               Q15_10  \
# 0  Do you use any of the following data visualiza...
# 1                                                NaN
# 2                                                NaN
#
#                                               Q15_11  \
# 0  Do you use any of the following data visualiza...
# 1                                                NaN
# 2                                                NaN
#
#                                               Q15_12  \
# 0  Do you use any of the following data visualiza...
# 1                                                NaN
# 2                                                NaN
#
#                                               Q15_13  \
# 0  Do you use any of the following data visualiza...
# 1                                                NaN
# 2                                                NaN
#
#                                               Q15_14  \
# 0  Do you use any of the following data visualiza...
# 1                                                NaN
# 2                                                NaN
#
#                                               Q15_15  \
# 0  Do you use any of the following data visualiza...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q17_1  \
# 0  Which of the following machine learning framew...
# 1                                                NaN
# 2                                      Scikit-learn
#
#                                                Q17_2  \
# 0  Which of the following machine learning framew...
# 1                                                NaN
# 2                                        TensorFlow
#
#                                                Q17_3  \
# 0  Which of the following machine learning framew...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q17_4  \
# 0  Which of the following machine learning framew...
# 1                                                NaN
# 2                                           PyTorch
#
#                                                Q17_5  \
# 0  Which of the following machine learning framew...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q17_6  \
# 0  Which of the following machine learning framew...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q17_7  \
# 0  Which of the following machine learning framew...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q17_8  \
# 0  Which of the following machine learning framew...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q17_9  \
# 0  Which of the following machine learning framew...
# 1                                                NaN
# 2                                                NaN
#
#                                               Q17_10  \
# 0  Which of the following machine learning framew...
# 1                                                NaN
# 2                                                NaN
#
#                                               Q17_11  \
# 0  Which of the following machine learning framew...
# 1                                                NaN
# 2                                                NaN
#
#                                               Q17_12  \
# 0  Which of the following machine learning framew...
# 1                                                NaN
# 2                                                NaN
#
#                                               Q17_13  \
# 0  Which of the following machine learning framew...
# 1                                                NaN
# 2                                                NaN
#
#                                               Q17_14  \
# 0  Which of the following machine learning framew...
# 1                                                NaN
# 2                                                NaN
#
#                                               Q17_15  \
# 0  Which of the following machine learning framew...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q21_1  \
# 0  Do you download pre-trained model weights from...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q21_2  \
# 0  Do you download pre-trained model weights from...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q21_3  \
# 0  Do you download pre-trained model weights from...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q21_4  \
# 0  Do you download pre-trained model weights from...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q21_5  \
# 0  Do you download pre-trained model weights from...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q21_6  \
# 0  Do you download pre-trained model weights from...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q21_7  \
# 0  Do you download pre-trained model weights from...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q21_8  \
# 0  Do you download pre-trained model weights from...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q21_9  \
# 0  Do you download pre-trained model weights from...
# 1                                                NaN
# 2  No, I do not download pre-trained model weight...
#
#                                               Q21_10  \
# 0  Do you download pre-trained model weights from...
# 1                                                NaN
# 2                                                NaN
#
#                                                  Q22  \
# 0  Which of the following ML model hubs/repositor...
# 1                                                NaN
# 2                                                NaN
#
#                                                  Q23  \
# 0  Select the title most similar to your current ...
# 1                                                NaN
# 2                                                NaN
#
#                                                  Q24  \
# 0  In what industry is your current employer/cont...
# 1                                                NaN
# 2                                                NaN
#
#                                                  Q25  \
# 0  What is the size of the company where you are ...
# 1                                                NaN
# 2                                                NaN
#
#                                                  Q26  \
# 0  Approximately how many individuals are respons...
# 1                                                NaN
# 2                                                NaN
#
#                                                  Q29  \
# 0  What is your current yearly compensation (appr...
# 1                                                NaN
# 2                                                NaN
#
#                                                  Q30  \
# 0  Approximately how much money have you spent on...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q31_1  \
# 0  Which of the following cloud computing platfor...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q31_2  \
# 0  Which of the following cloud computing platfor...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q31_3  \
# 0  Which of the following cloud computing platfor...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q31_4  \
# 0  Which of the following cloud computing platfor...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q31_5  \
# 0  Which of the following cloud computing platfor...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q31_6  \
# 0  Which of the following cloud computing platfor...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q31_7  \
# 0  Which of the following cloud computing platfor...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q31_8  \
# 0  Which of the following cloud computing platfor...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q31_9  \
# 0  Which of the following cloud computing platfor...
# 1                                                NaN
# 2                                                NaN
#
#                                               Q31_10  \
# 0  Which of the following cloud computing platfor...
# 1                                                NaN
# 2                                                NaN
#
#                                               Q31_11  \
# 0  Which of the following cloud computing platfor...
# 1                                                NaN
# 2                                                NaN
#
#                                               Q31_12  \
# 0  Which of the following cloud computing platfor...
# 1                                                NaN
# 2                                                NaN
#
#                                                  Q32  \
# 0  Of the cloud platforms that you are familiar w...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q33_1  \
# 0  Do you use any of the following cloud computin...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q33_2  \
# 0  Do you use any of the following cloud computin...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q33_3  \
# 0  Do you use any of the following cloud computin...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q33_4  \
# 0  Do you use any of the following cloud computin...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q33_5  \
# 0  Do you use any of the following cloud computin...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q34_1  \
# 0  Do you use any of the following data storage p...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q34_2  \
# 0  Do you use any of the following data storage p...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q34_3  \
# 0  Do you use any of the following data storage p...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q34_4  \
# 0  Do you use any of the following data storage p...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q34_5  \
# 0  Do you use any of the following data storage p...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q34_6  \
# 0  Do you use any of the following data storage p...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q34_7  \
# 0  Do you use any of the following data storage p...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q34_8  \
# 0  Do you use any of the following data storage p...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q35_1  \
# 0  Do you use any of the following data products ...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q35_2  \
# 0  Do you use any of the following data products ...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q35_3  \
# 0  Do you use any of the following data products ...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q35_4  \
# 0  Do you use any of the following data products ...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q35_5  \
# 0  Do you use any of the following data products ...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q35_6  \
# 0  Do you use any of the following data products ...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q35_7  \
# 0  Do you use any of the following data products ...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q35_8  \
# 0  Do you use any of the following data products ...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q35_9  \
# 0  Do you use any of the following data products ...
# 1                                                NaN
# 2                                                NaN
#
#                                               Q35_10  \
# 0  Do you use any of the following data products ...
# 1                                                NaN
# 2                                                NaN
#
#                                               Q35_11  \
# 0  Do you use any of the following data products ...
# 1                                                NaN
# 2                                                NaN
#
#                                               Q35_12  \
# 0  Do you use any of the following data products ...
# 1                                                NaN
# 2                                                NaN
#
#                                               Q35_13  \
# 0  Do you use any of the following data products ...
# 1                                                NaN
# 2                                                NaN
#
#                                               Q35_14  \
# 0  Do you use any of the following data products ...
# 1                                                NaN
# 2                                                NaN
#
#                                               Q35_15  \
# 0  Do you use any of the following data products ...
# 1                                                NaN
# 2                                                NaN
#
#                                               Q35_16  \
# 0  Do you use any of the following data products ...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q36_1  \
# 0  Do you use any of the following business intel...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q36_2  \
# 0  Do you use any of the following business intel...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q36_3  \
# 0  Do you use any of the following business intel...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q36_4  \
# 0  Do you use any of the following business intel...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q36_5  \
# 0  Do you use any of the following business intel...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q36_6  \
# 0  Do you use any of the following business intel...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q36_7  \
# 0  Do you use any of the following business intel...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q36_8  \
# 0  Do you use any of the following business intel...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q36_9  \
# 0  Do you use any of the following business intel...
# 1                                                NaN
# 2                                                NaN
#
#                                               Q36_10  \
# 0  Do you use any of the following business intel...
# 1                                                NaN
# 2                                                NaN
#
#                                               Q36_11  \
# 0  Do you use any of the following business intel...
# 1                                                NaN
# 2                                                NaN
#
#                                               Q36_12  \
# 0  Do you use any of the following business intel...
# 1                                                NaN
# 2                                                NaN
#
#                                               Q36_13  \
# 0  Do you use any of the following business intel...
# 1                                                NaN
# 2                                                NaN
#
#                                               Q36_14  \
# 0  Do you use any of the following business intel...
# 1                                                NaN
# 2                                                NaN
#
#                                               Q36_15  \
# 0  Do you use any of the following business intel...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q37_1  \
# 0  Do you use any of the following managed machin...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q37_2  \
# 0  Do you use any of the following managed machin...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q37_3  \
# 0  Do you use any of the following managed machin...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q37_4  \
# 0  Do you use any of the following managed machin...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q37_5  \
# 0  Do you use any of the following managed machin...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q37_6  \
# 0  Do you use any of the following managed machin...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q37_7  \
# 0  Do you use any of the following managed machin...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q37_8  \
# 0  Do you use any of the following managed machin...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q37_9  \
# 0  Do you use any of the following managed machin...
# 1                                                NaN
# 2                                                NaN
#
#                                               Q37_10  \
# 0  Do you use any of the following managed machin...
# 1                                                NaN
# 2                                                NaN
#
#                                               Q37_11  \
# 0  Do you use any of the following managed machin...
# 1                                                NaN
# 2                                                NaN
#
#                                               Q37_12  \
# 0  Do you use any of the following managed machin...
# 1                                                NaN
# 2                                                NaN
#
#                                               Q37_13  \
# 0  Do you use any of the following managed machin...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q38_1  \
# 0  Do you use any of the following automated mach...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q38_2  \
# 0  Do you use any of the following automated mach...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q38_3  \
# 0  Do you use any of the following automated mach...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q38_4  \
# 0  Do you use any of the following automated mach...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q38_5  \
# 0  Do you use any of the following automated mach...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q38_6  \
# 0  Do you use any of the following automated mach...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q38_7  \
# 0  Do you use any of the following automated mach...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q38_8  \
# 0  Do you use any of the following automated mach...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q39_1  \
# 0  Do you use any of the following products to se...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q39_2  \
# 0  Do you use any of the following products to se...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q39_3  \
# 0  Do you use any of the following products to se...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q39_4  \
# 0  Do you use any of the following products to se...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q39_5  \
# 0  Do you use any of the following products to se...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q39_6  \
# 0  Do you use any of the following products to se...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q39_7  \
# 0  Do you use any of the following products to se...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q39_8  \
# 0  Do you use any of the following products to se...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q39_9  \
# 0  Do you use any of the following products to se...
# 1                                                NaN
# 2                                                NaN
#
#                                               Q39_10  \
# 0  Do you use any of the following products to se...
# 1                                                NaN
# 2                                                NaN
#
#                                               Q39_11  \
# 0  Do you use any of the following products to se...
# 1                                                NaN
# 2                                                NaN
#
#                                               Q39_12  \
# 0  Do you use any of the following products to se...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q40_1  \
# 0  Do you use any tools to help monitor your mach...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q40_2  \
# 0  Do you use any tools to help monitor your mach...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q40_3  \
# 0  Do you use any tools to help monitor your mach...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q40_4  \
# 0  Do you use any tools to help monitor your mach...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q40_5  \
# 0  Do you use any tools to help monitor your mach...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q40_6  \
# 0  Do you use any tools to help monitor your mach...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q40_7  \
# 0  Do you use any tools to help monitor your mach...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q40_8  \
# 0  Do you use any tools to help monitor your mach...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q40_9  \
# 0  Do you use any tools to help monitor your mach...
# 1                                                NaN
# 2                                                NaN
#
#                                               Q40_10  \
# 0  Do you use any tools to help monitor your mach...
# 1                                                NaN
# 2                                                NaN
#
#                                               Q40_11  \
# 0  Do you use any tools to help monitor your mach...
# 1                                                NaN
# 2                                                NaN
#
#                                               Q40_12  \
# 0  Do you use any tools to help monitor your mach...
# 1                                                NaN
# 2                                                NaN
#
#                                               Q40_13  \
# 0  Do you use any tools to help monitor your mach...
# 1                                                NaN
# 2                                                NaN
#
#                                               Q40_14  \
# 0  Do you use any tools to help monitor your mach...
# 1                                                NaN
# 2                                                NaN
#
#                                               Q40_15  \
# 0  Do you use any tools to help monitor your mach...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q41_1  \
# 0  Do you use any of the following responsible or...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q41_2  \
# 0  Do you use any of the following responsible or...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q41_3  \
# 0  Do you use any of the following responsible or...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q41_4  \
# 0  Do you use any of the following responsible or...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q41_5  \
# 0  Do you use any of the following responsible or...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q41_6  \
# 0  Do you use any of the following responsible or...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q41_7  \
# 0  Do you use any of the following responsible or...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q41_8  \
# 0  Do you use any of the following responsible or...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q41_9  \
# 0  Do you use any of the following responsible or...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q42_1  \
# 0  Do you use any of the following types of speci...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q42_2  \
# 0  Do you use any of the following types of speci...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q42_3  \
# 0  Do you use any of the following types of speci...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q42_4  \
# 0  Do you use any of the following types of speci...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q42_5  \
# 0  Do you use any of the following types of speci...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q42_6  \
# 0  Do you use any of the following types of speci...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q42_7  \
# 0  Do you use any of the following types of speci...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q42_8  \
# 0  Do you use any of the following types of speci...
# 1                                                NaN
# 2                                                NaN
#
#                                                Q42_9  \
# 0  Do you use any of the following types of speci...
# 1                                                NaN
# 2                                                NaN
#
#                                                  Q43
# 0  Approximately how many times have you used a T...
# 1                                                NaN
# 2                                                NaN

# %% [markdown]
# ### Merging columns of Multiple Select Question & Creating new columns.

# %%
df['Programming_Language'] = df[df.columns[4:19]].apply(lambda x: ','.join(x.dropna().str.strip()),axis=1)
df['IDE'] = df[df.columns[19:33]].apply(lambda x: ','.join(x.dropna().str.strip()),axis=1)
df['Hosted_Notebook'] = df[df.columns[33:49]].apply(lambda x: ','.join(x.dropna().str.strip()),axis=1)
df['Visualization_Libraries'] = df[df.columns[49:64]].apply(lambda x: ','.join(x.dropna().str.strip()),axis=1)
df['ML_Frameworks'] = df[df.columns[64:79]].apply(lambda x: ','.join(x.dropna().str.strip()),axis=1)
df['Pre-Trained_Model_Weights'] = df[df.columns[79:89]].apply(lambda x: ','.join(x.dropna().str.strip()),axis=1)
df['Best_Exp_Cloud_platForm'] = df[df.columns[96:108]].apply(lambda x: ','.join(x.dropna().str.strip()),axis=1)
df['Cloud_Computing_Products'] = df[df.columns[109:114]].apply(lambda x: ','.join(x.dropna().str.strip()),axis=1)
df['Data_Storage_Products'] = df[df.columns[114:122]].apply(lambda x: ','.join(x.dropna().str.strip()),axis=1)
df['DBMS'] = df[df.columns[122:138]].apply(lambda x: ','.join(x.dropna().str.strip()),axis=1)
df['BI_Tools'] = df[df.columns[138:153]].apply(lambda x: ','.join(x.dropna().str.strip()),axis=1)
df['Managed_ML_Products'] = df[df.columns[153:166]].apply(lambda x: ','.join(x.dropna().str.strip()),axis=1)
df['Auto_ML_Tools'] = df[df.columns[166:174]].apply(lambda x: ','.join(x.dropna().str.strip()),axis=1)
df['Serve_ML_Models'] = df[df.columns[174:186]].apply(lambda x: ','.join(x.dropna().str.strip()),axis=1)
df['ML_Monitering_Tools'] = df[df.columns[186:201]].apply(lambda x: ','.join(x.dropna().str.strip()),axis=1)
df['Ethical_AI_Products'] = df[df.columns[201:210]].apply(lambda x: ','.join(x.dropna().str.strip()),axis=1)
df['Hardware'] = df[df.columns[210:219]].apply(lambda x: ','.join(x.dropna().str.strip()),axis=1)

# %% [markdown]
# ### Droping merged columns.

# %%
remove_col = df.columns[4:89].append(df.columns[96:108]).append(df.columns[109:219])
df.drop(remove_col, axis=1, inplace=True)

# %%
list(df.columns)
# Out:
# ['Q2',
#  'Q3',
#  'Q4',
#  'Q11',
#  'Q22',
#  'Q23',
#  'Q24',
#  'Q25',
#  'Q26',
#  'Q29',
#  'Q30',
#  'Q32',
#  'Q43',
#  'Programming_Language',
#  'IDE',
#  'Hosted_Notebook',
#  'Visualization_Libraries',
#  'ML_Frameworks',
#  'Pre-Trained_Model_Weights',
#  'Best_Exp_Cloud_platForm',
#  'Cloud_Computing_Products',
#  'Data_Storage_Products',
#  'DBMS',
#  'BI_Tools',
#  'Managed_ML_Products',
#  'Auto_ML_Tools',
#  'Serve_ML_Models',
#  'ML_Monitering_Tools',
#  'Ethical_AI_Products',
#  'Hardware']

# %% [markdown]
# ### Renaming columns

# %%
df.rename(columns = {
    'Q2': 'Age',
    'Q3' : 'Gender',
    'Q4' : 'Country',
    'Q11' : 'Coding_Experience',
    'Q22': 'ML_Model_Hubs/Repo',
    'Q23': 'Role',
    'Q24': 'Industry',
    'Q25': 'Company_Size',
    'Q26': 'Team_Size',
    'Q29': 'SalaryPerAnnum_USD',
    'Q30': 'Cloud_Expenses',
    'Q32': 'Best_Cloud_Experience',
    'Q43': 'Time_TPUs_Used',
}, inplace=True)

# %%
list(df.columns)
# Out:
# ['Age',
#  'Gender',
#  'Country',
#  'Coding_Experience',
#  'ML_Model_Hubs/Repo',
#  'Role',
#  'Industry',
#  'Company_Size',
#  'Team_Size',
#  'SalaryPerAnnum_USD',
#  'Cloud_Expenses',
#  'Best_Cloud_Experience',
#  'Time_TPUs_Used',
#  'Programming_Language',
#  'IDE',
#  'Hosted_Notebook',
#  'Visualization_Libraries',
#  'ML_Frameworks',
#  'Pre-Trained_Model_Weights',
#  'Best_Exp_Cloud_platForm',
#  'Cloud_Computing_Products',
#  'Data_Storage_Products',
#  'DBMS',
#  'BI_Tools',
#  'Managed_ML_Products',
#  'Auto_ML_Tools',
#  'Serve_ML_Models',
#  'ML_Monitering_Tools',
#  'Ethical_AI_Products',
#  'Hardware']

# %% [markdown]
# Removing the 0th header row!

# %%
df.drop(0, inplace=True)

# %%
df.head(3)
# Out:
#      Age Gender  Country Coding_Experience ML_Model_Hubs/Repo Role Industry  \
# 1  30-34    Man    India               NaN                NaN  NaN      NaN
# 2  30-34    Man  Algeria         1-3 years                NaN  NaN      NaN
# 3  18-21    Man    Egypt         1-3 years                NaN  NaN      NaN
#
#   Company_Size Team_Size SalaryPerAnnum_USD Cloud_Expenses  \
# 1          NaN       NaN                NaN            NaN
# 2          NaN       NaN                NaN            NaN
# 3          NaN       NaN                NaN            NaN
#
#   Best_Cloud_Experience Time_TPUs_Used Programming_Language  \
# 1                   NaN            NaN
# 2                   NaN            NaN                 Java
# 3                   NaN            NaN  Python,SQL,C,MATLAB
#
#                            IDE                     Hosted_Notebook  \
# 1
# 2              Notepad++,Other                                None
# 3  JupyterLab,Jupyter Notebook  Kaggle Notebooks,IBM Watson Studio
#
#                              Visualization_Libraries  \
# 1
# 2                                         Matplotlib
# 3  Matplotlib,Seaborn,Plotly / Plotly Express,Geo...
#
#                                     ML_Frameworks  \
# 1
# 2                 Scikit-learn,TensorFlow,PyTorch
# 3  Scikit-learn,PyTorch,Xgboost,PyTorch Lightning
#
#                            Pre-Trained_Model_Weights Best_Exp_Cloud_platForm  \
# 1
# 2  No, I do not download pre-trained model weight...
# 3                                    Kaggle datasets
#
#   Cloud_Computing_Products Data_Storage_Products DBMS BI_Tools  \
# 1
# 2
# 3
#
#   Managed_ML_Products Auto_ML_Tools Serve_ML_Models ML_Monitering_Tools  \
# 1
# 2
# 3
#
#   Ethical_AI_Products Hardware
# 1
# 2
# 3

# %% [markdown]
# ### Renaming values with large names replacing null/NaN with None.

# %%
df.Country = df.Country.replace(
   ['United States of America','United Kingdom of Great Britain and Northern Ireland','Viet Nam','Iran, Islamic Republic of...', 'United Arab Emirates', 'Czech Republic', 'Hong Kong (S.A.R.)', 'I do not wish to disclose my location'],
   ['USA', 'UK', 'Vietnam', 'Iran',  'UAE', 'Czechia', 'Hong Kong', 'Not wish to disclose'])


df.Role = df.Role.replace(
   ['Data Analyst (Business, Marketing, Financial, Quantitative, etc)', 'Manager (Program, Project, Operations, Executive-level, etc)'],
   ['Data Analyst', 'Manager'])

df.Cloud_Expenses = df.Cloud_Expenses.replace(['$0 ($USD)', '$100,000 or more ($USD)'],
                          ['$0', '$100,000 or more'])

df.Best_Cloud_Experience = df.Best_Cloud_Experience.replace(['They all had a similarly enjoyable developer experience'],
                          ['Similar experience'])

df.IDE = df.IDE.replace(['', 'Visual Studio Code (VSCode)'],
               ['None', 'VSCode'])

df.fillna('None', inplace=True)

df = df.replace([''], 'None')

# %% [markdown]
# # Step 3: Features Understanding
# - Unique values
# - Ploting / Graphing
#  - Distributions
#  - Histograms, barplots, KDE
#  - Co-Relation between features

# %% [markdown]
# ### Looking for unique values.

# %%
for column in df.columns:
    print(f'{column} : {df[column].unique()}\n\n\n')
# Out:
# Age : ['30-34' '18-21' '55-59' '45-49' '70+' '22-24' '35-39' '40-44' '50-54'
#  '25-29' '60-69']
#
#
#
# Gender : ['Man' 'Woman' 'Prefer not to say' 'Nonbinary' 'Prefer to self-describe']
#
#
#
# Country : ['India' 'Algeria' 'Egypt' 'France' 'Germany' 'Australia' 'Other'
#  'South Korea' 'USA' 'Pakistan' 'Mexico' 'Singapore' 'Italy' 'Taiwan'
#  'China' 'Argentina' 'Turkey' 'Brazil' 'Nigeria' 'Chile' 'Japan' 'Canada'
#  'Indonesia' 'Israel' 'Colombia' 'Russia' 'UK' 'Ethiopia' 'South Africa'
#  'Vietnam' 'Kenya' 'Spain' 'Iran' 'Cameroon' 'Tunisia' 'Peru' 'Nepal'
#  'Morocco' 'Philippines' 'Ecuador' 'Thailand' 'UAE' 'Bangladesh'
#  'Netherlands' 'Zimbabwe' 'Ghana' 'Portugal' 'Poland' 'Saudi Arabia'
#  'Romania' 'Czechia' 'Malaysia' 'Sri Lanka' 'Hong Kong' 'Ukraine'
#  'Not wish to disclose' 'Belgium' 'Ireland']
#
#
#
# Coding_Experience : ['None' '1-3 years' '10-20 years' '5-10 years' '20+ years' '3-5 years'
#  '< 1 years' 'I have never written code']
#
#
#
# ML_Model_Hubs/Repo : ['None' ' Huggingface Models ' ' Kaggle datasets ' '  TensorFlow Hub '
#  ' PyTorch Hub ' ' ONNX models ' ' Timm '
#  'Other storage services (i.e. google drive)' ' Jumpstart '
#  ' NVIDIA NGC models  ']
#
#
#
# Role : ['None' 'Data Scientist' 'Software Engineer' 'Research Scientist' 'Other'
#  'Developer Advocate' 'Data Analyst' 'Data Engineer'
#  'Currently not employed' 'Machine Learning/ MLops Engineer'
#  'Engineer (non-software)' 'Teacher / professor' 'Statistician' 'Manager'
#  'Data Administrator' 'Data Architect']
#
#
#
# Industry : ['None' 'Online Service/Internet-based Services'
#  'Insurance/Risk Assessment' 'Government/Public Service'
#  'Manufacturing/Fabrication' 'Computers/Technology' 'Accounting/Finance'
#  'Academics/Education' 'Non-profit/Service' 'Other'
#  'Medical/Pharmaceutical' 'Marketing/CRM' 'Energy/Mining'
#  'Broadcasting/Communications' 'Retail/Sales' 'Shipping/Transportation']
#
#
#
# Company_Size : ['None' '0-49 employees' '250-999 employees' '1000-9,999 employees'
#  '10,000 or more employees' '50-249 employees']
#
#
#
# Team_Size : ['None' '1-2' '20+' '3-4' '5-9' '0' '10-14' '15-19']
#
#
#
# SalaryPerAnnum_USD : ['None' '25,000-29,999' '100,000-124,999' '200,000-249,999'
#  '150,000-199,999' '90,000-99,999' '30,000-39,999' '3,000-3,999'
#  '50,000-59,999' '125,000-149,999' '15,000-19,999' '5,000-7,499'
#  '10,000-14,999' '20,000-24,999' '$0-999' '7,500-9,999' '4,000-4,999'
#  '80,000-89,999' '2,000-2,999' '250,000-299,999' '1,000-1,999'
#  '$500,000-999,999' '70,000-79,999' '60,000-69,999' '40,000-49,999'
#  '>$1,000,000' '300,000-499,999']
#
#
#
# Cloud_Expenses : ['None' '$1000-$9,999' '$0' '$100-$999' '$100,000 or more' '$1-$99'
#  '$10,000-$99,999']
#
#
#
# Best_Cloud_Experience : ['None' 'Similar experience' ' Microsoft Azure ' ' Alibaba Cloud '
#  ' Amazon Web Services (AWS) ' 'None were satisfactory'
#  ' Google Cloud Platform (GCP) ' ' VMware Cloud ' ' IBM Cloud / Red Hat '
#  ' Oracle Cloud ' 'Other' ' SAP Cloud ' ' Tencent Cloud ' ' Huawei Cloud ']
#
#
#
# Time_TPUs_Used : ['None' '2-5 times' 'Never' 'More than 25 times' 'Once' '6-25 times']
#
#
#
# Programming_Language : ['None' 'Java' 'Python,SQL,C,MATLAB' ...
#  'Python,SQL,C,C#,C++,Javascript,Bash' 'Python,R,SQL,Javascript,Julia'
#  'Python,SQL,C++,Bash,PHP']
#
#
#
# IDE : ['None' 'Notepad++,Other' 'JupyterLab,Jupyter Notebook' ...
#  'JupyterLab,RStudio,Visual Studio Code (VSCode),PyCharm,Vim / Emacs,IntelliJ'
#  'JupyterLab,RStudio,Visual Studio Code (VSCode),PyCharm,Sublime Text,MATLAB,IntelliJ'
#  'JupyterLab,RStudio,Visual Studio,Jupyter Notebook,IntelliJ']
#
#
#
# Hosted_Notebook : ['None' 'Kaggle Notebooks,IBM Watson Studio'
#  'Kaggle Notebooks,Colab Notebooks,Deepnote Notebooks'
#  'Kaggle Notebooks,Colab Notebooks' 'Colab Notebooks' 'Kaggle Notebooks'
#  'Kaggle Notebooks,Colab Notebooks,Azure Notebooks,Google Cloud Vertex AI Workbench'
#  'Kaggle Notebooks,Colab Notebooks,Databricks Collaborative Notebooks'
#  'Colab Notebooks,Databricks Collaborative Notebooks'
#  'Kaggle Notebooks,Amazon Sagemaker Studio Lab'
#  'Colab Notebooks,Google Cloud Vertex AI Workbench'
#  'Amazon Sagemaker Studio,Amazon Sagemaker Studio Lab,Google Cloud Vertex AI Workbench'
#  'Kaggle Notebooks,Colab Notebooks,Google Cloud Vertex AI Workbench'
#  'Azure Notebooks,Databricks Collaborative Notebooks'
#  'Amazon Sagemaker Studio,Amazon Sagemaker Studio Lab,Amazon EMR Notebooks'
#  'Kaggle Notebooks,Colab Notebooks,Azure Notebooks,Noteable Notebooks,Gradient Notebooks'
#  'Colab Notebooks,Azure Notebooks' 'Colab Notebooks,Other'
#  'Kaggle Notebooks,Colab Notebooks,IBM Watson Studio'
#  'Colab Notebooks,IBM Watson Studio,Google Cloud Vertex AI Workbench'
#  'Other' 'Google Cloud Vertex AI Workbench'
#  'Amazon Sagemaker Studio,Databricks Collaborative Notebooks'
#  'Colab Notebooks,Gradient Notebooks'
#  'Colab Notebooks,Amazon Sagemaker Studio,Amazon Sagemaker Studio Lab'
#  'Kaggle Notebooks,Noteable Notebooks,Deepnote Notebooks'
#  'Kaggle Notebooks,Colab Notebooks,Amazon Sagemaker Studio,Amazon Sagemaker Studio Lab'
#  'Kaggle Notebooks,Colab Notebooks,Azure Notebooks,Other'
#  'Colab Notebooks,Amazon Sagemaker Studio Lab'
#  'Colab Notebooks,Azure Notebooks,Amazon Sagemaker Studio Lab'
#  'Kaggle Notebooks,IBM Watson Studio,Other'
#  'Kaggle Notebooks,Colab Notebooks,Gradient Notebooks'
#  'Kaggle Notebooks,Google Cloud Vertex AI Workbench'
#  'Kaggle Notebooks,Colab Notebooks,Amazon Sagemaker Studio,Amazon EMR Notebooks'
#  'Kaggle Notebooks,Noteable Notebooks'
#  'Colab Notebooks,Azure Notebooks,Amazon Sagemaker Studio,Amazon EMR Notebooks,Noteable Notebooks'
#  'Databricks Collaborative Notebooks'
#  'Google Cloud Vertex AI Workbench,Databricks Collaborative Notebooks'
#  'Kaggle Notebooks,Colab Notebooks,Azure Notebooks,IBM Watson Studio,Other'
#  'Kaggle Notebooks,Azure Notebooks'
#  'Azure Notebooks,Amazon Sagemaker Studio' 'Hex Workspaces'
#  'Amazon Sagemaker Studio'
#  'Google Cloud Vertex AI Workbench,Noteable Notebooks'
#  'Kaggle Notebooks,Colab Notebooks,Azure Notebooks,IBM Watson Studio,Amazon Sagemaker Studio,Amazon Sagemaker Studio Lab'
#  'Colab Notebooks,IBM Watson Studio'
#  'Colab Notebooks,Amazon Sagemaker Studio,Amazon Sagemaker Studio Lab,Google Cloud Vertex AI Workbench'
#  'Kaggle Notebooks,Colab Notebooks,Azure Notebooks'
#  'Colab Notebooks,IBM Watson Studio,Noteable Notebooks'
#  'Kaggle Notebooks,Colab Notebooks,Amazon Sagemaker Studio Lab'
#  'Deepnote Notebooks'
#  'Colab Notebooks,Azure Notebooks,Databricks Collaborative Notebooks'
#  'Azure Notebooks,IBM Watson Studio'
#  'Kaggle Notebooks,Azure Notebooks,IBM Watson Studio,Amazon Sagemaker Studio,Amazon EMR Notebooks,Google Cloud Vertex AI Workbench,Databricks Collaborative Notebooks'
#  'Kaggle Notebooks,Azure Notebooks,IBM Watson Studio,Amazon Sagemaker Studio Lab,Google Cloud Vertex AI Workbench'
#  'Colab Notebooks,Amazon Sagemaker Studio' 'IBM Watson Studio'
#  'Kaggle Notebooks,Colab Notebooks,Amazon Sagemaker Studio Lab,Google Cloud Vertex AI Workbench'
#  'Kaggle Notebooks,Colab Notebooks,Noteable Notebooks'
#  'Kaggle Notebooks,Colab Notebooks,IBM Watson Studio,Amazon EMR Notebooks'
#  'Azure Notebooks,Google Cloud Vertex AI Workbench'
#  'Code Ocean,IBM Watson Studio,Databricks Collaborative Notebooks'
#  'Noteable Notebooks' 'Code Ocean'
#  'Colab Notebooks,Google Cloud Vertex AI Workbench,Gradient Notebooks'
#  'Amazon Sagemaker Studio Lab' 'Kaggle Notebooks,Amazon Sagemaker Studio'
#  'Kaggle Notebooks,Colab Notebooks,Azure Notebooks,Gradient Notebooks'
#  'Kaggle Notebooks,Colab Notebooks,Code Ocean'
#  'Kaggle Notebooks,Colab Notebooks,Azure Notebooks,Databricks Collaborative Notebooks'
#  'Kaggle Notebooks,Colab Notebooks,Amazon Sagemaker Studio,Databricks Collaborative Notebooks,Deepnote Notebooks'
#  'Amazon Sagemaker Studio Lab,Other'
#  'Kaggle Notebooks,Colab Notebooks,Other'
#  'Kaggle Notebooks,Colab Notebooks,Azure Notebooks,Code Ocean,IBM Watson Studio,Amazon Sagemaker Studio,Amazon Sagemaker Studio Lab,Amazon EMR Notebooks,Google Cloud Vertex AI Workbench,Hex Workspaces,Noteable Notebooks,Databricks Collaborative Notebooks,Deepnote Notebooks,Gradient Notebooks'
#  'Kaggle Notebooks,Code Ocean'
#  'Kaggle Notebooks,Colab Notebooks,IBM Watson Studio,Noteable Notebooks'
#  'Colab Notebooks,Deepnote Notebooks' 'Kaggle Notebooks,Other'
#  'Kaggle Notebooks,Colab Notebooks,Amazon Sagemaker Studio,Amazon Sagemaker Studio Lab,Deepnote Notebooks'
#  'Kaggle Notebooks,Colab Notebooks,Google Cloud Vertex AI Workbench,Databricks Collaborative Notebooks'
#  'Kaggle Notebooks,Colab Notebooks,Azure Notebooks,IBM Watson Studio,Google Cloud Vertex AI Workbench,Noteable Notebooks'
#  'Colab Notebooks,Amazon Sagemaker Studio,Databricks Collaborative Notebooks'
#  'Azure Notebooks,Code Ocean,Databricks Collaborative Notebooks'
#  'Kaggle Notebooks,Colab Notebooks,Amazon Sagemaker Studio,Google Cloud Vertex AI Workbench,Databricks Collaborative Notebooks'
#  'Amazon Sagemaker Studio,Amazon Sagemaker Studio Lab'
#  'Amazon Sagemaker Studio,Amazon EMR Notebooks'
#  'Amazon EMR Notebooks,Google Cloud Vertex AI Workbench'
#  'Colab Notebooks,Noteable Notebooks'
#  'Kaggle Notebooks,Amazon EMR Notebooks'
#  'Kaggle Notebooks,Azure Notebooks,IBM Watson Studio,Databricks Collaborative Notebooks'
#  'Kaggle Notebooks,Colab Notebooks,Azure Notebooks,IBM Watson Studio,Amazon Sagemaker Studio,Amazon Sagemaker Studio Lab,Google Cloud Vertex AI Workbench,Databricks Collaborative Notebooks'
#  'Kaggle Notebooks,Colab Notebooks,Amazon Sagemaker Studio,Amazon Sagemaker Studio Lab,Amazon EMR Notebooks'
#  'Kaggle Notebooks,Colab Notebooks,Amazon Sagemaker Studio,Deepnote Notebooks'
#  'Kaggle Notebooks,Amazon Sagemaker Studio,Databricks Collaborative Notebooks'
#  'Kaggle Notebooks,Amazon Sagemaker Studio,Amazon Sagemaker Studio Lab'
#  'Kaggle Notebooks,Amazon EMR Notebooks,Google Cloud Vertex AI Workbench'
#  'Kaggle Notebooks,Azure Notebooks,IBM Watson Studio,Amazon EMR Notebooks'
#  'Kaggle Notebooks,Azure Notebooks,IBM Watson Studio,Amazon Sagemaker Studio,Amazon EMR Notebooks,Google Cloud Vertex AI Workbench,Gradient Notebooks'
#  'Kaggle Notebooks,Colab Notebooks,Amazon Sagemaker Studio Lab,Gradient Notebooks'
#  'Kaggle Notebooks,Colab Notebooks,IBM Watson Studio,Amazon Sagemaker Studio,Amazon Sagemaker Studio Lab,Amazon EMR Notebooks'
#  'Kaggle Notebooks,IBM Watson Studio,Amazon Sagemaker Studio,Noteable Notebooks,Databricks Collaborative Notebooks,Deepnote Notebooks'
#  'Colab Notebooks,Code Ocean,IBM Watson Studio,Amazon Sagemaker Studio,Google Cloud Vertex AI Workbench'
#  'Azure Notebooks' 'Gradient Notebooks'
#  'Kaggle Notebooks,Colab Notebooks,IBM Watson Studio,Amazon Sagemaker Studio,Amazon Sagemaker Studio Lab'
#  'Kaggle Notebooks,Colab Notebooks,Amazon Sagemaker Studio'
#  'Kaggle Notebooks,Colab Notebooks,Deepnote Notebooks,Gradient Notebooks'
#  'Colab Notebooks,Google Cloud Vertex AI Workbench,Databricks Collaborative Notebooks'
#  'Kaggle Notebooks,Databricks Collaborative Notebooks'
#  'Colab Notebooks,Code Ocean'
#  'Kaggle Notebooks,Azure Notebooks,Google Cloud Vertex AI Workbench'
#  'Kaggle Notebooks,IBM Watson Studio,Amazon EMR Notebooks,Noteable Notebooks'
#  'Hex Workspaces,Other'
#  'Kaggle Notebooks,Colab Notebooks,Google Cloud Vertex AI Workbench,Noteable Notebooks'
#  'Kaggle Notebooks,IBM Watson Studio,Gradient Notebooks'
#  'Code Ocean,IBM Watson Studio,Noteable Notebooks'
#  'Kaggle Notebooks,Colab Notebooks,Azure Notebooks,IBM Watson Studio,Amazon EMR Notebooks,Google Cloud Vertex AI Workbench,Noteable Notebooks'
#  'Colab Notebooks,Azure Notebooks,Google Cloud Vertex AI Workbench'
#  'Kaggle Notebooks,Colab Notebooks,Google Cloud Vertex AI Workbench,Deepnote Notebooks'
#  'Colab Notebooks,Amazon Sagemaker Studio Lab,Google Cloud Vertex AI Workbench'
#  'Kaggle Notebooks,Deepnote Notebooks'
#  'Amazon Sagemaker Studio,Amazon EMR Notebooks,Google Cloud Vertex AI Workbench'
#  'Azure Notebooks,Amazon Sagemaker Studio,Databricks Collaborative Notebooks'
#  'IBM Watson Studio,Google Cloud Vertex AI Workbench'
#  'Kaggle Notebooks,Colab Notebooks,Azure Notebooks,Amazon Sagemaker Studio,Amazon Sagemaker Studio Lab,Deepnote Notebooks'
#  'Kaggle Notebooks,Azure Notebooks,IBM Watson Studio'
#  'Kaggle Notebooks,Colab Notebooks,Amazon Sagemaker Studio Lab,Databricks Collaborative Notebooks'
#  'Azure Notebooks,IBM Watson Studio,Google Cloud Vertex AI Workbench,Databricks Collaborative Notebooks'
#  'Kaggle Notebooks,Gradient Notebooks'
#  'Kaggle Notebooks,Colab Notebooks,Azure Notebooks,Amazon Sagemaker Studio,Amazon Sagemaker Studio Lab,Amazon EMR Notebooks,Databricks Collaborative Notebooks'
#  'Kaggle Notebooks,Colab Notebooks,Amazon Sagemaker Studio,Amazon EMR Notebooks,Noteable Notebooks,Deepnote Notebooks,Gradient Notebooks'
#  'Kaggle Notebooks,Colab Notebooks,IBM Watson Studio,Amazon Sagemaker Studio'
#  'Kaggle Notebooks,Colab Notebooks,Amazon EMR Notebooks'
#  'Amazon Sagemaker Studio,Gradient Notebooks'
#  'Kaggle Notebooks,Amazon EMR Notebooks,Noteable Notebooks'
#  'Colab Notebooks,Amazon EMR Notebooks'
#  'Kaggle Notebooks,Colab Notebooks,Azure Notebooks,Code Ocean,IBM Watson Studio,Databricks Collaborative Notebooks'
#  'Kaggle Notebooks,Colab Notebooks,Azure Notebooks,Amazon Sagemaker Studio'
#  'Kaggle Notebooks,Colab Notebooks,IBM Watson Studio,Google Cloud Vertex AI Workbench'
#  'Azure Notebooks,Noteable Notebooks'
#  'Kaggle Notebooks,Colab Notebooks,Azure Notebooks,IBM Watson Studio,Amazon Sagemaker Studio,Noteable Notebooks,Databricks Collaborative Notebooks'
#  'Kaggle Notebooks,Noteable Notebooks,Gradient Notebooks'
#  'Amazon Sagemaker Studio Lab,Databricks Collaborative Notebooks'
#  'Azure Notebooks,Amazon EMR Notebooks'
#  'Kaggle Notebooks,Colab Notebooks,IBM Watson Studio,Amazon Sagemaker Studio,Amazon Sagemaker Studio Lab,Google Cloud Vertex AI Workbench'
#  'Kaggle Notebooks,Colab Notebooks,Azure Notebooks,IBM Watson Studio,Gradient Notebooks'
#  'Kaggle Notebooks,IBM Watson Studio,Amazon EMR Notebooks,Google Cloud Vertex AI Workbench,Noteable Notebooks,Databricks Collaborative Notebooks'
#  'Amazon EMR Notebooks' 'Azure Notebooks,Code Ocean'
#  'Kaggle Notebooks,Colab Notebooks,Amazon Sagemaker Studio,Google Cloud Vertex AI Workbench'
#  'Code Ocean,Amazon Sagemaker Studio,Google Cloud Vertex AI Workbench,Noteable Notebooks'
#  'Amazon EMR Notebooks,Gradient Notebooks'
#  'Kaggle Notebooks,IBM Watson Studio,Google Cloud Vertex AI Workbench,Databricks Collaborative Notebooks'
#  'Kaggle Notebooks,Azure Notebooks,Google Cloud Vertex AI Workbench,Noteable Notebooks'
#  'Kaggle Notebooks,Colab Notebooks,Azure Notebooks,Amazon Sagemaker Studio Lab'
#  'Kaggle Notebooks,IBM Watson Studio,Google Cloud Vertex AI Workbench'
#  'Amazon Sagemaker Studio,Amazon Sagemaker Studio Lab,Deepnote Notebooks'
#  'Kaggle Notebooks,Azure Notebooks,Amazon Sagemaker Studio Lab,Google Cloud Vertex AI Workbench'
#  'Kaggle Notebooks,Azure Notebooks,Other'
#  'Kaggle Notebooks,Colab Notebooks,IBM Watson Studio,Deepnote Notebooks'
#  'Kaggle Notebooks,Amazon Sagemaker Studio,Amazon Sagemaker Studio Lab,Amazon EMR Notebooks'
#  'Kaggle Notebooks,Azure Notebooks,Code Ocean,Hex Workspaces'
#  'Kaggle Notebooks,Colab Notebooks,Azure Notebooks,Deepnote Notebooks'
#  'Kaggle Notebooks,Colab Notebooks,Google Cloud Vertex AI Workbench,Other'
#  'Kaggle Notebooks,Google Cloud Vertex AI Workbench,Noteable Notebooks'
#  'Code Ocean,IBM Watson Studio'
#  'Kaggle Notebooks,Colab Notebooks,Azure Notebooks,IBM Watson Studio,Google Cloud Vertex AI Workbench,Deepnote Notebooks'
#  'Kaggle Notebooks,Google Cloud Vertex AI Workbench,Gradient Notebooks'
#  'Kaggle Notebooks,Colab Notebooks,Azure Notebooks,IBM Watson Studio,Google Cloud Vertex AI Workbench'
#  'Kaggle Notebooks,Amazon Sagemaker Studio,Amazon EMR Notebooks'
#  'Kaggle Notebooks,Colab Notebooks,Azure Notebooks,Amazon EMR Notebooks'
#  'Kaggle Notebooks,Colab Notebooks,Azure Notebooks,IBM Watson Studio,Databricks Collaborative Notebooks'
#  'Kaggle Notebooks,Azure Notebooks,Amazon Sagemaker Studio,Amazon Sagemaker Studio Lab,Google Cloud Vertex AI Workbench'
#  'Kaggle Notebooks,Colab Notebooks,Amazon Sagemaker Studio,Amazon Sagemaker Studio Lab,Databricks Collaborative Notebooks'
#  'Kaggle Notebooks,Colab Notebooks,Azure Notebooks,IBM Watson Studio'
#  'Amazon Sagemaker Studio,Amazon Sagemaker Studio Lab,Databricks Collaborative Notebooks'
#  'Amazon Sagemaker Studio Lab,Amazon EMR Notebooks,Google Cloud Vertex AI Workbench,Other'
#  'Kaggle Notebooks,Azure Notebooks,IBM Watson Studio,Amazon Sagemaker Studio,Amazon Sagemaker Studio Lab,Amazon EMR Notebooks,Databricks Collaborative Notebooks,Gradient Notebooks'
#  'Kaggle Notebooks,Colab Notebooks,Azure Notebooks,Amazon Sagemaker Studio,Amazon Sagemaker Studio Lab,Amazon EMR Notebooks'
#  'Colab Notebooks,Amazon Sagemaker Studio,Amazon Sagemaker Studio Lab,Amazon EMR Notebooks'
#  'Kaggle Notebooks,Amazon Sagemaker Studio Lab,Amazon EMR Notebooks'
#  'Kaggle Notebooks,Azure Notebooks,Amazon EMR Notebooks,Databricks Collaborative Notebooks'
#  'Azure Notebooks,Amazon Sagemaker Studio,Amazon Sagemaker Studio Lab'
#  'IBM Watson Studio,Other'
#  'Kaggle Notebooks,Colab Notebooks,Azure Notebooks,Amazon Sagemaker Studio,Amazon Sagemaker Studio Lab,Google Cloud Vertex AI Workbench,Databricks Collaborative Notebooks'
#  'Colab Notebooks,Azure Notebooks,IBM Watson Studio,Google Cloud Vertex AI Workbench,Databricks Collaborative Notebooks'
#  'Kaggle Notebooks,Colab Notebooks,Google Cloud Vertex AI Workbench,Noteable Notebooks,Databricks Collaborative Notebooks'
#  'IBM Watson Studio,Amazon EMR Notebooks'
#  'Kaggle Notebooks,Hex Workspaces,Gradient Notebooks'
#  'Kaggle Notebooks,Colab Notebooks,Azure Notebooks,Amazon Sagemaker Studio,Amazon Sagemaker Studio Lab,Noteable Notebooks,Databricks Collaborative Notebooks'
#  'Kaggle Notebooks,Azure Notebooks,Databricks Collaborative Notebooks'
#  'Colab Notebooks,Azure Notebooks,IBM Watson Studio,Google Cloud Vertex AI Workbench'
#  'Colab Notebooks,Azure Notebooks,IBM Watson Studio'
#  'Kaggle Notebooks,Code Ocean,Noteable Notebooks'
#  'Hex Workspaces,Databricks Collaborative Notebooks'
#  'Kaggle Notebooks,Azure Notebooks,Code Ocean'
#  'Kaggle Notebooks,Code Ocean,Amazon Sagemaker Studio,Amazon Sagemaker Studio Lab,Google Cloud Vertex AI Workbench'
#  'Amazon Sagemaker Studio Lab,Amazon EMR Notebooks'
#  'Colab Notebooks,Hex Workspaces,Gradient Notebooks'
#  'Azure Notebooks,Amazon Sagemaker Studio,Amazon EMR Notebooks,Google Cloud Vertex AI Workbench'
#  'Kaggle Notebooks,Code Ocean,Amazon Sagemaker Studio'
#  'Amazon Sagemaker Studio,Amazon Sagemaker Studio Lab,Amazon EMR Notebooks,Databricks Collaborative Notebooks'
#  'Colab Notebooks,Amazon Sagemaker Studio,Amazon EMR Notebooks'
#  'Colab Notebooks,Databricks Collaborative Notebooks,Other'
#  'IBM Watson Studio,Amazon Sagemaker Studio'
#  'Kaggle Notebooks,Colab Notebooks,Amazon EMR Notebooks,Databricks Collaborative Notebooks'
#  'Kaggle Notebooks,Colab Notebooks,Amazon Sagemaker Studio Lab,Google Cloud Vertex AI Workbench,Gradient Notebooks'
#  'Kaggle Notebooks,Colab Notebooks,Azure Notebooks,Code Ocean,IBM Watson Studio,Amazon Sagemaker Studio Lab,Amazon EMR Notebooks,Google Cloud Vertex AI Workbench,Noteable Notebooks,Databricks Collaborative Notebooks,Deepnote Notebooks,Gradient Notebooks'
#  'Azure Notebooks,Amazon Sagemaker Studio Lab'
#  'Kaggle Notebooks,Amazon Sagemaker Studio,Noteable Notebooks'
#  'Kaggle Notebooks,Colab Notebooks,Azure Notebooks,IBM Watson Studio,Amazon EMR Notebooks,Google Cloud Vertex AI Workbench'
#  'Colab Notebooks,Azure Notebooks,Amazon Sagemaker Studio,Amazon Sagemaker Studio Lab'
#  'Kaggle Notebooks,Amazon Sagemaker Studio,Google Cloud Vertex AI Workbench'
#  'Colab Notebooks,Azure Notebooks,Amazon EMR Notebooks'
#  'Kaggle Notebooks,Colab Notebooks,Azure Notebooks,IBM Watson Studio,Amazon EMR Notebooks'
#  'Kaggle Notebooks,Amazon Sagemaker Studio,Amazon Sagemaker Studio Lab,Google Cloud Vertex AI Workbench'
#  'Colab Notebooks,Code Ocean,Amazon EMR Notebooks'
#  'Kaggle Notebooks,Colab Notebooks,Azure Notebooks,Code Ocean,IBM Watson Studio,Amazon Sagemaker Studio,Google Cloud Vertex AI Workbench,Databricks Collaborative Notebooks,Deepnote Notebooks,Gradient Notebooks'
#  'Kaggle Notebooks,Colab Notebooks,Azure Notebooks,Amazon Sagemaker Studio Lab,Databricks Collaborative Notebooks'
#  'IBM Watson Studio,Amazon Sagemaker Studio,Google Cloud Vertex AI Workbench'
#  'Amazon Sagemaker Studio,Google Cloud Vertex AI Workbench,Databricks Collaborative Notebooks'
#  'Colab Notebooks,Amazon Sagemaker Studio,Gradient Notebooks'
#  'Kaggle Notebooks,Amazon EMR Notebooks,Databricks Collaborative Notebooks'
#  'Kaggle Notebooks,Amazon Sagemaker Studio Lab,Google Cloud Vertex AI Workbench'
#  'Kaggle Notebooks,Colab Notebooks,Noteable Notebooks,Databricks Collaborative Notebooks'
#  'Kaggle Notebooks,Colab Notebooks,Hex Workspaces'
#  'Azure Notebooks,Code Ocean,Amazon Sagemaker Studio Lab,Amazon EMR Notebooks,Google Cloud Vertex AI Workbench'
#  'Kaggle Notebooks,Azure Notebooks,Deepnote Notebooks'
#  'Kaggle Notebooks,Code Ocean,IBM Watson Studio,Amazon Sagemaker Studio,Google Cloud Vertex AI Workbench,Databricks Collaborative Notebooks'
#  'Kaggle Notebooks,Code Ocean,Hex Workspaces'
#  'Kaggle Notebooks,Colab Notebooks,Azure Notebooks,Amazon Sagemaker Studio Lab,Amazon EMR Notebooks,Google Cloud Vertex AI Workbench,Other'
#  'Kaggle Notebooks,Colab Notebooks,Azure Notebooks,Noteable Notebooks,Databricks Collaborative Notebooks'
#  'Kaggle Notebooks,Code Ocean,Deepnote Notebooks'
#  'Kaggle Notebooks,Colab Notebooks,Code Ocean,IBM Watson Studio,Amazon Sagemaker Studio,Amazon Sagemaker Studio Lab,Amazon EMR Notebooks,Google Cloud Vertex AI Workbench,Hex Workspaces,Noteable Notebooks,Databricks Collaborative Notebooks,Deepnote Notebooks,Gradient Notebooks'
#  'Kaggle Notebooks,Noteable Notebooks,Other'
#  'Azure Notebooks,Gradient Notebooks'
#  'Kaggle Notebooks,Colab Notebooks,Azure Notebooks,Amazon Sagemaker Studio Lab,Amazon EMR Notebooks'
#  'Amazon Sagemaker Studio Lab,Google Cloud Vertex AI Workbench'
#  'Azure Notebooks,Amazon Sagemaker Studio,Amazon EMR Notebooks'
#  'Kaggle Notebooks,Colab Notebooks,Google Cloud Vertex AI Workbench,Databricks Collaborative Notebooks,Deepnote Notebooks'
#  'Kaggle Notebooks,Colab Notebooks,Azure Notebooks,Google Cloud Vertex AI Workbench,Databricks Collaborative Notebooks'
#  'Amazon EMR Notebooks,Deepnote Notebooks'
#  'Kaggle Notebooks,Colab Notebooks,Azure Notebooks,Code Ocean'
#  'IBM Watson Studio,Amazon Sagemaker Studio Lab,Other'
#  'Kaggle Notebooks,Colab Notebooks,Azure Notebooks,IBM Watson Studio,Amazon Sagemaker Studio'
#  'Kaggle Notebooks,Colab Notebooks,Azure Notebooks,IBM Watson Studio,Amazon Sagemaker Studio,Amazon Sagemaker Studio Lab,Amazon EMR Notebooks,Hex Workspaces,Noteable Notebooks,Databricks Collaborative Notebooks,Deepnote Notebooks,Gradient Notebooks,Other'
#  'Kaggle Notebooks,Code Ocean,Google Cloud Vertex AI Workbench'
#  'Kaggle Notebooks,Colab Notebooks,Hex Workspaces,Databricks Collaborative Notebooks'
#  'Kaggle Notebooks,Colab Notebooks,Amazon Sagemaker Studio,Amazon Sagemaker Studio Lab,Amazon EMR Notebooks,Google Cloud Vertex AI Workbench,Databricks Collaborative Notebooks'
#  'Kaggle Notebooks,Colab Notebooks,Azure Notebooks,Amazon Sagemaker Studio,Amazon Sagemaker Studio Lab,Google Cloud Vertex AI Workbench'
#  'Kaggle Notebooks,Colab Notebooks,Amazon EMR Notebooks,Google Cloud Vertex AI Workbench'
#  'Kaggle Notebooks,Colab Notebooks,IBM Watson Studio,Amazon EMR Notebooks,Google Cloud Vertex AI Workbench,Databricks Collaborative Notebooks'
#  'Kaggle Notebooks,Colab Notebooks,Azure Notebooks,Code Ocean,Google Cloud Vertex AI Workbench'
#  'Kaggle Notebooks,Colab Notebooks,IBM Watson Studio,Databricks Collaborative Notebooks'
#  'Code Ocean,Google Cloud Vertex AI Workbench'
#  'Kaggle Notebooks,Amazon Sagemaker Studio Lab,Noteable Notebooks'
#  'Kaggle Notebooks,Azure Notebooks,Amazon Sagemaker Studio Lab'
#  'Azure Notebooks,Code Ocean,IBM Watson Studio,Google Cloud Vertex AI Workbench,Noteable Notebooks,Deepnote Notebooks'
#  'Azure Notebooks,Amazon Sagemaker Studio Lab,Google Cloud Vertex AI Workbench'
#  'Kaggle Notebooks,Google Cloud Vertex AI Workbench,Databricks Collaborative Notebooks'
#  'Azure Notebooks,Code Ocean,Amazon Sagemaker Studio'
#  'Amazon Sagemaker Studio,Google Cloud Vertex AI Workbench'
#  'Colab Notebooks,Azure Notebooks,Amazon Sagemaker Studio'
#  'Kaggle Notebooks,Google Cloud Vertex AI Workbench,Deepnote Notebooks'
#  'Kaggle Notebooks,Colab Notebooks,Azure Notebooks,Google Cloud Vertex AI Workbench,Noteable Notebooks,Databricks Collaborative Notebooks,Deepnote Notebooks'
#  'Kaggle Notebooks,Colab Notebooks,Databricks Collaborative Notebooks,Deepnote Notebooks'
#  'Kaggle Notebooks,Azure Notebooks,Amazon Sagemaker Studio'
#  'Colab Notebooks,Hex Workspaces'
#  'Kaggle Notebooks,Amazon Sagemaker Studio,Deepnote Notebooks'
#  'Kaggle Notebooks,IBM Watson Studio,Noteable Notebooks,Gradient Notebooks'
#  'Kaggle Notebooks,Colab Notebooks,Amazon Sagemaker Studio,Google Cloud Vertex AI Workbench,Gradient Notebooks'
#  'Colab Notebooks,Azure Notebooks,Code Ocean,Databricks Collaborative Notebooks'
#  'Kaggle Notebooks,Colab Notebooks,Azure Notebooks,Code Ocean,IBM Watson Studio,Amazon Sagemaker Studio,Amazon EMR Notebooks,Databricks Collaborative Notebooks,Deepnote Notebooks'
#  'Kaggle Notebooks,Colab Notebooks,IBM Watson Studio,Google Cloud Vertex AI Workbench,Databricks Collaborative Notebooks'
#  'Kaggle Notebooks,Colab Notebooks,Amazon Sagemaker Studio,Amazon Sagemaker Studio Lab,Google Cloud Vertex AI Workbench'
#  'Kaggle Notebooks,Azure Notebooks,Amazon EMR Notebooks'
#  'Kaggle Notebooks,Colab Notebooks,Azure Notebooks,Code Ocean,Noteable Notebooks,Gradient Notebooks'
#  'Kaggle Notebooks,IBM Watson Studio,Amazon Sagemaker Studio'
#  'Kaggle Notebooks,Colab Notebooks,Azure Notebooks,Amazon Sagemaker Studio,Amazon Sagemaker Studio Lab'
#  'Deepnote Notebooks,Gradient Notebooks'
#  'Kaggle Notebooks,Code Ocean,Amazon Sagemaker Studio Lab,Google Cloud Vertex AI Workbench,Hex Workspaces,Gradient Notebooks'
#  'Colab Notebooks,Amazon Sagemaker Studio,Amazon Sagemaker Studio Lab,Amazon EMR Notebooks,Databricks Collaborative Notebooks'
#  'Kaggle Notebooks,IBM Watson Studio,Amazon Sagemaker Studio Lab'
#  'Databricks Collaborative Notebooks,Other'
#  'Azure Notebooks,IBM Watson Studio,Amazon EMR Notebooks'
#  'Kaggle Notebooks,Azure Notebooks,Code Ocean,Google Cloud Vertex AI Workbench'
#  'Kaggle Notebooks,Colab Notebooks,IBM Watson Studio,Amazon Sagemaker Studio,Deepnote Notebooks,Gradient Notebooks'
#  'Kaggle Notebooks,Colab Notebooks,Azure Notebooks,Code Ocean,IBM Watson Studio,Amazon Sagemaker Studio,Amazon Sagemaker Studio Lab,Google Cloud Vertex AI Workbench,Noteable Notebooks,Databricks Collaborative Notebooks,Deepnote Notebooks,Gradient Notebooks'
#  'Azure Notebooks,Amazon EMR Notebooks,Google Cloud Vertex AI Workbench'
#  'Kaggle Notebooks,Google Cloud Vertex AI Workbench,Other'
#  'IBM Watson Studio,Noteable Notebooks'
#  'Colab Notebooks,Azure Notebooks,Amazon Sagemaker Studio,Amazon Sagemaker Studio Lab,Google Cloud Vertex AI Workbench,Databricks Collaborative Notebooks'
#  'Kaggle Notebooks,Colab Notebooks,Azure Notebooks,Code Ocean,IBM Watson Studio,Amazon Sagemaker Studio,Google Cloud Vertex AI Workbench,Databricks Collaborative Notebooks,Deepnote Notebooks'
#  'Kaggle Notebooks,Colab Notebooks,Amazon Sagemaker Studio Lab,Google Cloud Vertex AI Workbench,Noteable Notebooks'
#  'Kaggle Notebooks,Colab Notebooks,Azure Notebooks,Code Ocean,IBM Watson Studio,Amazon Sagemaker Studio,Amazon Sagemaker Studio Lab,Amazon EMR Notebooks,Google Cloud Vertex AI Workbench,Hex Workspaces,Databricks Collaborative Notebooks,Gradient Notebooks'
#  'Kaggle Notebooks,Colab Notebooks,Azure Notebooks,Code Ocean,IBM Watson Studio,Amazon Sagemaker Studio Lab,Hex Workspaces'
#  'Colab Notebooks,Amazon Sagemaker Studio,Google Cloud Vertex AI Workbench,Deepnote Notebooks,Gradient Notebooks'
#  'Kaggle Notebooks,IBM Watson Studio,Amazon Sagemaker Studio Lab,Other'
#  'Amazon EMR Notebooks,Databricks Collaborative Notebooks'
#  'Kaggle Notebooks,Colab Notebooks,IBM Watson Studio,Amazon Sagemaker Studio Lab'
#  'Amazon EMR Notebooks,Other'
#  'Kaggle Notebooks,Hex Workspaces,Noteable Notebooks,Databricks Collaborative Notebooks,Deepnote Notebooks'
#  'Kaggle Notebooks,Colab Notebooks,Azure Notebooks,Noteable Notebooks'
#  'Kaggle Notebooks,Colab Notebooks,Amazon Sagemaker Studio Lab,Other'
#  'Kaggle Notebooks,Colab Notebooks,Hex Workspaces,Noteable Notebooks,Deepnote Notebooks'
#  'Kaggle Notebooks,Noteable Notebooks,Databricks Collaborative Notebooks'
#  'Kaggle Notebooks,IBM Watson Studio,Amazon Sagemaker Studio Lab,Google Cloud Vertex AI Workbench,Noteable Notebooks,Deepnote Notebooks'
#  'Kaggle Notebooks,Azure Notebooks,IBM Watson Studio,Amazon Sagemaker Studio,Amazon Sagemaker Studio Lab,Amazon EMR Notebooks,Databricks Collaborative Notebooks'
#  'Kaggle Notebooks,Colab Notebooks,Azure Notebooks,IBM Watson Studio,Amazon Sagemaker Studio Lab,Google Cloud Vertex AI Workbench,Databricks Collaborative Notebooks'
#  'Azure Notebooks,IBM Watson Studio,Amazon Sagemaker Studio,Amazon Sagemaker Studio Lab,Google Cloud Vertex AI Workbench'
#  'Kaggle Notebooks,Colab Notebooks,Google Cloud Vertex AI Workbench,Gradient Notebooks'
#  'Colab Notebooks,IBM Watson Studio,Google Cloud Vertex AI Workbench,Other'
#  'Kaggle Notebooks,Colab Notebooks,IBM Watson Studio,Amazon Sagemaker Studio Lab,Gradient Notebooks'
#  'Kaggle Notebooks,Azure Notebooks,Amazon Sagemaker Studio,Amazon Sagemaker Studio Lab,Databricks Collaborative Notebooks'
#  'Kaggle Notebooks,Colab Notebooks,Amazon EMR Notebooks,Google Cloud Vertex AI Workbench,Noteable Notebooks'
#  'Kaggle Notebooks,Colab Notebooks,Azure Notebooks,Amazon Sagemaker Studio,Amazon Sagemaker Studio Lab,Databricks Collaborative Notebooks'
#  'Kaggle Notebooks,Amazon Sagemaker Studio,Hex Workspaces,Noteable Notebooks'
#  'Kaggle Notebooks,Colab Notebooks,Amazon Sagemaker Studio,Other'
#  'Kaggle Notebooks,Amazon Sagemaker Studio,Amazon EMR Notebooks,Google Cloud Vertex AI Workbench'
#  'Azure Notebooks,IBM Watson Studio,Google Cloud Vertex AI Workbench'
#  'Amazon Sagemaker Studio Lab,Amazon EMR Notebooks,Databricks Collaborative Notebooks'
#  'Colab Notebooks,Azure Notebooks,IBM Watson Studio,Amazon EMR Notebooks'
#  'Kaggle Notebooks,Azure Notebooks,Amazon Sagemaker Studio,Amazon EMR Notebooks,Google Cloud Vertex AI Workbench,Databricks Collaborative Notebooks,Gradient Notebooks'
#  'Kaggle Notebooks,IBM Watson Studio,Amazon Sagemaker Studio,Google Cloud Vertex AI Workbench'
#  'Kaggle Notebooks,Amazon Sagemaker Studio,Amazon Sagemaker Studio Lab,Databricks Collaborative Notebooks'
#  'Kaggle Notebooks,Azure Notebooks,Noteable Notebooks'
#  'Kaggle Notebooks,Colab Notebooks,Databricks Collaborative Notebooks,Gradient Notebooks'
#  'Kaggle Notebooks,Azure Notebooks,IBM Watson Studio,Google Cloud Vertex AI Workbench,Deepnote Notebooks'
#  'Kaggle Notebooks,Azure Notebooks,Google Cloud Vertex AI Workbench,Databricks Collaborative Notebooks'
#  'Colab Notebooks,Google Cloud Vertex AI Workbench,Noteable Notebooks'
#  'Colab Notebooks,Amazon Sagemaker Studio Lab,Gradient Notebooks'
#  'Colab Notebooks,Amazon Sagemaker Studio Lab,Amazon EMR Notebooks'
#  'Kaggle Notebooks,IBM Watson Studio,Amazon Sagemaker Studio Lab,Noteable Notebooks'
#  'Kaggle Notebooks,Colab Notebooks,Code Ocean,IBM Watson Studio,Amazon Sagemaker Studio,Amazon Sagemaker Studio Lab,Google Cloud Vertex AI Workbench'
#  'Kaggle Notebooks,Colab Notebooks,Azure Notebooks,Amazon Sagemaker Studio Lab,Google Cloud Vertex AI Workbench'
#  'IBM Watson Studio,Amazon Sagemaker Studio Lab,Databricks Collaborative Notebooks'
#  'Noteable Notebooks,Gradient Notebooks'
#  'Kaggle Notebooks,Azure Notebooks,Code Ocean,IBM Watson Studio,Amazon EMR Notebooks,Noteable Notebooks'
#  'Kaggle Notebooks,Amazon Sagemaker Studio Lab,Databricks Collaborative Notebooks'
#  'Kaggle Notebooks,Colab Notebooks,Gradient Notebooks,Other'
#  'Kaggle Notebooks,Azure Notebooks,IBM Watson Studio,Google Cloud Vertex AI Workbench'
#  'Colab Notebooks,Azure Notebooks,Amazon Sagemaker Studio Lab,Databricks Collaborative Notebooks'
#  'Google Cloud Vertex AI Workbench,Hex Workspaces'
#  'Kaggle Notebooks,Colab Notebooks,Azure Notebooks,Google Cloud Vertex AI Workbench,Noteable Notebooks'
#  'Azure Notebooks,IBM Watson Studio,Amazon Sagemaker Studio,Amazon Sagemaker Studio Lab,Amazon EMR Notebooks,Google Cloud Vertex AI Workbench,Hex Workspaces,Databricks Collaborative Notebooks'
#  'Azure Notebooks,IBM Watson Studio,Noteable Notebooks'
#  'Kaggle Notebooks,Amazon Sagemaker Studio,Databricks Collaborative Notebooks,Gradient Notebooks'
#  'Kaggle Notebooks,Colab Notebooks,Azure Notebooks,Code Ocean,IBM Watson Studio,Amazon Sagemaker Studio,Google Cloud Vertex AI Workbench,Hex Workspaces,Noteable Notebooks,Databricks Collaborative Notebooks,Deepnote Notebooks,Gradient Notebooks'
#  'Colab Notebooks,Code Ocean,IBM Watson Studio,Amazon Sagemaker Studio Lab,Google Cloud Vertex AI Workbench'
#  'Colab Notebooks,IBM Watson Studio,Other'
#  'Amazon Sagemaker Studio Lab,Google Cloud Vertex AI Workbench,Deepnote Notebooks'
#  'Kaggle Notebooks,Colab Notebooks,Azure Notebooks,Noteable Notebooks,Databricks Collaborative Notebooks,Deepnote Notebooks'
#  'Kaggle Notebooks,Code Ocean,Gradient Notebooks'
#  'Kaggle Notebooks,Colab Notebooks,IBM Watson Studio,Gradient Notebooks'
#  'Kaggle Notebooks,Colab Notebooks,Amazon Sagemaker Studio,Amazon Sagemaker Studio Lab,Gradient Notebooks'
#  'Kaggle Notebooks,Colab Notebooks,IBM Watson Studio,Amazon Sagemaker Studio,Amazon Sagemaker Studio Lab,Amazon EMR Notebooks,Google Cloud Vertex AI Workbench'
#  'Kaggle Notebooks,Colab Notebooks,IBM Watson Studio,Amazon Sagemaker Studio,Amazon Sagemaker Studio Lab,Google Cloud Vertex AI Workbench,Databricks Collaborative Notebooks'
#  'Kaggle Notebooks,Colab Notebooks,Code Ocean,Google Cloud Vertex AI Workbench'
#  'Azure Notebooks,Other'
#  'Kaggle Notebooks,Colab Notebooks,IBM Watson Studio,Amazon Sagemaker Studio,Amazon Sagemaker Studio Lab,Deepnote Notebooks'
#  'Kaggle Notebooks,Colab Notebooks,Code Ocean,Amazon Sagemaker Studio,Noteable Notebooks'
#  'Colab Notebooks,IBM Watson Studio,Deepnote Notebooks'
#  'Kaggle Notebooks,Amazon EMR Notebooks,Google Cloud Vertex AI Workbench,Deepnote Notebooks'
#  'Kaggle Notebooks,Azure Notebooks,Amazon Sagemaker Studio,Noteable Notebooks,Other'
#  'Kaggle Notebooks,Colab Notebooks,Azure Notebooks,Code Ocean,IBM Watson Studio,Amazon Sagemaker Studio,Amazon EMR Notebooks,Google Cloud Vertex AI Workbench,Noteable Notebooks,Deepnote Notebooks'
#  'Code Ocean,Amazon Sagemaker Studio,Google Cloud Vertex AI Workbench,Noteable Notebooks,Gradient Notebooks'
#  'Amazon Sagemaker Studio,Amazon Sagemaker Studio Lab,Other'
#  'Kaggle Notebooks,Azure Notebooks,Amazon EMR Notebooks,Google Cloud Vertex AI Workbench'
#  'Kaggle Notebooks,Colab Notebooks,IBM Watson Studio,Hex Workspaces,Noteable Notebooks,Deepnote Notebooks'
#  'Kaggle Notebooks,Colab Notebooks,Azure Notebooks,Code Ocean,Amazon Sagemaker Studio,Amazon Sagemaker Studio Lab,Deepnote Notebooks,Gradient Notebooks'
#  'Colab Notebooks,Amazon Sagemaker Studio,Amazon Sagemaker Studio Lab,Amazon EMR Notebooks,Deepnote Notebooks'
#  'IBM Watson Studio,Databricks Collaborative Notebooks'
#  'Kaggle Notebooks,Colab Notebooks,IBM Watson Studio,Other'
#  'Colab Notebooks,Amazon Sagemaker Studio,Amazon Sagemaker Studio Lab,Deepnote Notebooks'
#  'Azure Notebooks,IBM Watson Studio,Amazon Sagemaker Studio'
#  'Kaggle Notebooks,Colab Notebooks,Amazon Sagemaker Studio,Gradient Notebooks'
#  'Colab Notebooks,Code Ocean,Amazon EMR Notebooks,Google Cloud Vertex AI Workbench'
#  'Kaggle Notebooks,Colab Notebooks,Azure Notebooks,IBM Watson Studio,Amazon Sagemaker Studio,Amazon Sagemaker Studio Lab,Amazon EMR Notebooks,Google Cloud Vertex AI Workbench,Databricks Collaborative Notebooks'
#  'Kaggle Notebooks,Colab Notebooks,Amazon Sagemaker Studio,Amazon EMR Notebooks,Gradient Notebooks'
#  'Colab Notebooks,Amazon Sagemaker Studio,Google Cloud Vertex AI Workbench'
#  'Kaggle Notebooks,Colab Notebooks,IBM Watson Studio,Google Cloud Vertex AI Workbench,Noteable Notebooks'
#  'Colab Notebooks,Amazon Sagemaker Studio,Noteable Notebooks'
#  'Kaggle Notebooks,Colab Notebooks,Azure Notebooks,IBM Watson Studio,Deepnote Notebooks'
#  'Azure Notebooks,IBM Watson Studio,Amazon EMR Notebooks,Google Cloud Vertex AI Workbench'
#  'Kaggle Notebooks,Colab Notebooks,Azure Notebooks,IBM Watson Studio,Databricks Collaborative Notebooks,Gradient Notebooks'
#  'Deepnote Notebooks,Other'
#  'Amazon Sagemaker Studio,Amazon Sagemaker Studio Lab,Noteable Notebooks'
#  'Kaggle Notebooks,Colab Notebooks,Databricks Collaborative Notebooks,Other'
#  'Kaggle Notebooks,Colab Notebooks,Hex Workspaces,Gradient Notebooks'
#  'Kaggle Notebooks,Colab Notebooks,Azure Notebooks,Code Ocean,IBM Watson Studio,Amazon Sagemaker Studio,Amazon Sagemaker Studio Lab,Amazon EMR Notebooks,Google Cloud Vertex AI Workbench,Hex Workspaces,Noteable Notebooks,Databricks Collaborative Notebooks,Deepnote Notebooks,Gradient Notebooks,Other'
#  'Colab Notebooks,Amazon EMR Notebooks,Google Cloud Vertex AI Workbench,Databricks Collaborative Notebooks'
#  'Colab Notebooks,Amazon Sagemaker Studio,Amazon EMR Notebooks,Databricks Collaborative Notebooks'
#  'Google Cloud Vertex AI Workbench,Other'
#  'Kaggle Notebooks,Colab Notebooks,Amazon EMR Notebooks,Other'
#  'Colab Notebooks,Azure Notebooks,Amazon EMR Notebooks,Google Cloud Vertex AI Workbench'
#  'Colab Notebooks,IBM Watson Studio,Databricks Collaborative Notebooks'
#  'Kaggle Notebooks,Colab Notebooks,Azure Notebooks,Amazon Sagemaker Studio,Amazon Sagemaker Studio Lab,Google Cloud Vertex AI Workbench,Deepnote Notebooks'
#  'Colab Notebooks,Amazon Sagemaker Studio,Amazon Sagemaker Studio Lab,Amazon EMR Notebooks,Google Cloud Vertex AI Workbench'
#  'Noteable Notebooks,Databricks Collaborative Notebooks,Deepnote Notebooks'
#  'Noteable Notebooks,Other'
#  'Colab Notebooks,Azure Notebooks,IBM Watson Studio,Amazon Sagemaker Studio,Amazon Sagemaker Studio Lab,Databricks Collaborative Notebooks'
#  'Kaggle Notebooks,Colab Notebooks,Azure Notebooks,Code Ocean,IBM Watson Studio,Amazon Sagemaker Studio,Amazon Sagemaker Studio Lab,Amazon EMR Notebooks,Google Cloud Vertex AI Workbench,Gradient Notebooks'
#  'Kaggle Notebooks,Colab Notebooks,Code Ocean,IBM Watson Studio'
#  'Kaggle Notebooks,Databricks Collaborative Notebooks,Deepnote Notebooks,Gradient Notebooks'
#  'Colab Notebooks,Azure Notebooks,IBM Watson Studio,Amazon Sagemaker Studio Lab'
#  'Colab Notebooks,IBM Watson Studio,Amazon Sagemaker Studio Lab,Google Cloud Vertex AI Workbench,Noteable Notebooks'
#  'Kaggle Notebooks,Colab Notebooks,Code Ocean,IBM Watson Studio,Google Cloud Vertex AI Workbench,Noteable Notebooks,Databricks Collaborative Notebooks'
#  'Kaggle Notebooks,Colab Notebooks,Azure Notebooks,IBM Watson Studio,Google Cloud Vertex AI Workbench,Databricks Collaborative Notebooks'
#  'Kaggle Notebooks,Azure Notebooks,IBM Watson Studio,Amazon Sagemaker Studio,Amazon Sagemaker Studio Lab,Databricks Collaborative Notebooks'
#  'Azure Notebooks,Amazon Sagemaker Studio Lab,Databricks Collaborative Notebooks'
#  'Colab Notebooks,Noteable Notebooks,Gradient Notebooks'
#  'Kaggle Notebooks,Azure Notebooks,IBM Watson Studio,Amazon Sagemaker Studio,Google Cloud Vertex AI Workbench'
#  'Kaggle Notebooks,IBM Watson Studio,Google Cloud Vertex AI Workbench,Noteable Notebooks'
#  'Kaggle Notebooks,Colab Notebooks,Amazon Sagemaker Studio,Amazon Sagemaker Studio Lab,Noteable Notebooks,Databricks Collaborative Notebooks,Deepnote Notebooks,Gradient Notebooks'
#  'Kaggle Notebooks,Hex Workspaces'
#  'Kaggle Notebooks,Colab Notebooks,Databricks Collaborative Notebooks,Deepnote Notebooks,Gradient Notebooks'
#  'Kaggle Notebooks,IBM Watson Studio,Amazon Sagemaker Studio,Amazon Sagemaker Studio Lab'
#  'Amazon Sagemaker Studio,Noteable Notebooks'
#  'Kaggle Notebooks,Code Ocean,Noteable Notebooks,Databricks Collaborative Notebooks'
#  'Colab Notebooks,Azure Notebooks,Amazon Sagemaker Studio Lab,Amazon EMR Notebooks,Google Cloud Vertex AI Workbench'
#  'Kaggle Notebooks,Colab Notebooks,Azure Notebooks,IBM Watson Studio,Amazon Sagemaker Studio,Amazon Sagemaker Studio Lab,Google Cloud Vertex AI Workbench'
#  'Amazon Sagemaker Studio Lab,Gradient Notebooks'
#  'Colab Notebooks,Azure Notebooks,Amazon EMR Notebooks,Google Cloud Vertex AI Workbench,Deepnote Notebooks'
#  'Colab Notebooks,Azure Notebooks,Google Cloud Vertex AI Workbench,Noteable Notebooks'
#  'Kaggle Notebooks,Amazon Sagemaker Studio,Google Cloud Vertex AI Workbench,Noteable Notebooks,Databricks Collaborative Notebooks'
#  'Code Ocean,Noteable Notebooks'
#  'Azure Notebooks,Code Ocean,Google Cloud Vertex AI Workbench'
#  'Kaggle Notebooks,Colab Notebooks,Amazon Sagemaker Studio,Databricks Collaborative Notebooks'
#  'Azure Notebooks,Amazon Sagemaker Studio,Google Cloud Vertex AI Workbench'
#  'Kaggle Notebooks,Colab Notebooks,Hex Workspaces,Deepnote Notebooks,Gradient Notebooks'
#  'Kaggle Notebooks,Colab Notebooks,Noteable Notebooks,Deepnote Notebooks'
#  'Kaggle Notebooks,Code Ocean,Amazon Sagemaker Studio Lab,Deepnote Notebooks,Other'
#  'Code Ocean,Other'
#  'Amazon Sagemaker Studio Lab,Amazon EMR Notebooks,Noteable Notebooks'
#  'Kaggle Notebooks,Colab Notebooks,Azure Notebooks,Amazon Sagemaker Studio,Amazon Sagemaker Studio Lab,Google Cloud Vertex AI Workbench,Databricks Collaborative Notebooks,Deepnote Notebooks'
#  'Azure Notebooks,IBM Watson Studio,Google Cloud Vertex AI Workbench,Hex Workspaces,Databricks Collaborative Notebooks,Deepnote Notebooks'
#  'Kaggle Notebooks,Colab Notebooks,Azure Notebooks,Google Cloud Vertex AI Workbench,Databricks Collaborative Notebooks,Deepnote Notebooks'
#  'Kaggle Notebooks,Colab Notebooks,Azure Notebooks,Amazon Sagemaker Studio,Google Cloud Vertex AI Workbench'
#  'Kaggle Notebooks,Colab Notebooks,IBM Watson Studio,Amazon Sagemaker Studio,Google Cloud Vertex AI Workbench'
#  'Azure Notebooks,Amazon EMR Notebooks,Databricks Collaborative Notebooks'
#  'Kaggle Notebooks,Azure Notebooks,Google Cloud Vertex AI Workbench,Deepnote Notebooks'
#  'Kaggle Notebooks,Azure Notebooks,Amazon Sagemaker Studio,Amazon Sagemaker Studio Lab,Amazon EMR Notebooks,Databricks Collaborative Notebooks'
#  'Kaggle Notebooks,Colab Notebooks,IBM Watson Studio,Amazon Sagemaker Studio,Amazon Sagemaker Studio Lab,Noteable Notebooks'
#  'Colab Notebooks,Azure Notebooks,IBM Watson Studio,Amazon Sagemaker Studio,Amazon Sagemaker Studio Lab,Google Cloud Vertex AI Workbench'
#  'Colab Notebooks,Deepnote Notebooks,Gradient Notebooks'
#  'Kaggle Notebooks,Colab Notebooks,IBM Watson Studio,Amazon Sagemaker Studio,Amazon EMR Notebooks'
#  'Kaggle Notebooks,Amazon Sagemaker Studio,Databricks Collaborative Notebooks,Other'
#  'Kaggle Notebooks,IBM Watson Studio,Deepnote Notebooks'
#  'Colab Notebooks,Amazon Sagemaker Studio,Amazon Sagemaker Studio Lab,Google Cloud Vertex AI Workbench,Databricks Collaborative Notebooks,Gradient Notebooks'
#  'Amazon Sagemaker Studio,Deepnote Notebooks'
#  'Colab Notebooks,IBM Watson Studio,Amazon Sagemaker Studio,Amazon Sagemaker Studio Lab,Amazon EMR Notebooks,Databricks Collaborative Notebooks'
#  'Azure Notebooks,IBM Watson Studio,Google Cloud Vertex AI Workbench,Hex Workspaces,Deepnote Notebooks'
#  'Kaggle Notebooks,Azure Notebooks,IBM Watson Studio,Noteable Notebooks,Databricks Collaborative Notebooks'
#  'Colab Notebooks,Amazon EMR Notebooks,Databricks Collaborative Notebooks'
#  'Amazon Sagemaker Studio,Databricks Collaborative Notebooks,Other'
#  'Kaggle Notebooks,Amazon Sagemaker Studio,Google Cloud Vertex AI Workbench,Noteable Notebooks'
#  'Kaggle Notebooks,Colab Notebooks,Code Ocean,Google Cloud Vertex AI Workbench,Databricks Collaborative Notebooks'
#  'Kaggle Notebooks,Colab Notebooks,Azure Notebooks,IBM Watson Studio,Amazon Sagemaker Studio,Amazon Sagemaker Studio Lab,Amazon EMR Notebooks,Hex Workspaces,Databricks Collaborative Notebooks,Deepnote Notebooks,Gradient Notebooks'
#  'Kaggle Notebooks,Colab Notebooks,IBM Watson Studio,Amazon Sagemaker Studio Lab,Google Cloud Vertex AI Workbench'
#  'Colab Notebooks,IBM Watson Studio,Gradient Notebooks'
#  'Kaggle Notebooks,Colab Notebooks,Amazon Sagemaker Studio Lab,Amazon EMR Notebooks,Other'
#  'Colab Notebooks,Azure Notebooks,IBM Watson Studio,Amazon Sagemaker Studio,Amazon EMR Notebooks,Google Cloud Vertex AI Workbench,Gradient Notebooks'
#  'Colab Notebooks,Code Ocean,IBM Watson Studio'
#  'Kaggle Notebooks,Google Cloud Vertex AI Workbench,Hex Workspaces,Deepnote Notebooks'
#  'Kaggle Notebooks,Colab Notebooks,Azure Notebooks,IBM Watson Studio,Amazon Sagemaker Studio,Amazon Sagemaker Studio Lab,Google Cloud Vertex AI Workbench,Gradient Notebooks'
#  'Kaggle Notebooks,Colab Notebooks,Azure Notebooks,IBM Watson Studio,Amazon Sagemaker Studio,Hex Workspaces,Noteable Notebooks,Databricks Collaborative Notebooks'
#  'Noteable Notebooks,Deepnote Notebooks'
#  'Kaggle Notebooks,Code Ocean,Google Cloud Vertex AI Workbench,Hex Workspaces,Gradient Notebooks'
#  'Kaggle Notebooks,Colab Notebooks,Azure Notebooks,Amazon Sagemaker Studio,Amazon EMR Notebooks'
#  'Kaggle Notebooks,IBM Watson Studio,Noteable Notebooks'
#  'Kaggle Notebooks,Colab Notebooks,Code Ocean,Amazon Sagemaker Studio,Amazon Sagemaker Studio Lab,Databricks Collaborative Notebooks'
#  'IBM Watson Studio,Amazon EMR Notebooks,Hex Workspaces'
#  'Kaggle Notebooks,Azure Notebooks,Hex Workspaces'
#  'IBM Watson Studio,Amazon Sagemaker Studio Lab,Google Cloud Vertex AI Workbench,Databricks Collaborative Notebooks'
#  'Kaggle Notebooks,Amazon EMR Notebooks,Other'
#  'Kaggle Notebooks,Colab Notebooks,Azure Notebooks,Code Ocean,Amazon Sagemaker Studio,Amazon Sagemaker Studio Lab,Amazon EMR Notebooks,Google Cloud Vertex AI Workbench,Noteable Notebooks,Deepnote Notebooks,Other'
#  'Amazon Sagemaker Studio,Google Cloud Vertex AI Workbench,Noteable Notebooks'
#  'Kaggle Notebooks,Amazon Sagemaker Studio Lab,Google Cloud Vertex AI Workbench,Hex Workspaces,Noteable Notebooks,Databricks Collaborative Notebooks,Deepnote Notebooks'
#  'Azure Notebooks,Amazon Sagemaker Studio,Amazon Sagemaker Studio Lab,Google Cloud Vertex AI Workbench'
#  'Kaggle Notebooks,IBM Watson Studio,Amazon Sagemaker Studio,Google Cloud Vertex AI Workbench,Gradient Notebooks'
#  'Colab Notebooks,Amazon Sagemaker Studio Lab,Deepnote Notebooks'
#  'Colab Notebooks,Google Cloud Vertex AI Workbench,Deepnote Notebooks'
#  'Kaggle Notebooks,Colab Notebooks,Azure Notebooks,Amazon Sagemaker Studio Lab,Amazon EMR Notebooks,Hex Workspaces'
#  'Kaggle Notebooks,IBM Watson Studio,Databricks Collaborative Notebooks'
#  'Kaggle Notebooks,Colab Notebooks,Amazon Sagemaker Studio,Amazon Sagemaker Studio Lab,Google Cloud Vertex AI Workbench,Noteable Notebooks,Other'
#  'Kaggle Notebooks,Colab Notebooks,Amazon EMR Notebooks,Noteable Notebooks'
#  'IBM Watson Studio,Google Cloud Vertex AI Workbench,Deepnote Notebooks'
#  'Kaggle Notebooks,Colab Notebooks,Azure Notebooks,Amazon Sagemaker Studio,Amazon Sagemaker Studio Lab,Amazon EMR Notebooks,Google Cloud Vertex AI Workbench'
#  'Kaggle Notebooks,Google Cloud Vertex AI Workbench,Hex Workspaces,Noteable Notebooks,Gradient Notebooks'
#  'Kaggle Notebooks,Amazon Sagemaker Studio Lab,Google Cloud Vertex AI Workbench,Databricks Collaborative Notebooks'
#  'Colab Notebooks,Azure Notebooks,IBM Watson Studio,Amazon Sagemaker Studio Lab,Amazon EMR Notebooks,Databricks Collaborative Notebooks'
#  'Kaggle Notebooks,Colab Notebooks,Azure Notebooks,IBM Watson Studio,Amazon Sagemaker Studio,Amazon Sagemaker Studio Lab,Amazon EMR Notebooks,Databricks Collaborative Notebooks'
#  'Colab Notebooks,Azure Notebooks,Amazon Sagemaker Studio,Amazon Sagemaker Studio Lab,Amazon EMR Notebooks,Google Cloud Vertex AI Workbench'
#  'Kaggle Notebooks,Google Cloud Vertex AI Workbench,Noteable Notebooks,Gradient Notebooks'
#  'Kaggle Notebooks,Deepnote Notebooks,Gradient Notebooks'
#  'Kaggle Notebooks,Azure Notebooks,IBM Watson Studio,Amazon Sagemaker Studio,Amazon Sagemaker Studio Lab,Amazon EMR Notebooks,Google Cloud Vertex AI Workbench,Hex Workspaces,Noteable Notebooks,Deepnote Notebooks,Gradient Notebooks'
#  'Azure Notebooks,Code Ocean,Amazon Sagemaker Studio Lab,Amazon EMR Notebooks,Noteable Notebooks'
#  'IBM Watson Studio,Amazon Sagemaker Studio Lab'
#  'Colab Notebooks,Azure Notebooks,Code Ocean,Amazon Sagemaker Studio,Amazon EMR Notebooks,Noteable Notebooks,Deepnote Notebooks,Gradient Notebooks'
#  'Kaggle Notebooks,Colab Notebooks,IBM Watson Studio,Amazon EMR Notebooks,Databricks Collaborative Notebooks'
#  'Azure Notebooks,IBM Watson Studio,Amazon Sagemaker Studio Lab'
# ...
#  'Comet.ml,TensorBoard,ClearML,Aporia'
#  'Neptune.ai,Weights & Biases,Comet.ml,TensorBoard,Guild.ai,ClearML,MLflow,Aporia,Evidently AI,Arize,WhyLabs,Fiddler,DVC'
#  'Neptune.ai,TensorBoard' 'Weights & Biases,TensorBoard,MLflow'
#  'Weights & Biases,MLflow,Fiddler'
#  'Neptune.ai,Weights & Biases,Comet.ml,TensorBoard,ClearML,MLflow,WhyLabs,Fiddler'
#  'Weights & Biases,ClearML,MLflow' 'Weights & Biases,DVC'
#  'Weights & Biases,Comet.ml,TensorBoard,Evidently AI'
#  'TensorBoard,MLflow,Evidently AI,DVC' 'Neptune.ai,TensorBoard,Fiddler'
#  'TensorBoard,Other' 'TensorBoard,MLflow,Evidently AI' 'WhyLabs'
#  'Weights & Biases,MLflow,DVC' 'Neptune.ai,Weights & Biases' 'Aporia'
#  'Neptune.ai,Weights & Biases,TensorBoard,Guild.ai,MLflow,Evidently AI,Arize'
#  'Arize' 'Neptune.ai,TensorBoard,MLflow' 'Comet.ml,TensorBoard,MLflow'
#  'TensorBoard,Fiddler' 'Evidently AI' 'WhyLabs,Fiddler'
#  'TensorBoard,ClearML,Fiddler' 'TensorBoard,DVC' 'Comet.ml,TensorBoard'
#  'ClearML,DVC' 'Comet.ml' 'TensorBoard,MLflow,DVC' 'Neptune.ai,WhyLabs'
#  'Comet.ml,TensorBoard,MLflow,Evidently AI,DVC'
#  'Neptune.ai,TensorBoard,DVC'
#  'Neptune.ai,Weights & Biases,TensorBoard,ClearML,MLflow'
#  'Neptune.ai,ClearML,MLflow,WhyLabs' 'MLflow,Fiddler' 'Comet.ml,Guild.ai'
#  'Guild.ai,MLflow' 'TensorBoard,ClearML,MLflow,Aporia' 'Guild.ai'
#  'Weights & Biases,ClearML,Arize' 'TensorBoard,ClearML,Arize,DVC'
#  'Weights & Biases,ClearML,Evidently AI,Fiddler'
#  'Weights & Biases,TensorBoard,ClearML,MLflow' 'Arize,Fiddler,DVC'
#  'Comet.ml,MLflow' 'TensorBoard,MLflow,Arize' 'TensorBoard,ClearML'
#  'Neptune.ai,Weights & Biases,Comet.ml,TensorBoard,ClearML,MLflow,Aporia,Evidently AI,Arize,WhyLabs,DVC'
#  'TensorBoard,Arize' 'Neptune.ai,ClearML,MLflow,DVC' 'Neptune.ai,Comet.ml'
#  'Comet.ml,TensorBoard,ClearML,MLflow' 'TensorBoard,ClearML,MLflow'
#  'Weights & Biases,Guild.ai,ClearML' 'Neptune.ai,DVC'
#  'Neptune.ai,TensorBoard,Aporia' 'Comet.ml,MLflow,Arize,Fiddler'
#  'Neptune.ai,ClearML,Aporia,WhyLabs' 'Neptune.ai,TensorBoard,Guild.ai'
#  'Guild.ai,WhyLabs' 'Weights & Biases,TensorBoard,ClearML,DVC'
#  'TensorBoard,ClearML,MLflow,DVC' 'Comet.ml,Evidently AI,DVC'
#  'Weights & Biases,ClearML' 'TensorBoard,ClearML,MLflow,Evidently AI'
#  'TensorBoard,Guild.ai,ClearML,MLflow,Aporia,Arize' 'MLflow,Evidently AI'
#  'Weights & Biases,MLflow,Evidently AI' 'ClearML,WhyLabs'
#  'TensorBoard,MLflow,Fiddler' 'Neptune.ai,TensorBoard,MLflow,DVC'
#  'Weights & Biases,Guild.ai' 'Evidently AI,WhyLabs' 'Comet.ml,ClearML'
#  'MLflow,Other' 'Aporia,Arize' 'Weights & Biases,Comet.ml,MLflow,DVC'
#  'Weights & Biases,TensorBoard,Guild.ai' 'Neptune.ai,MLflow,WhyLabs'
#  'Neptune.ai,Weights & Biases,TensorBoard,Arize,DVC'
#  'TensorBoard,ClearML,MLflow,Arize' 'Weights & Biases,Arize'
#  'Evidently AI,Fiddler' 'Neptune.ai,Weights & Biases,TensorBoard,MLflow'
#  'Neptune.ai,MLflow,Arize' 'TensorBoard,Guild.ai'
#  'Weights & Biases,TensorBoard,DVC' 'TensorBoard,MLflow,Other'
#  'Weights & Biases,Guild.ai,ClearML,MLflow'
#  'Neptune.ai,Weights & Biases,ClearML,Evidently AI'
#  'Weights & Biases,TensorBoard,ClearML' 'Weights & Biases,ClearML,WhyLabs'
#  'TensorBoard,Evidently AI' 'Weights & Biases,Comet.ml,TensorBoard'
#  'Neptune.ai,TensorBoard,ClearML,MLflow'
#  'Weights & Biases,TensorBoard,MLflow,Other'
#  'Weights & Biases,Comet.ml,MLflow' 'Weights & Biases,MLflow,Arize'
#  'Weights & Biases,TensorBoard,MLflow,Evidently AI,Other'
#  'Weights & Biases,Other' 'MLflow,Evidently AI,DVC'
#  'Weights & Biases,ClearML,DVC' 'Neptune.ai,MLflow,WhyLabs,DVC'
#  'Comet.ml,TensorBoard,Guild.ai,MLflow,Evidently AI'
#  'Neptune.ai,Weights & Biases,Comet.ml,TensorBoard,MLflow,DVC'
#  'Comet.ml,ClearML,Aporia,DVC' 'MLflow,Arize'
#  'Weights & Biases,TensorBoard,Fiddler'
#  'Weights & Biases,TensorBoard,MLflow,Evidently AI,DVC'
#  'Neptune.ai,Aporia' 'Weights & Biases,Comet.ml,TensorBoard,ClearML'
#  'Weights & Biases,TensorBoard,MLflow,Fiddler,DVC' 'Guild.ai,ClearML'
#  'MLflow,DVC,Other' 'Weights & Biases,Comet.ml,Arize'
#  'Neptune.ai,Weights & Biases,Arize' 'Neptune.ai,TensorBoard,ClearML'
#  'Comet.ml,TensorBoard,MLflow,DVC'
#  'Neptune.ai,Weights & Biases,Comet.ml,TensorBoard,DVC' 'ClearML,Aporia'
#  'Neptune.ai,Guild.ai,WhyLabs' 'Neptune.ai,TensorBoard,Guild.ai,MLflow'
#  'TensorBoard,Guild.ai,DVC'
#  'Neptune.ai,Weights & Biases,Comet.ml,TensorBoard,Guild.ai,ClearML,MLflow,Aporia,Evidently AI,Arize,WhyLabs,Fiddler,DVC,Other'
#  'MLflow,Aporia' 'Neptune.ai,TensorBoard,WhyLabs'
#  'Neptune.ai,Guild.ai,Evidently AI,Arize,Fiddler,DVC' 'Comet.ml,DVC'
#  'Neptune.ai,Weights & Biases,MLflow'
#  'Neptune.ai,Comet.ml,TensorBoard,Guild.ai,ClearML,MLflow,WhyLabs'
#  'Neptune.ai,Comet.ml,TensorBoard,ClearML,MLflow,Fiddler'
#  'Neptune.ai,Weights & Biases,Comet.ml,Guild.ai,ClearML,MLflow,Aporia,Evidently AI,WhyLabs,Fiddler,DVC'
#  'Weights & Biases,Fiddler' 'TensorBoard,MLflow,WhyLabs'
#  'Weights & Biases,MLflow,Other'
#  'Neptune.ai,Comet.ml,Guild.ai,Evidently AI,Other'
#  'Comet.ml,Guild.ai,Arize,Fiddler,DVC'
#  'Neptune.ai,Weights & Biases,TensorBoard,DVC' 'Neptune.ai,Fiddler']
#
#
#
# Ethical_AI_Products : ['None' 'Audit-AI' 'Other'
#  'Google Responsible AI Toolkit (LIT, What-if, Fairness Indicator, etc)'
#  'Amazon AI Ethics Tools (Clarify, A2I, etc)'
#  'Google Responsible AI Toolkit (LIT, What-if, Fairness Indicator, etc),Microsoft Responsible AI Resources (Fairlearn, Counterfit, InterpretML, etc)'
#  'Microsoft Responsible AI Resources (Fairlearn, Counterfit, InterpretML, etc)'
#  'Google Responsible AI Toolkit (LIT, What-if, Fairness Indicator, etc),IBM AI Ethics tools (AI Fairness 360, Adversarial Robustness Toolbox, etc'
#  'Amazon AI Ethics Tools (Clarify, A2I, etc),Aequitas'
#  'Google Responsible AI Toolkit (LIT, What-if, Fairness Indicator, etc),Microsoft Responsible AI Resources (Fairlearn, Counterfit, InterpretML, etc),IBM AI Ethics tools (AI Fairness 360, Adversarial Robustness Toolbox, etc,Amazon AI Ethics Tools (Clarify, A2I, etc)'
#  'IBM AI Ethics tools (AI Fairness 360, Adversarial Robustness Toolbox, etc'
#  'Aequitas'
#  'Microsoft Responsible AI Resources (Fairlearn, Counterfit, InterpretML, etc),Amazon AI Ethics Tools (Clarify, A2I, etc)'
#  'Google Responsible AI Toolkit (LIT, What-if, Fairness Indicator, etc),IBM AI Ethics tools (AI Fairness 360, Adversarial Robustness Toolbox, etc,Amazon AI Ethics Tools (Clarify, A2I, etc)'
#  'Google Responsible AI Toolkit (LIT, What-if, Fairness Indicator, etc),Microsoft Responsible AI Resources (Fairlearn, Counterfit, InterpretML, etc),Amazon AI Ethics Tools (Clarify, A2I, etc)'
#  'The LinkedIn Fairness Toolkit (LiFT),Aequitas'
#  'Google Responsible AI Toolkit (LIT, What-if, Fairness Indicator, etc),Microsoft Responsible AI Resources (Fairlearn, Counterfit, InterpretML, etc),IBM AI Ethics tools (AI Fairness 360, Adversarial Robustness Toolbox, etc,Amazon AI Ethics Tools (Clarify, A2I, etc),The LinkedIn Fairness Toolkit (LiFT),Audit-AI,Aequitas'
#  'Google Responsible AI Toolkit (LIT, What-if, Fairness Indicator, etc),Microsoft Responsible AI Resources (Fairlearn, Counterfit, InterpretML, etc),Amazon AI Ethics Tools (Clarify, A2I, etc),Audit-AI'
#  'Microsoft Responsible AI Resources (Fairlearn, Counterfit, InterpretML, etc),The LinkedIn Fairness Toolkit (LiFT),Audit-AI'
#  'Google Responsible AI Toolkit (LIT, What-if, Fairness Indicator, etc),Audit-AI'
#  'IBM AI Ethics tools (AI Fairness 360, Adversarial Robustness Toolbox, etc,The LinkedIn Fairness Toolkit (LiFT)'
#  'Microsoft Responsible AI Resources (Fairlearn, Counterfit, InterpretML, etc),Audit-AI'
#  'Google Responsible AI Toolkit (LIT, What-if, Fairness Indicator, etc),Amazon AI Ethics Tools (Clarify, A2I, etc)'
#  'Google Responsible AI Toolkit (LIT, What-if, Fairness Indicator, etc),The LinkedIn Fairness Toolkit (LiFT)'
#  'Google Responsible AI Toolkit (LIT, What-if, Fairness Indicator, etc),Microsoft Responsible AI Resources (Fairlearn, Counterfit, InterpretML, etc),IBM AI Ethics tools (AI Fairness 360, Adversarial Robustness Toolbox, etc,Amazon AI Ethics Tools (Clarify, A2I, etc),The LinkedIn Fairness Toolkit (LiFT)'
#  'Google Responsible AI Toolkit (LIT, What-if, Fairness Indicator, etc),Microsoft Responsible AI Resources (Fairlearn, Counterfit, InterpretML, etc),The LinkedIn Fairness Toolkit (LiFT)'
#  'IBM AI Ethics tools (AI Fairness 360, Adversarial Robustness Toolbox, etc,Amazon AI Ethics Tools (Clarify, A2I, etc)'
#  'IBM AI Ethics tools (AI Fairness 360, Adversarial Robustness Toolbox, etc,Amazon AI Ethics Tools (Clarify, A2I, etc),The LinkedIn Fairness Toolkit (LiFT),Aequitas'
#  'Google Responsible AI Toolkit (LIT, What-if, Fairness Indicator, etc),Microsoft Responsible AI Resources (Fairlearn, Counterfit, InterpretML, etc),IBM AI Ethics tools (AI Fairness 360, Adversarial Robustness Toolbox, etc,The LinkedIn Fairness Toolkit (LiFT)'
#  'The LinkedIn Fairness Toolkit (LiFT)'
#  'Google Responsible AI Toolkit (LIT, What-if, Fairness Indicator, etc),Microsoft Responsible AI Resources (Fairlearn, Counterfit, InterpretML, etc),IBM AI Ethics tools (AI Fairness 360, Adversarial Robustness Toolbox, etc,Amazon AI Ethics Tools (Clarify, A2I, etc),Audit-AI,Aequitas'
#  'Microsoft Responsible AI Resources (Fairlearn, Counterfit, InterpretML, etc),IBM AI Ethics tools (AI Fairness 360, Adversarial Robustness Toolbox, etc,Amazon AI Ethics Tools (Clarify, A2I, etc)'
#  'Microsoft Responsible AI Resources (Fairlearn, Counterfit, InterpretML, etc),IBM AI Ethics tools (AI Fairness 360, Adversarial Robustness Toolbox, etc,Amazon AI Ethics Tools (Clarify, A2I, etc),The LinkedIn Fairness Toolkit (LiFT),Audit-AI,Aequitas'
#  'Google Responsible AI Toolkit (LIT, What-if, Fairness Indicator, etc),IBM AI Ethics tools (AI Fairness 360, Adversarial Robustness Toolbox, etc,Audit-AI'
#  'Google Responsible AI Toolkit (LIT, What-if, Fairness Indicator, etc),Microsoft Responsible AI Resources (Fairlearn, Counterfit, InterpretML, etc),IBM AI Ethics tools (AI Fairness 360, Adversarial Robustness Toolbox, etc'
#  'IBM AI Ethics tools (AI Fairness 360, Adversarial Robustness Toolbox, etc,Amazon AI Ethics Tools (Clarify, A2I, etc),Audit-AI'
#  'Google Responsible AI Toolkit (LIT, What-if, Fairness Indicator, etc),Amazon AI Ethics Tools (Clarify, A2I, etc),The LinkedIn Fairness Toolkit (LiFT)'
#  'Microsoft Responsible AI Resources (Fairlearn, Counterfit, InterpretML, etc),IBM AI Ethics tools (AI Fairness 360, Adversarial Robustness Toolbox, etc,The LinkedIn Fairness Toolkit (LiFT)'
#  'Amazon AI Ethics Tools (Clarify, A2I, etc),The LinkedIn Fairness Toolkit (LiFT)'
#  'Google Responsible AI Toolkit (LIT, What-if, Fairness Indicator, etc),Amazon AI Ethics Tools (Clarify, A2I, etc),Aequitas'
#  'IBM AI Ethics tools (AI Fairness 360, Adversarial Robustness Toolbox, etc,Audit-AI'
#  'Amazon AI Ethics Tools (Clarify, A2I, etc),The LinkedIn Fairness Toolkit (LiFT),Audit-AI'
#  'Google Responsible AI Toolkit (LIT, What-if, Fairness Indicator, etc),Amazon AI Ethics Tools (Clarify, A2I, etc),The LinkedIn Fairness Toolkit (LiFT),Audit-AI'
#  'Google Responsible AI Toolkit (LIT, What-if, Fairness Indicator, etc),Microsoft Responsible AI Resources (Fairlearn, Counterfit, InterpretML, etc),IBM AI Ethics tools (AI Fairness 360, Adversarial Robustness Toolbox, etc,Amazon AI Ethics Tools (Clarify, A2I, etc),The LinkedIn Fairness Toolkit (LiFT),Audit-AI'
#  'Microsoft Responsible AI Resources (Fairlearn, Counterfit, InterpretML, etc),IBM AI Ethics tools (AI Fairness 360, Adversarial Robustness Toolbox, etc'
#  'Audit-AI,Aequitas' 'The LinkedIn Fairness Toolkit (LiFT),Audit-AI'
#  'Microsoft Responsible AI Resources (Fairlearn, Counterfit, InterpretML, etc),The LinkedIn Fairness Toolkit (LiFT)'
#  'IBM AI Ethics tools (AI Fairness 360, Adversarial Robustness Toolbox, etc,The LinkedIn Fairness Toolkit (LiFT),Aequitas'
#  'Microsoft Responsible AI Resources (Fairlearn, Counterfit, InterpretML, etc),Amazon AI Ethics Tools (Clarify, A2I, etc),The LinkedIn Fairness Toolkit (LiFT)'
#  'Google Responsible AI Toolkit (LIT, What-if, Fairness Indicator, etc),Microsoft Responsible AI Resources (Fairlearn, Counterfit, InterpretML, etc),Audit-AI'
#  'Google Responsible AI Toolkit (LIT, What-if, Fairness Indicator, etc),Microsoft Responsible AI Resources (Fairlearn, Counterfit, InterpretML, etc),IBM AI Ethics tools (AI Fairness 360, Adversarial Robustness Toolbox, etc,Amazon AI Ethics Tools (Clarify, A2I, etc),The LinkedIn Fairness Toolkit (LiFT),Other'
#  'Amazon AI Ethics Tools (Clarify, A2I, etc),Other'
#  'Google Responsible AI Toolkit (LIT, What-if, Fairness Indicator, etc),Microsoft Responsible AI Resources (Fairlearn, Counterfit, InterpretML, etc),Amazon AI Ethics Tools (Clarify, A2I, etc),The LinkedIn Fairness Toolkit (LiFT)'
#  'Microsoft Responsible AI Resources (Fairlearn, Counterfit, InterpretML, etc),Amazon AI Ethics Tools (Clarify, A2I, etc),Aequitas'
#  'Google Responsible AI Toolkit (LIT, What-if, Fairness Indicator, etc),Microsoft Responsible AI Resources (Fairlearn, Counterfit, InterpretML, etc),IBM AI Ethics tools (AI Fairness 360, Adversarial Robustness Toolbox, etc,Audit-AI'
#  'Google Responsible AI Toolkit (LIT, What-if, Fairness Indicator, etc),Microsoft Responsible AI Resources (Fairlearn, Counterfit, InterpretML, etc),Aequitas'
#  'Amazon AI Ethics Tools (Clarify, A2I, etc),Audit-AI'
#  'Google Responsible AI Toolkit (LIT, What-if, Fairness Indicator, etc),IBM AI Ethics tools (AI Fairness 360, Adversarial Robustness Toolbox, etc,Aequitas'
#  'IBM AI Ethics tools (AI Fairness 360, Adversarial Robustness Toolbox, etc,Aequitas'
#  'Google Responsible AI Toolkit (LIT, What-if, Fairness Indicator, etc),IBM AI Ethics tools (AI Fairness 360, Adversarial Robustness Toolbox, etc,Amazon AI Ethics Tools (Clarify, A2I, etc),The LinkedIn Fairness Toolkit (LiFT)'
#  'Google Responsible AI Toolkit (LIT, What-if, Fairness Indicator, etc),Microsoft Responsible AI Resources (Fairlearn, Counterfit, InterpretML, etc),IBM AI Ethics tools (AI Fairness 360, Adversarial Robustness Toolbox, etc,Amazon AI Ethics Tools (Clarify, A2I, etc),The LinkedIn Fairness Toolkit (LiFT),Audit-AI,Aequitas,Other'
#  'IBM AI Ethics tools (AI Fairness 360, Adversarial Robustness Toolbox, etc,Amazon AI Ethics Tools (Clarify, A2I, etc),The LinkedIn Fairness Toolkit (LiFT),Audit-AI'
#  'Google Responsible AI Toolkit (LIT, What-if, Fairness Indicator, etc),Aequitas'
#  'Microsoft Responsible AI Resources (Fairlearn, Counterfit, InterpretML, etc),Other'
#  'Google Responsible AI Toolkit (LIT, What-if, Fairness Indicator, etc),IBM AI Ethics tools (AI Fairness 360, Adversarial Robustness Toolbox, etc,Amazon AI Ethics Tools (Clarify, A2I, etc),The LinkedIn Fairness Toolkit (LiFT),Audit-AI'
#  'Google Responsible AI Toolkit (LIT, What-if, Fairness Indicator, etc),Amazon AI Ethics Tools (Clarify, A2I, etc),Audit-AI']
#
#
#
# Hardware : ['None' 'GPUs' 'GPUs,TPUs' 'Other' 'Trainium Chips' 'RDUs'
#  'GPUs,TPUs,RDUs' 'TPUs' 'GPUs,TPUs,Trainium Chips,Inferentia Chips'
#  'GPUs,IPUs' 'GPUs,TPUs,Inferentia Chips' 'TPUs,Inferentia Chips'
#  'GPUs,TPUs,IPUs,RDUs,WSEs,Trainium Chips,Inferentia Chips' 'GPUs,Other'
#  'GPUs,RDUs' 'TPUs,WSEs' 'IPUs' 'GPUs,TPUs,Other' 'GPUs,Inferentia Chips'
#  'GPUs,RDUs,Trainium Chips' 'GPUs,IPUs,Trainium Chips,Inferentia Chips'
#  'GPUs,IPUs,RDUs' 'GPUs,Trainium Chips' 'IPUs,Inferentia Chips'
#  'TPUs,IPUs,Inferentia Chips' 'GPUs,RDUs,WSEs' 'TPUs,Trainium Chips'
#  'WSEs' 'Inferentia Chips' 'GPUs,TPUs,IPUs,Trainium Chips'
#  'GPUs,TPUs,IPUs,WSEs,Inferentia Chips' 'GPUs,TPUs,IPUs,RDUs,WSEs'
#  'TPUs,IPUs,RDUs,WSEs,Trainium Chips,Inferentia Chips' 'GPUs,IPUs,Other'
#  'IPUs,WSEs' 'GPUs,IPUs,RDUs,WSEs' 'GPUs,TPUs,IPUs,RDUs'
#  'GPUs,Trainium Chips,Inferentia Chips' 'GPUs,IPUs,RDUs,Trainium Chips'
#  'GPUs,IPUs,RDUs,Inferentia Chips' 'IPUs,WSEs,Trainium Chips'
#  'GPUs,TPUs,IPUs' 'WSEs,Trainium Chips,Inferentia Chips' 'TPUs,IPUs'
#  'GPUs,IPUs,Inferentia Chips' 'TPUs,RDUs'
#  'GPUs,TPUs,IPUs,RDUs,WSEs,Trainium Chips,Inferentia Chips,Other'
#  'GPUs,TPUs,Trainium Chips' 'WSEs,Other'
#  'GPUs,TPUs,IPUs,RDUs,Trainium Chips,Inferentia Chips'
#  'GPUs,TPUs,RDUs,Trainium Chips,Inferentia Chips'
#  'GPUs,IPUs,Trainium Chips' 'GPUs,TPUs,IPUs,RDUs,Other'
#  'WSEs,Inferentia Chips' 'GPUs,WSEs,Trainium Chips']
